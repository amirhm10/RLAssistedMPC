# %%
from Simulation.mpc import *
from Simulation.system_functions import PolymerCSTR
from utils.helpers import *

# %% [markdown]
# ## Initialize the system

# %%
# First initiate the system
# Parameters
Ad = 2.142e17           # h^-1
Ed = 14897              # K
Ap = 3.816e10           # L/(molh)
Ep = 3557               # K
At = 4.50e12            # L/(molh)
Et = 843                # K
fi = 0.6                # Coefficient
m_delta_H_r = -6.99e4   # j/mol
hA = 1.05e6             # j/(Kh)
rhocp = 1506            # j/(Kh)
rhoccpc = 4043          # j/(Kh)
Mm = 104.14             # g/mol
system_params = np.array([Ad, Ed, Ap, Ep, At, Et, fi, m_delta_H_r, hA, rhocp, rhoccpc, Mm])

# %%
# Design Parameters
CIf = 0.5888    # mol/L
CMf = 8.6981    # mol/L
Qi = 108.       # L/h
Qs = 459.       # L/h
Tf = 330.       # K
Tcf = 295.      # K
V = 3000.       # L
Vc = 3312.4     # L

system_design_params = np.array([CIf, CMf, Qi, Qs, Tf, Tcf, V, Vc])

# %%
# Steady State Inputs
Qm_ss = 378.    # L/h
Qc_ss = 471.6   # L/h

system_steady_state_inputs = np.array([Qc_ss, Qm_ss])

# %%
# Sampling time of the system
delta_t = 0.5 # 30 mins

# %%
# Initiate the CSTR for steady state values
cstr = PolymerCSTR(system_params, system_design_params, system_steady_state_inputs, delta_t)
steady_states={"ss_inputs":cstr.ss_inputs,
               "y_ss":cstr.y_ss}

# %% [markdown]
# ## Loading the system matrices, min max scaling, and min max of the states

# %%
dir_path = os.path.join(os.getcwd(), "Data")

# %%
# Defining the range of setpoints for data generation
setpoint_y = np.array([[3.2, 321],
                       [4.5, 325]])
u_min = np.array([71.6, 78])
u_max = np.array([870, 670])

system_data = load_and_prepare_system_data(steady_states=steady_states, setpoint_y=setpoint_y, u_min=u_min, u_max=u_max)

# %%
A_aug = system_data["A_aug"]
B_aug = system_data["B_aug"]
C_aug = system_data["C_aug"]

# %%
data_min = system_data["data_min"]
data_max = system_data["data_max"]

# %%
min_max_states = {'max_s': np.array([256.79686253, 256.01560603,  48.99447186, 144.79949103,
          2.82199733,   3.14014989,   2.78866348,   3.71691422,
          6.2029936 ]),
                  'min_s': np.array([ -272.28060121, -1112.33972595,   -76.63993491,  -608.60327886,
           -3.94399122,    -3.93115257,    -2.9532091 ,    -4.06547624,
          -28.25906582])}

# %%
y_sp_scaled_deviation = system_data["y_sp_scaled_deviation"]

# %%
b_min = system_data["b_min"]
b_max = system_data["b_max"]

# %%
min_max_dict = system_data["min_max_dict"]
min_max_dict["x_max"] = np.array([256.79686253, 256.01560603,  48.99447186, 144.79949103,
          2.82199733,   3.14014989,   2.78866348,   3.71691422,
          6.2029936 ])
min_max_dict["x_min"] = np.array([ -272.28060121, -1112.33972595,   -76.63993491,  -608.60327886,
           -3.94399122,    -3.93115257,    -2.9532091 ,    -4.06547624,
          -28.25906582])

# %%
# Setpoints in deviation form
inputs_number = int(B_aug.shape[1])
y_sp_scenario = np.array([[4.5, 324],
                          [3.4, 321]])

y_sp_scenario = (apply_min_max(y_sp_scenario, data_min[inputs_number:], data_max[inputs_number:])
                 - apply_min_max(steady_states["y_ss"], data_min[inputs_number:], data_max[inputs_number:]))
n_tests = 200
set_points_len = 400
TEST_CYCLE = [False, False, False, False, False]
warm_start = 5
ACTOR_FREEZE = 0 * set_points_len
warm_start_plot = warm_start * 2 * set_points_len + ACTOR_FREEZE

# %%
# Observer Gain
poles = np.array(np.array([0.44619852, 0.33547649, 0.36380595, 0.70467118, 0.3562966,
                           0.42900673, 0.4228262 , 0.96916776, 0.91230187]))
L = compute_observer_gain(A_aug, C_aug, poles)

# %% [markdown]
# ## Setting The hyperparameters for the TD3 Agent

# %%
from TD3Agent.agent import TD3Agent
import torch

# %%
set_points_number = int(C_aug.shape[0])
inputs_number = int(B_aug.shape[1])
STATE_DIM = int(A_aug.shape[0]) + set_points_number + inputs_number
n_states = A_aug.shape[0]
ACTION_DIM = n_states
n_outputs = C_aug.shape[0]
ACTOR_LAYER_SIZES = [512, 512, 512]
CRITIC_LAYER_SIZES = [512, 512, 512]
# Bound poles inside unit circle (discrete-time)
POLE_MIN = np.array([0.3, 0.2, 0.2, 0.5, 0.3, 0.4, 0.4, 0.9, 0.9])
POLE_MAX = np.array([0.6, 0.5, 0.5, 0.8, 0.6, 0.6, 0.6, 0.99, 0.99])

LOW_POLES = POLE_MIN * np.ones(n_states)
HIGH_POLES = POLE_MAX * np.ones(n_states)
BUFFER_CAPACITY = 150000
ACTOR_LR = 1e-4
CRITIC_LR = 1e-4
SMOOTHING_STD = 0.1
NOISE_CLIP = 0.2
GAMMA = 0.995
TAU = 0.005
MAX_ACTION = 1.0
POLICY_DELAY = 4
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
BATCH_SIZE = 128
STD_START = 0.2
STD_END = 0.02
STD_DECAY_RATE = 0.99995
STD_DECAY_MODE = "exp"
ACTOR_FREEZE = 0

# %%
td3_agent = TD3Agent(
    state_dim=STATE_DIM,
    action_dim=ACTION_DIM,
    actor_hidden=ACTOR_LAYER_SIZES,
    critic_hidden=CRITIC_LAYER_SIZES,
    gamma=GAMMA,
    actor_lr=ACTOR_LR,
    critic_lr=CRITIC_LR,
    batch_size=BATCH_SIZE,
    policy_delay=POLICY_DELAY,
    target_policy_smoothing_noise_std=SMOOTHING_STD,
    noise_clip=NOISE_CLIP,
    max_action=MAX_ACTION,
    tau=TAU,
    std_start=STD_START,
    std_end=STD_END,
    std_decay_rate=STD_DECAY_RATE,
    std_decay_mode=STD_DECAY_MODE,
    buffer_size=BUFFER_CAPACITY,
    device=DEVICE,
    actor_freeze=ACTOR_FREEZE,
    )

# %% [markdown]
# ## MPC initialization and setpoints

# %%
# MPC parameters
n_inputs = 2
predict_h = 9
cont_h = 3
u_ss = apply_min_max(steady_states['ss_inputs'], data_min[:n_inputs], data_max[:n_inputs])
b_min = apply_min_max(np.array([71.6, 78]), data_min[:n_inputs], data_max[:n_inputs])
b_max= apply_min_max(np.array([870, 670]), data_min[:n_inputs], data_max[:n_inputs])
b1 = (b_min[0]-u_ss[0], b_max[0]-u_ss[0])
b2 = (b_min[1]-u_ss[1], b_max[1]-u_ss[1])
bnds = (b1, b2)*cont_h
cons = []
IC_opt = np.zeros(n_inputs*cont_h)
Q1_penalty = 5.
Q2_penalty = 1.
R1_penalty = 1
R2_penalty = 1

# %%
MPC_obj = MpcSolverGeneral(A_aug, B_aug, C_aug,
    Q_out=np.array([Q1_penalty, Q2_penalty]),
    R_in=np.array([R1_penalty, R2_penalty]),
    NP=predict_h,
    NC=cont_h)

# %%
def make_reward_fn_relative_QR(
    data_min, data_max, n_inputs,
    k_rel, band_floor_phys,
    Q_diag, R_diag,
    tau_frac=0.7,
    gamma_out=0.5, gamma_in=0.5,
    beta=5.0, gate="geom", lam_in=1.0,
    bonus_kind="exp", bonus_k=12.0, bonus_p=0.6, bonus_c=20.0,
):
    """
    Reward with relative tracking bands.

    data_min, data_max : arrays for [u_min..., y_min...], [u_max..., y_max...]
    n_inputs           : number of inputs (so outputs start at index n_inputs)
    k_rel              : per-output relative tolerance factors (same length as outputs)
    band_floor_phys    : per-output minimum band in physical units
    Q_diag, R_diag     : quadratic weights (same as before)
    """

    data_min = np.asarray(data_min, float)
    data_max = np.asarray(data_max, float)
    dy = np.maximum(data_max[n_inputs:] - data_min[n_inputs:], 1e-12)  # phys range for each y

    k_rel = np.asarray(k_rel, float)
    band_floor_phys = np.asarray(band_floor_phys, float)
    Q_diag = np.asarray(Q_diag, float)
    R_diag = np.asarray(R_diag, float)

    # floor in *scaled* coordinates (used if y_sp_phys is not provided)
    band_floor_scaled = band_floor_phys / np.maximum(dy, 1e-12)

    def _sigmoid(x):
        x = np.clip(x, -60.0, 60.0)
        return 1.0 / (1.0 + np.exp(-x))

    def _phi(z, kind=bonus_kind, k=bonus_k, p=bonus_p, c=bonus_c):
        z = np.clip(z, 0.0, 1.0)
        if kind == "linear":
            return 1.0 - z
        if kind == "quadratic":
            return (1.0 - z) ** 2
        if kind == "exp":
            return (np.exp(-k * z) - np.exp(-k)) / (1.0 - np.exp(-k))
        if kind == "power":
            return 1.0 - np.power(z, p)
        if kind == "log":
            return np.log1p(c * (1.0 - z)) / np.log1p(c)
        raise ValueError("unknown bonus kind")

    def reward_fn(e_scaled, du_scaled, y_sp_phys=None):
        """
        e_scaled : output error in scaled deviation space  (same as before)
        du_scaled: input move in scaled deviation space    (same as before)
        y_sp_phys: current setpoint in *physical* units (array len = n_outputs)
        """

        e_scaled = np.asarray(e_scaled, float)
        du_scaled = np.asarray(du_scaled, float)

        # ----- dynamic band based on setpoint -----
        if y_sp_phys is None:
            # fallback: just use the floor
            band_scaled = band_floor_scaled
        else:
            y_sp_phys_arr = np.asarray(y_sp_phys, float)
            # band_phys_i = max(k_rel_i * |y_sp_i|, band_floor_phys_i)
            band_phys = np.maximum(k_rel * np.abs(y_sp_phys_arr), band_floor_phys)
            band_scaled = band_phys / np.maximum(dy, 1e-12)

        tau_scaled = tau_frac * band_scaled

        # ----- inside/outside gate -----
        abs_e = np.abs(e_scaled)
        s_i = _sigmoid((band_scaled - abs_e) / np.maximum(tau_scaled, 1e-12))

        if gate == "prod":
            w_in = float(np.prod(s_i, dtype=np.float64))
        elif gate == "mean":
            w_in = float(np.mean(s_i))
        elif gate == "geom":
            w_in = float(np.prod(s_i, dtype=np.float64) ** (1.0 / len(s_i)))
        else:
            raise ValueError("gate must be 'prod'|'mean'|'geom'")

        # ----- core quadratic costs -----
        err_quad = np.sum(Q_diag * (e_scaled ** 2))
        err_eff = (1.0 - w_in) * err_quad + w_in * (lam_in * err_quad)
        move = np.sum(R_diag * (du_scaled ** 2))

        # ----- linear penalties around band edge -----
        slope_at_edge = 2.0 * Q_diag * band_scaled

        overflow = np.maximum(abs_e - band_scaled, 0.0)
        lin_out = (1.0 - w_in) * np.sum(gamma_out * slope_at_edge * overflow)

        inside_mag = np.minimum(abs_e, band_scaled)
        lin_in = w_in * np.sum(gamma_in * slope_at_edge * inside_mag)

        # ----- bonus near zero error -----
        qb2 = Q_diag * (band_scaled ** 2)
        z = abs_e / np.maximum(band_scaled, 1e-12)
        phi = _phi(z)
        bonus = w_in * beta * np.sum(qb2 * phi)

        # ----- total reward -----
        return (-(err_eff + move + lin_out + lin_in) + bonus) * 0.01

    params = dict(
        k_rel=k_rel,
        band_floor_phys=band_floor_phys,
        band_floor_scaled=band_floor_scaled,
        Q_diag=Q_diag,
        R_diag=R_diag,
        tau_frac=tau_frac,
        gamma_out=gamma_out,
        gamma_in=gamma_in,
        beta=beta,
        gate=gate,
        lam_in=lam_in,
        bonus_kind=bonus_kind,
        bonus_k=bonus_k,
        bonus_p=bonus_p,
        bonus_c=bonus_c,
    )
    return params, reward_fn

# %%
n_inputs = 2

dy = data_max[n_inputs:] - data_min[n_inputs:]
y_sp_nom = 0.5 * (data_min[n_inputs:] + data_max[n_inputs:])

k_rel = np.array([0.003, 0.0003])
band_floor_phys = np.array([0.006, 0.07])

band_phys = np.maximum(k_rel * np.abs(y_sp_nom), band_floor_phys)

scale_factor = 1.0  # use 2.0 for [-1, 1] scaling, 1.0 for [0, 1]
band_scaled = scale_factor * band_phys / dy

q0 = 1.4
Q_diag = q0 / np.maximum(band_scaled ** 2, 1e-12)

print("dy:", dy)
print("y_sp_nom:", y_sp_nom)
print("band_phys:", band_phys)
print("band_scaled:", band_scaled)
print("Q_diag:", Q_diag)
# Out:
# dy: [0.22165278 0.78153727]
# y_sp_nom: [  3.83915067 323.21371982]
# band_phys: [0.01151745 0.09696412]
# band_scaled: [0.05196169 0.12406845]
# Q_diag: [518.51529284  90.95055189]

# %%
Q_diag = np.array([518., 90.])          # rounded from the band-based calculation
R_diag = np.array([90., 90.])          # move cost for du_scaled ~ 0.02

n_inputs = 2

print("Band scaled are:")

params, reward_fn = make_reward_fn_relative_QR(
    data_min, data_max, n_inputs,
    k_rel, band_floor_phys,
    Q_diag, R_diag,
    tau_frac=0.7,
    gamma_out=0.5, gamma_in=0.5,
    beta=7.0, gate="geom", lam_in=1.0,
    bonus_kind="exp", bonus_k=12.0, bonus_p=0.6, bonus_c=20.0,
)
print(params)
# Out:
# Band scaled are:
# {'k_rel': array([0.003 , 0.0003]), 'band_floor_phys': array([0.006, 0.07 ]), 'band_floor_scaled': array([0.02706937, 0.08956707]), 'Q_diag': array([518.,  90.]), 'R_diag': array([90., 90.]), 'tau_frac': 0.7, 'gamma_out': 0.5, 'gamma_in': 0.5, 'beta': 7.0, 'gate': 'geom', 'lam_in': 1.0, 'bonus_kind': 'exp', 'bonus_k': 12.0, 'bonus_p': 0.6, 'bonus_c': 20.0}

# %%
nominal_qs = 459
nominal_qi = 108
nominal_hA = 1.05e6
qi_change = 0.85
qs_change = 1.3
ha_change = 0.85

# %%
def sanitize_poles(poles, low, high, eps=1e-3):
    poles = np.asarray(poles, float)
    poles = np.sort(poles)

    low = np.asarray(low, float)
    high = np.asarray(high, float)
    if low.shape != poles.shape or high.shape != poles.shape:
        raise ValueError("low/high must have same shape as poles")

    poles = np.minimum(np.maximum(poles, low), high)

    n = len(poles)

    # forward pass: enforce spacing, respect upper bounds
    for k in range(1, n):
        poles[k] = max(poles[k], poles[k - 1] + eps)
        poles[k] = min(poles[k], high[k])

    # backward pass: if upper bounds forced compression, enforce spacing backward
    for k in range(n - 2, -1, -1):
        poles[k] = min(poles[k], poles[k + 1] - eps)
        poles[k] = max(poles[k], low[k])

    # final clip (in case bounds are very tight)
    poles = np.minimum(np.maximum(poles, low), high)

    return poles

# %%
import warnings
def compute_observer_gain(A, C, desired_poles):
    """
    Compute an observer gain L for the given MPC system using the desired poles.
    Also performs an observability check.

    Parameters:
    -----------
    A, C : np.ndarray
        System Matrices
    desired_poles : np.ndarray
        A vector of desired observer poles.

    Returns:
    --------
    L : np.ndarray
        The observer gain matrix.
    """
    # Compute the observer gain using pole placement
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", UserWarning)
        obs_gain_calc = signal.place_poles(A.T, C.T, desired_poles, "KNV0")
    L = np.squeeze(obs_gain_calc.gain_matrix).T

    # Check observability
    observability_matrix = control.obsv(A, C)
    rank = np.linalg.matrix_rank(observability_matrix)
    if rank == A.shape[0]:
        # print("The system is observable.")
        pass
    else:
        # print("The system is not observable.")
        pass
    return L

# %%
def run_rl_train_disturbance_gradually(
    system, y_sp_scenario, n_tests, set_points_len,
    steady_states, min_max_dict, agent, MPC_obj,
    poles,  # baseline poles
    data_min, data_max, warm_start,
    test_cycle,
    low_poles, high_poles,  # changed meaning
    reward_fn,
    nominal_qi, nominal_qs, nominal_ha,
    qi_change, qs_change, ha_change,
    mode="disturb",
    pole_update_every=1,      # set to time_in_sub_episodes if you only want updates at setpoint changes
    pole_smooth=0.25          # 0..1, smoothing on poles to avoid jitter
):

    y_sp, nFE, sub_episodes_changes_dict, time_in_sub_episodes, test_train_dict, WARM_START, qi, qs, ha = \
        generate_setpoints_training_rl_gradually(
            y_sp_scenario, n_tests, set_points_len, warm_start, test_cycle,
            nominal_qi, nominal_qs, nominal_ha,
            qi_change, qs_change, ha_change
        )

    n_inputs = B_aug.shape[1]
    n_outputs = C_aug.shape[0]
    n_states = A_aug.shape[0]

    ss_scaled_inputs = apply_min_max(steady_states["ss_inputs"], data_min[:n_inputs], data_max[:n_inputs])
    y_ss_scaled = apply_min_max(steady_states["y_ss"], data_min[n_inputs:], data_max[n_inputs:])

    y_system = np.zeros((nFE + 1, n_outputs))
    y_system[0, :] = system.current_output
    u_mpc = np.zeros((nFE, n_inputs))
    rewards = np.zeros(nFE)
    avg_rewards = []
    yhat = np.zeros((n_outputs, nFE))
    xhatdhat = np.zeros((n_states, nFE + 1))

    # log poles and L
    poles_log = np.zeros((nFE, n_states))
    poles_base = np.asarray(poles, float).copy()
    poles_cur = poles_base.copy()

    def map_to_bounds(a, low, high):
        return low + ((a + 1.0) / 2.0) * (high - low)

    def map_from_bounds(x, low, high):
        return 2.0 * (x - low) / (high - low) - 1.0

    test = False

    # initial observer gain from baseline poles
    L = compute_observer_gain(MPC_obj.A, MPC_obj.C, poles_cur)

    for i in range(nFE):
        if i in test_train_dict:
            test = test_train_dict[i]

        scaled_current_input = apply_min_max(system.current_input, data_min[:n_inputs], data_max[:n_inputs])
        scaled_current_input_dev = scaled_current_input - ss_scaled_inputs

        current_rl_state = apply_rl_scaled(
            min_max_dict, xhatdhat[:, i], y_sp[i, :], scaled_current_input_dev
        ).astype(np.float32)

        # TD3 action = pole proposal (in [-1,1])
        if i > WARM_START:
            if not test:
                action = agent.take_action(current_rl_state, explore=True)
            else:
                action = agent.act_eval(current_rl_state)
        else:
            action = map_from_bounds(poles, low_poles, high_poles)

        # update poles and L every pole_update_every steps
        if (i % pole_update_every) == 0:
            poles_prop = map_to_bounds(action, LOW_POLES, HIGH_POLES)
            poles_prop = sanitize_poles(poles_prop, LOW_POLES, HIGH_POLES)

            # smooth pole motion (reduces chattering)
            poles_cur = (1.0 - pole_smooth) * poles_cur + pole_smooth * poles_prop
            poles_cur = sanitize_poles(poles_cur, LOW_POLES, HIGH_POLES)

            try:
                L_new = compute_observer_gain(MPC_obj.A, MPC_obj.C, poles_cur)
                if np.all(np.isfinite(L_new)):
                    L = L_new
            except Exception:
                pass

        poles_log[i, :] = poles_cur

        # MPC solve (A,B,C fixed, no multipliers)
        sol = spo.minimize(
            lambda x: MPC_obj.mpc_opt_fun(x, y_sp[i, :], scaled_current_input_dev, xhatdhat[:, i]),
            IC_opt, bounds=bnds, constraints=cons
        )

        u_mpc[i, :] = sol.x[:n_inputs] + ss_scaled_inputs
        u_plant = reverse_min_max(u_mpc[i, :], data_min[:n_inputs], data_max[:n_inputs])

        delta_u = u_mpc[i, :] - scaled_current_input

        system.current_input = u_plant
        system.step()
        if mode == "disturb":
            system.hA = ha[i]
            system.Qs = qs[i]
            system.Qi = qi[i]

        y_system[i + 1, :] = system.current_output

        y_current_scaled = apply_min_max(y_system[i + 1, :], data_min[n_inputs:], data_max[n_inputs:]) - y_ss_scaled
        y_prev_scaled = apply_min_max(y_system[i, :], data_min[n_inputs:], data_max[n_inputs:]) - y_ss_scaled

        delta_y = y_current_scaled - y_sp[i, :]

        # observer update with current L
        yhat[:, i] = MPC_obj.C @ xhatdhat[:, i]
        xhatdhat[:, i + 1] = (
            MPC_obj.A @ xhatdhat[:, i]
            + MPC_obj.B @ (u_mpc[i, :] - ss_scaled_inputs)
            + L @ (y_prev_scaled - yhat[:, i])
        )

        y_sp_phys = reverse_min_max(y_sp[i, :] + y_ss_scaled, data_min[n_inputs:], data_max[n_inputs:])
        reward = reward_fn(delta_y, delta_u, y_sp_phys)
        rewards[i] = reward

        next_u_dev = u_mpc[i, :] - ss_scaled_inputs
        next_rl_state = apply_rl_scaled(min_max_dict, xhatdhat[:, i + 1], y_sp[i, :], next_u_dev)

        done = 0.0

        if not test:
            agent.push(
                current_rl_state,
                action.astype(np.float32),
                float(reward),
                next_rl_state,
                float(done)
            )
            if i >= warm_start:
                _ = agent.train_step()

        if i in sub_episodes_changes_dict:
            avg_rewards.append(np.mean(rewards[max(0, i - time_in_sub_episodes + 1): i + 1]))
            print("Sub_Episode:", sub_episodes_changes_dict[i], "| avg. reward:", avg_rewards[-1])
            print("Avg poles:", np.mean(poles_log[max(0, i - time_in_sub_episodes + 1): i + 1, :], axis=0))
            if hasattr(agent, "_expl_sigma"):
                print("Exploration noise:", agent._expl_sigma)

    u_rl = reverse_min_max(u_mpc, data_min[:n_inputs], data_max[:n_inputs])

    return (
        y_system, u_rl, avg_rewards, rewards, xhatdhat, nFE, time_in_sub_episodes,
        y_sp, yhat, poles_log
    )

# %%
cstr = PolymerCSTR(system_params, system_design_params, system_steady_state_inputs, delta_t)
poles = np.array(np.array([0.44619852, 0.33547649, 0.36380595, 0.70467118, 0.3562966,
                           0.42900673, 0.4228262 , 0.96916776, 0.91230187]))

(y_system, u_rl, avg_rewards, rewards, xhatdhat, nFE, time_in_sub_episodes,
 y_sp, yhat, poles_log) = run_rl_train_disturbance_gradually(
    cstr, y_sp_scenario, n_tests, set_points_len,
    steady_states, min_max_dict, td3_agent, MPC_obj,
    poles,
    data_min, data_max, warm_start,
    TEST_CYCLE,
    LOW_POLES, HIGH_POLES,
    reward_fn,
    nominal_qi, nominal_qs, nominal_hA,
    qi_change, qs_change, ha_change,
    mode="nominal",
    pole_update_every=400,
    pole_smooth=0.25
)
# Out:
# Sub_Episode: 1 | avg. reward: -3.430970006529064
# Avg poles: [0.34003089 0.36286728 0.38888914 0.5        0.501      0.502
#  0.6        0.92474128 0.95672835]
# Sub_Episode: 2 | avg. reward: -4.476687397206739
# Avg poles: [0.33803834 0.35999261 0.37791524 0.5        0.501      0.502
#  0.6        0.91929904 0.96217059]
# Sub_Episode: 3 | avg. reward: -4.454447255689477
# Avg poles: [0.33691753 0.3583756  0.37174243 0.5        0.501      0.502
#  0.6        0.91623778 0.96523185]
# Sub_Episode: 4 | avg. reward: -4.440408202806696
# Avg poles: [0.33628708 0.35746604 0.36827022 0.5        0.501      0.502
#  0.6        0.91451582 0.96695381]
# Sub_Episode: 5 | avg. reward: -4.431897932646429
# Avg poles: [0.33593244 0.35695441 0.3663171  0.5        0.501      0.502
#  0.6        0.91354722 0.96792241]
# Sub_Episode: 6 | avg. reward: -4.423134306075252
# Avg poles: [0.3312984  0.34975454 0.35749273 0.50275865 0.505324   0.514125
#  0.6        0.91606621 0.97029341]
# Exploration noise: 0.19295057362832285
# Sub_Episode: 7 | avg. reward: -4.4501200813566175
# Avg poles: [0.31967826 0.33208687 0.38067447 0.50362073 0.50667525 0.53913281
#  0.587875   0.92375616 0.96847011]
# Exploration noise: 0.18616891846288888
# Sub_Episode: 8 | avg. reward: -4.821027179658395
# Avg poles: [0.31669001 0.35652937 0.41932905 0.50203666 0.51616128 0.55577811
#  0.58408594 0.92227713 0.97788943]
# Exploration noise: 0.17965318231592373
# Sub_Episode: 9 | avg. reward: -5.296538183028772
# Avg poles: [0.3118787  0.36566973 0.42150652 0.50114562 0.52998224 0.57229878
#  0.59104834 0.91675244 0.98318781]
# Exploration noise: 0.17339293809807255
# Sub_Episode: 10 | avg. reward: -6.598497079476342
# Avg poles: [0.30668177 0.35903297 0.41374673 0.50064441 0.52681163 0.56413646
#  0.59496469 0.90942325 0.98546979]
# Exploration noise: 0.16737816758202073
# Sub_Episode: 11 | avg. reward: -6.8106269905873384
# Avg poles: [0.30375849 0.3366072  0.39548254 0.50036248 0.52279002 0.547135
#  0.58558407 0.90845719 0.98692799]
# Exploration noise: 0.1615992453703911
# Sub_Episode: 12 | avg. reward: -4.427793147003644
# Avg poles: [0.30211415 0.32102905 0.3613318  0.5002039  0.51325689 0.54101967
#  0.57976604 0.93035804 0.98575286]
# Exploration noise: 0.1560469234922843
# Sub_Episode: 13 | avg. reward: -4.381996000587268
# Avg poles: [0.30211493 0.31847656 0.35016914 0.50011469 0.5078945  0.53724433
#  0.57952465 0.92345112 0.97878784]
# Exploration noise: 0.1507123166038122
# Sub_Episode: 14 | avg. reward: -4.410143969924169
# Avg poles: [0.30118965 0.31157954 0.35576126 0.50006451 0.50487816 0.53428307
#  0.58848261 0.93245687 0.97434048]
# Exploration noise: 0.14558688776894124
# Sub_Episode: 15 | avg. reward: -4.392369644755933
# Avg poles: [0.30066918 0.32006282 0.36014621 0.50003629 0.50489787 0.53688133
#  0.57230272 0.92850558 0.98094234]
# Exploration noise: 0.14066243479788998
# Sub_Episode: 16 | avg. reward: -4.391817944490777
# Avg poles: [0.30265207 0.32270829 0.3779816  0.50002041 0.50447986 0.53719603
#  0.58284048 0.92800748 0.98211168]
# Exploration noise: 0.1359310771212194
# Sub_Episode: 17 | avg. reward: -4.411694659769248
# Avg poles: [0.30735866 0.33012579 0.39080316 0.50001148 0.5105085  0.54118085
#  0.58751835 0.92436776 0.97116332]
# Exploration noise: 0.13138524317860975
# Sub_Episode: 18 | avg. reward: -7.515866023708147
# Avg poles: [0.31398169 0.34335872 0.41033539 0.5107739  0.52277928 0.54296706
#  0.59174565 0.9159709  0.96081124]
# Exploration noise: 0.12701765830214287
# Sub_Episode: 19 | avg. reward: -7.890937402339582
# Avg poles: [0.31384312 0.3467622  0.39389776 0.5141359  0.52132643 0.54412575
#  0.59315095 0.91133207 0.95529357]
# Exploration noise: 0.12282133307469925
# Sub_Episode: 20 | avg. reward: -5.073218813041174
# Avg poles: [0.31190815 0.34860686 0.3975409  0.50795145 0.51243362 0.54471062
#  0.59449293 0.90869247 0.9528893 ]
# Exploration noise: 0.11878955214484031
# Sub_Episode: 21 | avg. reward: -20.83390209215991
# Avg poles: [0.30872249 0.3499846  0.39889911 0.50447269 0.50743141 0.54636717
#  0.59690227 0.9075646  0.95036326]
# Exploration noise: 0.1149158634802758
# Sub_Episode: 22 | avg. reward: -10.334360645971536
# Avg poles: [0.3049064  0.33132018 0.39224787 0.50251589 0.51962434 0.54510633
#  0.59317587 0.90487798 0.95848884]
# Exploration noise: 0.1111940680427195
# Sub_Episode: 23 | avg. reward: -4.33822971363629
# Avg poles: [0.30275985 0.32134808 0.3931831  0.50141519 0.51147619 0.54746606
#  0.59235019 0.9193175  0.97154156]
# Exploration noise: 0.10761820986760927
# Sub_Episode: 24 | avg. reward: -4.386700382508444
# Avg poles: [0.30155242 0.3197369  0.38391549 0.50079604 0.50689286 0.52757466
#  0.59569698 0.92380803 0.97945458]
# Exploration noise: 0.10418256653281642
# Sub_Episode: 25 | avg. reward: -4.4182676911957595
# Avg poles: [0.30087323 0.32493725 0.37671499 0.50044777 0.50431473 0.52696259
#  0.59757955 0.93415732 0.98253094]
# Exploration noise: 0.10088164000109158
# Sub_Episode: 26 | avg. reward: -4.421369276178726
# Avg poles: [0.30049119 0.32145343 0.38108596 0.50025187 0.50286454 0.5322013
#  0.5986385  0.92733716 0.9850945 ]
# Exploration noise: 0.09771014782159211
# Sub_Episode: 27 | avg. reward: -5.661330948213382
# Avg poles: [0.30622007 0.33445237 0.38921063 0.50014168 0.5020488  0.52515864
#  0.57811149 0.91559275 0.98694607]
# Exploration noise: 0.09466301467641107
# Sub_Episode: 28 | avg. reward: -6.807730896184287
# Avg poles: [0.30349879 0.32042379 0.38140425 0.50007969 0.50158995 0.51502673
#  0.56866977 0.91013086 0.98754869]
# Exploration noise: 0.09173536425857959
# Sub_Episode: 29 | avg. reward: -6.968118436473322
# Avg poles: [0.30196807 0.31893508 0.37032595 0.50004483 0.50133185 0.50932754
#  0.57406467 0.90608065 0.98730874]
# Exploration noise: 0.08892251146854516
# Sub_Episode: 30 | avg. reward: -7.074224745042861
# Avg poles: [0.30110704 0.31860521 0.37581098 0.50002522 0.50118666 0.517246
#  0.57672539 0.9060015  0.98827466]
# Exploration noise: 0.08621995491663792
# Sub_Episode: 31 | avg. reward: -7.313837014568296
# Avg poles: [0.3019381  0.31926563 0.38639368 0.50001418 0.501105   0.5168264
#  0.58645813 0.90420281 0.98816614]
# Exploration noise: 0.08362336971952657
# Sub_Episode: 32 | avg. reward: -6.180624879384621
# Avg poles: [0.30207672 0.31779721 0.37090894 0.50000798 0.50105906 0.51033985
#  0.5923827  0.90405346 0.98068102]
# Exploration noise: 0.08112860057913625
# Sub_Episode: 33 | avg. reward: -6.231699002875212
# Avg poles: [0.30263189 0.31776151 0.37346899 0.50000449 0.50103322 0.51122507
#  0.59571527 0.90331585 0.96772195]
# Exploration noise: 0.07873165513295267
# Sub_Episode: 34 | avg. reward: -6.842006011467614
# Avg poles: [0.30341503 0.32174067 0.37389839 0.50000252 0.50101869 0.51310396
#  0.59758984 0.90308997 0.95854465]
# Exploration noise: 0.0764286975650707
# Sub_Episode: 35 | avg. reward: -6.894494360849621
# Avg poles: [0.30192096 0.32189826 0.3708683  0.50000142 0.50101051 0.51013181
#  0.59834661 0.90276719 0.95680404]
# Exploration noise: 0.07421604246776374
# Sub_Episode: 36 | avg. reward: -6.286122906113956
# Avg poles: [0.30108054 0.31533766 0.35218289 0.5000008  0.50100591 0.50657414
#  0.59725982 0.90570014 0.95587897]
# Exploration noise: 0.0720901489437501
# Sub_Episode: 37 | avg. reward: -4.675932525063772
# Avg poles: [0.3006078  0.30968509 0.34247788 0.50000045 0.50100333 0.51669795
#  0.59726848 0.90762431 0.94631686]
# Exploration noise: 0.07004761493971857
# Sub_Episode: 38 | avg. reward: -4.6339657308702895
# Avg poles: [0.30178163 0.31872548 0.34633131 0.50000025 0.50100187 0.53064473
#  0.59846352 0.90635487 0.93559182]
# Exploration noise: 0.0680851718020451
# Sub_Episode: 39 | avg. reward: -4.62771893261716
# Avg poles: [0.30208197 0.32025183 0.33621761 0.50000014 0.50100105 0.5265752
#  0.59913573 0.90795934 0.93134424]
# Exploration noise: 0.06619967904598803
# Sub_Episode: 40 | avg. reward: -4.622990206850473
# Avg poles: [0.30117111 0.31182916 0.32255272 0.50000008 0.50100059 0.51582355
#  0.59951385 0.90935191 0.9293829 ]
# Exploration noise: 0.0643881193299912
# Sub_Episode: 41 | avg. reward: -4.6240773913099735
# Avg poles: [0.30065875 0.3070914  0.31735556 0.50000004 0.50100033 0.50977575
#  0.59972654 0.90726828 0.92665686]
# Exploration noise: 0.06264759362705223
# Sub_Episode: 42 | avg. reward: -4.622975222480416
# Avg poles: [0.30101282 0.31721637 0.32538605 0.50000003 0.50100019 0.51357766
#  0.59984618 0.90768122 0.92419665]
# Exploration noise: 0.060975316585428915
# Sub_Episode: 43 | avg. reward: -4.621817037946396
# Avg poles: [0.30771288 0.32657266 0.33806199 0.50000001 0.50100011 0.51391529
#  0.59991348 0.90694579 0.92330747]
# Exploration noise: 0.05936861207125922
# Sub_Episode: 44 | avg. reward: -4.620986098106758
# Avg poles: [0.31145564 0.33214742 0.34574682 0.50000001 0.50100006 0.50870235
#  0.59995133 0.90587841 0.92114985]
# Exploration noise: 0.057824908885962006
# Sub_Episode: 45 | avg. reward: -4.624061414074852
# Avg poles: [0.31383508 0.33543455 0.34804509 0.5        0.50100003 0.50577007
#  0.59997262 0.90451889 0.92383274]
# Exploration noise: 0.05634173665156507
# Sub_Episode: 46 | avg. reward: -4.626979211988791
# Avg poles: [0.31269344 0.33892112 0.34971344 0.5        0.50100002 0.51502108
#  0.5999846  0.90334038 0.92440596]
# Exploration noise: 0.05491672185737553
# Sub_Episode: 47 | avg. reward: -4.629620008228531
# Avg poles: [0.30802114 0.34400086 0.35140655 0.5        0.50100001 0.52841373
#  0.59999134 0.90301978 0.92500416]
# Exploration noise: 0.053547584061666514
# Sub_Episode: 48 | avg. reward: -4.631941720663465
# Avg poles: [0.30698886 0.34685473 0.35296594 0.5        0.50100001 0.53716827
#  0.59999513 0.90213158 0.92412684]
# Exploration noise: 0.05223213224230133
# Sub_Episode: 49 | avg. reward: -4.6353534511395855
# Avg poles: [0.30552996 0.34844953 0.35305646 0.5        0.501      0.5430009
#  0.59999726 0.90145133 0.92458123]
# Exploration noise: 0.05096826129045526
# Sub_Episode: 50 | avg. reward: -4.635257816874156
# Avg poles: [0.30368109 0.34975259 0.35315263 0.5        0.501      0.54628176
#  0.59999846 0.9015987  0.92087169]
# Exploration noise: 0.04975394864182388
# Sub_Episode: 51 | avg. reward: -4.635365213957601
# Avg poles: [0.30249848 0.35044176 0.35384174 0.5        0.501      0.54734299
#  0.59999913 0.9012491  0.91856644]
# Exploration noise: 0.048587251039926845
# Sub_Episode: 52 | avg. reward: -4.636313997174885
# Avg poles: [0.30210403 0.35051052 0.35345466 0.5        0.501      0.548136
#  0.59999951 0.90070262 0.9179059 ]
# Exploration noise: 0.047466301426327365
# Sub_Episode: 53 | avg. reward: -4.635934539435308
# Avg poles: [0.30292606 0.35124574 0.3535335  0.5        0.501      0.54917025
#  0.59999973 0.90039522 0.9138303 ]
# Exploration noise: 0.04638930595279102
# Sub_Episode: 54 | avg. reward: -4.6289204133318815
# Avg poles: [0.30255984 0.33854448 0.35253429 0.5        0.513125   0.54975201
#  0.59999985 0.90079943 0.91453293]
# Exploration noise: 0.04535454111060228
# Sub_Episode: 55 | avg. reward: -4.632859892267703
# Avg poles: [0.30143991 0.32269143 0.36436304 0.50266958 0.52903906 0.55007926
#  0.59999991 0.90158365 0.92798013]
# Exploration noise: 0.044360350972445
# Sub_Episode: 56 | avg. reward: -4.961935640165914
# Avg poles: [0.30080995 0.31363093 0.38165999 0.51457405 0.53732373 0.54973168
#  0.59999995 0.90122479 0.94147279]
# Exploration noise: 0.04340514454243284
# Sub_Episode: 57 | avg. reward: -5.488523370030277
# Avg poles: [0.3004556  0.30987763 0.41173142 0.52862558 0.5421506  0.55417046
#  0.59999997 0.90120166 0.9535729 ]
# Exploration noise: 0.04248739321004914
# Sub_Episode: 58 | avg. reward: -5.816083197198737
# Avg poles: [0.30025627 0.30896798 0.41610198 0.52519564 0.54471796 0.55427704
#  0.59999998 0.90092824 0.96075799]
# Exploration noise: 0.04160562830392165
# Sub_Episode: 59 | avg. reward: -4.547753836789046
# Avg poles: [0.30051583 0.30818462 0.41034342 0.51417255 0.5463241  0.55303826
#  0.57992385 0.90099075 0.97025114]
# Exploration noise: 0.04075843874151744
# Sub_Episode: 60 | avg. reward: -5.548550124934559
# Avg poles: [0.30029016 0.32025094 0.4202593  0.51550675 0.54771356 0.55192777
#  0.58870717 0.90084624 0.97788626]
# Exploration noise: 0.0399444687709969
# Sub_Episode: 61 | avg. reward: -5.737872557789242
# Avg poles: [0.30016321 0.33636985 0.43433476 0.52036102 0.54958572 0.55329537
#  0.58586299 0.90095746 0.98149585]
# Exploration noise: 0.03916241580161307
# Sub_Episode: 62 | avg. reward: -4.985432847750978
# Avg poles: [0.30009181 0.34529815 0.44068839 0.52304173 0.54920913 0.55258385
#  0.57749619 0.90053857 0.98354415]
# Exploration noise: 0.03841102831918426
# Sub_Episode: 63 | avg. reward: -5.8231168387913
# Avg poles: [0.3012591  0.35877484 0.44298179 0.52999313 0.54919889 0.55573597
#  0.58076094 0.90043359 0.98408481]
# Exploration noise: 0.03768910388330428
# Sub_Episode: 64 | avg. reward: -5.875141799862601
# Avg poles: [0.30070824 0.35497592 0.44161031 0.52565259 0.5492275  0.55577474
#  0.58563718 0.90034187 0.98379099]
# Exploration noise: 0.03699548720308494
# Sub_Episode: 65 | avg. reward: -5.195472471543395
# Avg poles: [0.30039839 0.33882078 0.44288684 0.51469413 0.54934672 0.55544351
#  0.5872693  0.9001923  0.98319874]
# Exploration noise: 0.036329068288351765
# Sub_Episode: 66 | avg. reward: -5.247509514373648
# Avg poles: [0.3004677  0.33253041 0.44069628 0.50846386 0.54941378 0.5532871
#  0.58592985 0.90023839 0.9826297 ]
# Exploration noise: 0.035688780673334045
# Sub_Episode: 67 | avg. reward: -5.230332174417989
# Avg poles: [0.30026308 0.31957426 0.44236464 0.50476092 0.5501986  0.56174627
#  0.58682057 0.90106136 0.98239287]
# Exploration noise: 0.03507359971000677
# Sub_Episode: 68 | avg. reward: -5.068602599206056
# Avg poles: [0.30014798 0.31371764 0.44318501 0.50321467 0.549561   0.56701534
#  0.58380931 0.9027628  0.97991985]
# Exploration noise: 0.03448254092835316
# Sub_Episode: 69 | avg. reward: -6.6268181088648905
# Avg poles: [0.30008324 0.30886312 0.43639728 0.5036956  0.54923641 0.57211443
#  0.58402124 0.91640836 0.98114704]
# Exploration noise: 0.0339146584609238
# Sub_Episode: 70 | avg. reward: -4.979164195259204
# Avg poles: [0.30004682 0.30642212 0.42154758 0.51381458 0.54922718 0.58163136
#  0.59101195 0.92439874 0.98228433]
# Exploration noise: 0.0333690435291713
# Sub_Episode: 71 | avg. reward: -6.935823185020187
# Avg poles: [0.30002634 0.30407113 0.43278297 0.52763709 0.5490769  0.5804164
#  0.59494422 0.92948917 0.98162174]
# Exploration noise: 0.032844822989137955
# Sub_Episode: 72 | avg. reward: -35.22869148647884
# Avg poles: [0.30001481 0.30323151 0.44009355 0.53638785 0.54910615 0.57938989
#  0.59004413 0.92543641 0.97848994]
# Exploration noise: 0.032341157934169286
# Sub_Episode: 73 | avg. reward: -33.580923248507226
# Avg poles: [0.30000833 0.32679478 0.46483182 0.55441747 0.5697689  0.58796932
#  0.59439982 0.92369712 0.98338208]
# Exploration noise: 0.03185724235241726
# Sub_Episode: 74 | avg. reward: -7.016896248894571
# Avg poles: [0.30042849 0.36338027 0.47824203 0.55182858 0.58187065 0.59254589
#  0.5968499  0.91344087 0.9856534 ]
# Exploration noise: 0.031392301836984916
# Sub_Episode: 75 | avg. reward: -6.853154319795559
# Avg poles: [0.30024102 0.35432987 0.46579795 0.55005956 0.56770849 0.58356439
#  0.59822807 0.91516222 0.97923123]
# Exploration noise: 0.03094559234664808
# Sub_Episode: 76 | avg. reward: -18.00791699095735
# Avg poles: [0.30013558 0.33099805 0.4588202  0.545235   0.55927656 0.57634033
#  0.59900329 0.91682587 0.97660265]
# Exploration noise: 0.030516399015171183
# Sub_Episode: 77 | avg. reward: -8.486885300425394
# Avg poles: [0.30007626 0.3178739  0.45066985 0.53160767 0.55422743 0.58497858
#  0.59943935 0.90974227 0.96293756]
# Exploration noise: 0.030104035007311538
# Sub_Episode: 78 | avg. reward: -7.093269502360459
# Avg poles: [0.3000429  0.31049157 0.44674933 0.5248311  0.55124746 0.57658894
#  0.59968463 0.91361843 0.96987201]
# Exploration noise: 0.029707840419681456
# Sub_Episode: 79 | avg. reward: -6.1427918089477
# Avg poles: [0.30002413 0.30633901 0.44786479 0.51925633 0.55003687 0.57393293
#  0.59982261 0.91428547 0.97610866]
# Exploration noise: 0.02932718122470923
# Sub_Episode: 80 | avg. reward: -5.417152005470897
# Avg poles: [0.30001357 0.30423904 0.44774869 0.51083169 0.54980199 0.57151104
#  0.59990022 0.91164603 0.97925764]
# Exploration noise: 0.02896144825600904
# Sub_Episode: 81 | avg. reward: -5.630552428911639
# Avg poles: [0.30000763 0.30339936 0.44777992 0.51587494 0.54934685 0.57247247
#  0.59994387 0.91146107 0.98123572]
# Exploration noise: 0.028610056233535977
# Sub_Episode: 82 | avg. reward: -5.669617957753673
# Avg poles: [0.30000429 0.3023662  0.44875121 0.51984321 0.54911633 0.57586734
#  0.59996843 0.9109248  0.98325214]
# Exploration noise: 0.02827244282696631
# Sub_Episode: 83 | avg. reward: -5.667119091695176
# Avg poles: [0.30000242 0.30184133 0.44964238 0.51384454 0.54898625 0.5786759
#  0.59998224 0.91091369 0.98343297]
# Exploration noise: 0.027948067755803982
# Sub_Episode: 84 | avg. reward: -5.736341823496968
# Avg poles: [0.30000136 0.30212567 0.44821144 0.50778755 0.54901865 0.58012916
#  0.59999001 0.91197313 0.98353124]
# Exploration noise: 0.027636411924773303
# Sub_Episode: 85 | avg. reward: -6.39358716000638
# Avg poles: [0.30000076 0.30208153 0.42405177 0.5043805  0.53710424 0.57163778
#  0.59999438 0.91535254 0.98251355]
# Exploration noise: 0.02733697659311425
# Sub_Episode: 86 | avg. reward: -4.6380273688283316
# Avg poles: [0.30000043 0.30211543 0.40588755 0.50246403 0.53327651 0.56553717
#  0.59999684 0.91953896 0.98305713]
# Exploration noise: 0.02704928257645091
# Sub_Episode: 87 | avg. reward: -4.614057295753717
# Avg poles: [0.30000024 0.30200773 0.40411183 0.50138602 0.54003978 0.57004752
#  0.59999822 0.91647796 0.98377378]
# Exploration noise: 0.026772869479955906
# Sub_Episode: 88 | avg. reward: -4.620774870006383
# Avg poles: [0.30000014 0.30156685 0.40362765 0.50077963 0.54346997 0.56884302
#  0.599999   0.91809712 0.98481477]
# Exploration noise: 0.026507294961583616
# Sub_Episode: 89 | avg. reward: -4.573220446087109
# Avg poles: [0.30000008 0.30131885 0.40272229 0.50043854 0.54569849 0.56775016
#  0.59999944 0.91847684 0.9847641 ]
# Exploration noise: 0.026252134024193127
# Sub_Episode: 90 | avg. reward: -4.465049691970267
# Avg poles: [0.30000004 0.30295406 0.40168559 0.50024668 0.54697953 0.56546691
#  0.59999968 0.92164202 0.98346099]
# Exploration noise: 0.026006978335428116
# Sub_Episode: 91 | avg. reward: -4.411214768473031
# Avg poles: [0.30000002 0.30216462 0.40106387 0.50013876 0.54725591 0.56905455
#  0.59999982 0.92419564 0.98289641]
# Exploration noise: 0.025771435574265315
# Sub_Episode: 92 | avg. reward: -4.504577610238486
# Avg poles: [0.30000001 0.30334577 0.40068752 0.50007805 0.54766075 0.57135732
#  0.5999999  0.92123782 0.98323983]
# Exploration noise: 0.02554512880318574
# Sub_Episode: 93 | avg. reward: -4.683158383125301
# Avg poles: [0.30000001 0.3036064  0.402075   0.5000439  0.5483363  0.57077379
#  0.59999994 0.91826601 0.98268074]
# Exploration noise: 0.02532769586496412
# Sub_Episode: 94 | avg. reward: -4.96226683291803
# Avg poles: [0.3        0.3024661  0.40203275 0.5000247  0.54884542 0.5746625
#  0.59999997 0.91791269 0.98214331]
# Exploration noise: 0.025118788803111056
# Sub_Episode: 95 | avg. reward: -4.777007875343937
# Avg poles: [0.3        0.30182468 0.40132646 0.50001389 0.54912389 0.57288636
#  0.59999998 0.91869062 0.97866275]
# Exploration noise: 0.02491807330504058
# Sub_Episode: 96 | avg. reward: -4.972255700100859
# Avg poles: [0.3        0.30169562 0.40088342 0.50000781 0.54928251 0.57310649
#  0.59999999 0.91563127 0.97961183]
# Exploration noise: 0.024725228167071928
# Sub_Episode: 97 | avg. reward: -4.511638737563671
# Avg poles: [0.3        0.30229728 0.40049692 0.5000044  0.54937766 0.56662337
#  0.59999999 0.91560693 0.98130225]
# Exploration noise: 0.02453994478040943
# Sub_Episode: 98 | avg. reward: -4.513876836261924
# Avg poles: [0.3        0.30177776 0.40071282 0.50000247 0.54927185 0.56631994
#  0.6        0.91520073 0.98265396]
# Exploration noise: 0.02436192663727789
# Sub_Episode: 99 | avg. reward: -4.533273117004982
# Avg poles: [0.3        0.30147352 0.40114595 0.50000139 0.54925217 0.5651085
#  0.6        0.91444284 0.98393146]
# Exploration noise: 0.02419088885642317
# Sub_Episode: 100 | avg. reward: -5.688003625504568
# Avg poles: [0.3        0.30126636 0.40141893 0.50000078 0.54932075 0.56398665
#  0.6        0.91360134 0.98530101]
# Exploration noise: 0.02402655772721859
# Sub_Episode: 101 | avg. reward: -5.920287486173643
# Avg poles: [0.3        0.30154591 0.40189255 0.50000044 0.54936851 0.56780303
#  0.6        0.91267129 0.98529535]
# Exploration noise: 0.023868670271647654
# Sub_Episode: 102 | avg. reward: -6.091306006012109
# Avg poles: [0.3        0.30188249 0.40137379 0.50000025 0.54890771 0.56743575
#  0.6        0.91226578 0.98621559]
# Exploration noise: 0.023716973823462044
# Sub_Episode: 103 | avg. reward: -5.861256602525117
# Avg poles: [0.3        0.3020733  0.40085207 0.50000014 0.54877853 0.56415086
#  0.6        0.91282585 0.98637715]
# Exploration noise: 0.023571225623841528
# Sub_Episode: 104 | avg. reward: -16.875115525763846
# Avg poles: [0.3        0.30229818 0.40047929 0.50000008 0.54908418 0.57340558
#  0.6        0.91312854 0.97486553]
# Exploration noise: 0.023431192432908594
# Sub_Episode: 105 | avg. reward: -5.360218663179595
# Avg poles: [0.30091274 0.3186622  0.4002696  0.50000004 0.5371336  0.58426694
#  0.6        0.90997403 0.95884713]
# Exploration noise: 0.02329665015647626
# Sub_Episode: 106 | avg. reward: -5.723045765435136
# Avg poles: [0.30051342 0.31103869 0.40023686 0.50000002 0.52132515 0.58095804
#  0.6        0.91217887 0.97011043]
# Exploration noise: 0.023167383487431605
# Sub_Episode: 107 | avg. reward: -19.701681247922764
# Avg poles: [0.3002888  0.30664677 0.40019714 0.50000001 0.5124329  0.56763265
#  0.6        0.9193793  0.97781504]
# Exploration noise: 0.023043185561181227
# Sub_Episode: 108 | avg. reward: -5.180660599342148
# Avg poles: [0.30016245 0.30628477 0.38546308 0.50000001 0.50743101 0.57579921
#  0.6        0.92607764 0.9716184 ]
# Exploration noise: 0.022923857624607222
# Sub_Episode: 109 | avg. reward: -4.464731725308716
# Avg poles: [0.30009138 0.30479184 0.39200977 0.5        0.50461744 0.56431607
#  0.6        0.92023042 0.95838777]
# Exploration noise: 0.022809208718003862
# Sub_Episode: 110 | avg. reward: -4.5141406898814
# Avg poles: [0.3000514  0.30313291 0.3955055  0.5        0.50303481 0.55827154
#  0.6        0.92256389 0.9497151 ]
# Exploration noise: 0.02269905536948607
# Sub_Episode: 111 | avg. reward: -4.828591089457663
# Avg poles: [0.30002891 0.3030565  0.37667313 0.5        0.50214458 0.55487149
#  0.6        0.91344448 0.93645463]
# Exploration noise: 0.022593221301380556
# Sub_Episode: 112 | avg. reward: -4.62639018564609
# Avg poles: [0.30001626 0.30360479 0.36635553 0.5        0.50164383 0.55295896
#  0.6        0.90820537 0.92721081]
# Exploration noise: 0.022491537148129844
# Sub_Episode: 113 | avg. reward: -4.627423773232031
# Avg poles: [0.30000915 0.30273957 0.35976373 0.5        0.50136215 0.55188317
#  0.6        0.90698767 0.92508292]
# Exploration noise: 0.022393840185257682
# Sub_Episode: 114 | avg. reward: -4.629714664530047
# Avg poles: [0.30000515 0.30258989 0.35602429 0.5        0.50120371 0.55127803
#  0.6        0.90587705 0.92421736]
# Exploration noise: 0.022299974068962145
# Sub_Episode: 115 | avg. reward: -4.62978575267287
# Avg poles: [0.30000289 0.30235286 0.35387064 0.5        0.50111459 0.55093764
#  0.6        0.90476435 0.92151796]
# Exploration noise: 0.022209788585919682
# Sub_Episode: 116 | avg. reward: -4.631835184069875
# Avg poles: [0.30000163 0.30176098 0.35330732 0.5        0.50106446 0.55072136
#  0.6        0.9032888  0.9225046 ]
# Exploration noise: 0.02212313941289974
# Sub_Episode: 117 | avg. reward: -4.633278727096132
# Avg poles: [0.30000092 0.30161469 0.35274038 0.5        0.50103626 0.5501872
#  0.6        0.90237708 0.92330339]
# Exploration noise: 0.022039887885805236
# Sub_Episode: 118 | avg. reward: -4.64687938561323
# Avg poles: [0.30000052 0.30135985 0.35197896 0.5        0.50102039 0.56615827
#  0.6        0.9014296  0.93133811]
# Exploration noise: 0.02195990077776935
# Sub_Episode: 119 | avg. reward: -4.661554872419908
# Avg poles: [0.30000029 0.30121298 0.35155067 0.5        0.50101147 0.56276978
#  0.6        0.90092076 0.93630689]
# Exploration noise: 0.021883050085953426
# Sub_Episode: 120 | avg. reward: -15.747318194050433
# Avg poles: [0.30000016 0.3011198  0.34365624 0.5        0.50100645 0.56332143
#  0.6        0.90130288 0.939534  ]
# Exploration noise: 0.021809212826704893
# Sub_Episode: 121 | avg. reward: -4.56576857968113
# Avg poles: [0.30000009 0.30106739 0.36288414 0.5        0.50100363 0.56404205
#  0.6        0.91783992 0.9422251 ]
# Exploration noise: 0.02173827083874734
# Sub_Episode: 122 | avg. reward: -4.56013684421298
# Avg poles: [0.30000005 0.30123825 0.35770889 0.5        0.50100204 0.5581174
#  0.6        0.91738983 0.94345475]
# Exploration noise: 0.0216701105940878
# Sub_Episode: 123 | avg. reward: -4.559888844627904
# Avg poles: [0.30000003 0.30128428 0.35488166 0.5        0.50100115 0.55431526
#  0.6        0.91572862 0.94331982]
# Exploration noise: 0.02160462301633867
# Sub_Episode: 124 | avg. reward: -4.561313862551648
# Avg poles: [0.30000002 0.30115991 0.35388054 0.5        0.50100065 0.55229394
#  0.6        0.91351179 0.94278073]
# Exploration noise: 0.021541703306163475
# Sub_Episode: 125 | avg. reward: -4.564801405084564
# Avg poles: [0.30000001 0.30108995 0.3526203  0.5        0.50100036 0.55150909
#  0.6        0.91331517 0.94147123]
# Exploration noise: 0.021481250773567204
# Sub_Episode: 126 | avg. reward: -4.563957071827657
# Avg poles: [0.30000001 0.3010506  0.35245507 0.5        0.5010002  0.55106761
#  0.6        0.91173354 0.94178801]
# Exploration noise: 0.021423168676762756
# Sub_Episode: 127 | avg. reward: -4.563933297405278
# Avg poles: [0.3        0.30102846 0.35182815 0.5        0.50100011 0.55081928
#  0.6        0.91213582 0.94176823]
# Exploration noise: 0.021367364067355718
# Sub_Episode: 128 | avg. reward: -4.565825728006994
# Avg poles: [0.3        0.30182456 0.35146584 0.5        0.50100006 0.55034418
#  0.6        0.91270755 0.94120883]
# Exploration noise: 0.021313747641599653
# Sub_Episode: 129 | avg. reward: -4.564911687201843
# Avg poles: [0.3        0.3026859  0.35126203 0.5        0.50100004 0.54994303
#  0.6        0.91364396 0.9417697 ]
# Exploration noise: 0.02126223359748392
# Sub_Episode: 130 | avg. reward: -4.561978820108222
# Avg poles: [0.3        0.30304252 0.35114739 0.5        0.50100002 0.55002339
#  0.6        0.91289756 0.94298566]
# Exploration noise: 0.02121273949742527
# Sub_Episode: 131 | avg. reward: -4.566468541611543
# Avg poles: [0.3        0.30291151 0.36362299 0.5        0.50100001 0.56500536
#  0.6        0.91314981 0.94346654]
# Exploration noise: 0.02116518613634354
# Sub_Episode: 132 | avg. reward: -4.572884943618126
# Avg poles: [0.3        0.30229142 0.37976765 0.5        0.50100001 0.5592076
#  0.59490107 0.91514117 0.93951773]
# Exploration noise: 0.021119497414910284
# Sub_Episode: 133 | avg. reward: -4.627189553685129
# Avg poles: [0.3        0.30190339 0.38891555 0.5        0.501      0.55539803
#  0.58488804 0.91798322 0.93340741]
# Exploration noise: 0.021075600217767523
# Sub_Episode: 134 | avg. reward: -4.616328359305462
# Avg poles: [0.3        0.30164088 0.393765   0.5        0.501      0.55325551
#  0.5729089  0.91988577 0.9311238 ]
# Exploration noise: 0.02103342429652172
# Sub_Episode: 135 | avg. reward: -4.937424854048034
# Avg poles: [0.3        0.30155673 0.39721676 0.5        0.501      0.55204775
#  0.56403538 0.92051108 0.93067584]
# Exploration noise: 0.020992902157325737
# Sub_Episode: 136 | avg. reward: -4.869667146836967
# Avg poles: [0.3        0.3024349  0.39870115 0.5        0.501      0.55264787
#  0.5662684  0.91846407 0.92847874]
# Exploration noise: 0.020953968952868902
# Sub_Episode: 137 | avg. reward: -4.619100911283886
# Avg poles: [0.3        0.30203822 0.3996899  0.5        0.501      0.55141642
#  0.57502935 0.9166432  0.93152998]
# Exploration noise: 0.020916562378602253
# Sub_Episode: 138 | avg. reward: -4.623384799524319
# Avg poles: [0.3        0.30175731 0.40008635 0.5        0.501      0.55208289
#  0.58360189 0.91697117 0.93412919]
# Exploration noise: 0.020880622573033015
# Sub_Episode: 139 | avg. reward: -4.596653792065285
# Avg poles: [0.3        0.30142599 0.40050761 0.5        0.501      0.55429618
#  0.58963522 0.91667272 0.93376658]
# Exploration noise: 0.020846092021928622
# Sub_Episode: 140 | avg. reward: -4.61527714676579
# Avg poles: [0.3        0.30123962 0.40028553 0.5        0.501      0.55394675
#  0.59359574 0.91600185 0.93260828]
# Exploration noise: 0.020812915466277088
# Sub_Episode: 141 | avg. reward: -4.614969196627725
# Avg poles: [0.3        0.30135471 0.40035224 0.5        0.501      0.55595067
#  0.59486228 0.9168201  0.93279359]
# Exploration noise: 0.020781039813856376
# Sub_Episode: 142 | avg. reward: -4.619942928564977
# Avg poles: [0.3        0.302399   0.400358   0.5        0.501      0.55896612
#  0.59711003 0.9161908  0.93309331]
# Exploration noise: 0.02075041405427126
# Sub_Episode: 143 | avg. reward: -4.62260042741593
# Avg poles: [0.3        0.30251186 0.40035009 0.5        0.501      0.55783568
#  0.59827555 0.91425505 0.93368774]
# Exploration noise: 0.020720989177321736
# Sub_Episode: 144 | avg. reward: -4.626604602909547
# Avg poles: [0.3        0.30281077 0.4003987  0.5        0.501      0.55870024
#  0.59884471 0.91314114 0.93447421]
# Exploration noise: 0.020692718094572318
# Sub_Episode: 145 | avg. reward: -4.6205203733877935
# Avg poles: [0.3        0.30204263 0.40061675 0.5        0.501      0.55939281
#  0.59935015 0.91479909 0.93430428]
# Exploration noise: 0.020665555563996723
# Sub_Episode: 146 | avg. reward: -4.981549977901908
# Avg poles: [0.3        0.30164047 0.40035576 0.5        0.501      0.57429759
#  0.59963446 0.90842049 0.93878584]
# Exploration noise: 0.02063945811757737
# Sub_Episode: 147 | avg. reward: -4.419637432381305
# Avg poles: [0.3        0.30146287 0.37876261 0.5        0.501      0.56388615
#  0.59979438 0.90483413 0.94164964]
# Exploration noise: 0.020614383991743784
# Sub_Episode: 148 | avg. reward: -4.4268886293476415
# Avg poles: [0.3        0.30143073 0.36749966 0.5        0.501      0.55777175
#  0.59988434 0.90285929 0.94333417]
# Exploration noise: 0.020590293060538646
# Sub_Episode: 149 | avg. reward: -4.433968726979246
# Avg poles: [0.3        0.30148385 0.38175166 0.5        0.501      0.57148599
#  0.59993494 0.90167994 0.94428112]
# Exploration noise: 0.020567146771404476
# Sub_Episode: 150 | avg. reward: -4.436312713234856
# Avg poles: [0.3        0.30159869 0.38976013 0.5        0.501      0.56576198
#  0.5999634  0.90318505 0.94483374]
# Exploration noise: 0.020544908083488238
# Sub_Episode: 151 | avg. reward: -4.508920080153579
# Avg poles: [0.3        0.30133676 0.39424007 0.5        0.501      0.56133007
#  0.59997942 0.90628599 0.94485476]
# Exploration noise: 0.020523541408365112
# Sub_Episode: 152 | avg. reward: -4.428674156161373
# Avg poles: [0.3        0.30314402 0.39701516 0.5        0.50908591 0.57448714
#  0.59998842 0.9038962  0.94491453]
# Exploration noise: 0.020503012553086564
# Sub_Episode: 153 | avg. reward: -5.396014890308361
# Avg poles: [0.3        0.30517561 0.39832103 0.5        0.50554832 0.57422052
#  0.59999349 0.90247336 0.93768977]
# Exploration noise: 0.020483288665461605
# Sub_Episode: 154 | avg. reward: -4.771062742483978
# Avg poles: [0.3        0.30470688 0.39905558 0.5        0.50355843 0.58346815
#  0.59999634 0.90165339 0.93135139]
# Exploration noise: 0.02046433818148364
# Sub_Episode: 155 | avg. reward: -16.381359197357956
# Avg poles: [0.3        0.3265097  0.40490834 0.5        0.5117779  0.58841126
#  0.59999794 0.90093003 0.92775775]
# Exploration noise: 0.020446130774818806
# Sub_Episode: 156 | avg. reward: -32.69084727229968
# Avg poles: [0.30007426 0.3586617  0.42468893 0.52121875 0.52828132 0.59304383
#  0.59999884 0.90052681 0.91616856]
# Exploration noise: 0.020428637308274943
# Sub_Episode: 157 | avg. reward: -6.52606531911638
# Avg poles: [0.30004177 0.33385197 0.41388752 0.51193555 0.51634574 0.57443091
#  0.59962892 0.90029633 0.90962285]
# Exploration noise: 0.020411829787173524
# Sub_Episode: 158 | avg. reward: -4.645473483827922
# Avg poles: [0.3000235  0.31990627 0.40932888 0.50671375 0.50963198 0.56396114
#  0.59979127 0.90036437 0.92303781]
# Exploration noise: 0.02039568131454997
# Sub_Episode: 159 | avg. reward: -4.638553291803382
# Avg poles: [0.30001322 0.3128564  0.3956539  0.50377648 0.50585549 0.55785779
#  0.59988259 0.90020496 0.92869166]
# Exploration noise: 0.02038016604811061
# Sub_Episode: 160 | avg. reward: -4.725667344343387
# Avg poles: [0.30000743 0.30790103 0.37623178 0.50212427 0.50373121 0.57544894
#  0.59993396 0.90013002 0.93579253]
# Exploration noise: 0.020365259158877436
# Sub_Episode: 161 | avg. reward: -4.528465227257399
# Avg poles: [0.30000418 0.304922   0.36527835 0.5011949  0.50253631 0.5851956
#  0.59996285 0.9002429  0.93935241]
# Exploration noise: 0.020350936791454437
# Sub_Episode: 162 | avg. reward: -5.129925437521047
# Avg poles: [0.30000235 0.3033948  0.36034606 0.50067213 0.50266391 0.59077492
#  0.5999791  0.90017885 0.94183529]
# Exploration noise: 0.02033717602585199
# Sub_Episode: 163 | avg. reward: -9.548841605231948
# Avg poles: [0.30000132 0.30258627 0.35896298 0.50037807 0.50258566 0.59217831
#  0.59998825 0.90013227 0.94347027]
# Exploration noise: 0.020323954840808144
# Sub_Episode: 164 | avg. reward: -56.309387123791474
# Avg poles: [0.30000074 0.30201182 0.39879167 0.52143142 0.52311068 0.5951628
#  0.59999339 0.9000744  0.94460345]
# Exploration noise: 0.020311252078548128
# Sub_Episode: 165 | avg. reward: -32.84609671866841
# Avg poles: [0.30000042 0.30165881 0.40911828 0.53327392 0.54678101 0.59684157
#  0.59999628 0.9195106  0.94517957]
# Exploration noise: 0.02029904741092572
# Sub_Episode: 166 | avg. reward: -5.094533631532372
# Avg poles: [0.30000024 0.30137058 0.37522035 0.51871658 0.54797057 0.57656714
#  0.57877916 0.91175317 0.95619524]
# Exploration noise: 0.02028732130689225
# Sub_Episode: 167 | avg. reward: -4.916910420767874
# Avg poles: [0.30000013 0.31369461 0.37779855 0.52265308 0.54863969 0.56516276
#  0.56684453 0.90661116 0.97045054]
# Exploration noise: 0.02027605500124118
# Sub_Episode: 168 | avg. reward: -4.967067878755837
# Avg poles: [0.30000007 0.32988033 0.38821117 0.53381104 0.54901608 0.5587478
#  0.5601313  0.9038346  0.97890732]
# Exploration noise: 0.02026523046457827
# Sub_Episode: 169 | avg. reward: -5.810349498619463
# Avg poles: [0.30000004 0.34055268 0.39346239 0.5401249  0.54922779 0.55513939
#  0.57757385 0.90231719 0.98357997]
# Exploration noise: 0.02025483037446927
# Sub_Episode: 170 | avg. reward: -6.47955674545984
# Avg poles: [0.30000002 0.35829107 0.3966057  0.54378901 0.54934688 0.55310966
#  0.58738529 0.90162413 0.98624013]
# Exploration noise: 0.020244838087718937
# Sub_Episode: 171 | avg. reward: -7.038789713757994
# Avg poles: [0.30000001 0.3764916  0.40551241 0.54585007 0.54941387 0.55196793
#  0.59290423 0.90122737 0.98784048]
# Exploration noise: 0.020235237613737033
# Sub_Episode: 172 | avg. reward: -7.321111077551902
# Avg poles: [0.30000001 0.37676617 0.41375607 0.54700941 0.54945155 0.55132571
#  0.59600863 0.90118359 0.98844697]
# Exploration noise: 0.0202260135889487
# Sub_Episode: 173 | avg. reward: -7.495926612408479
# Avg poles: [0.3        0.36722564 0.42967111 0.54746276 0.54947275 0.55096446
#  0.59775485 0.90084736 0.98898002]
# Exploration noise: 0.020217151252208226
# Sub_Episode: 174 | avg. reward: -7.347284182718693
# Avg poles: [0.3        0.36239813 0.43860176 0.54455949 0.54912973 0.55727652
#  0.5987371  0.90069871 0.98874632]
# Exploration noise: 0.020208636421176887
# Sub_Episode: 175 | avg. reward: -7.201345557645272
# Avg poles: [0.3        0.34619536 0.44294358 0.54387749 0.54902552 0.56881996
#  0.59928962 0.90063146 0.98924059]
# Exploration noise: 0.020200455469627038
# Sub_Episode: 176 | avg. reward: -35.4208520414935
# Avg poles: [0.3        0.32698413 0.44494279 0.54538519 0.54919983 0.57993799
#  0.59960041 0.91158194 0.98895295]
# Exploration noise: 0.020192595305636156
# Sub_Episode: 177 | avg. reward: -46.3974523556225
# Avg poles: [0.3        0.31569988 0.4444854  0.55545568 0.55839995 0.58827762
#  0.59977523 0.93445095 0.98924067]
# Exploration noise: 0.020185043350635923
# Sub_Episode: 178 | avg. reward: -4.6626358146049
# Avg poles: [0.3        0.30926868 0.3957119  0.53119382 0.54541247 0.57174991
#  0.59987357 0.93059637 0.98925384]
# Exploration noise: 0.02017778751928282
# Sub_Episode: 179 | avg. reward: -10.61809936554333
# Avg poles: [0.3        0.30565113 0.36409849 0.51754652 0.53507577 0.56245308
#  0.59992888 0.93644718 0.98945467]
# Exploration noise: 0.020170816200118045
# Sub_Episode: 180 | avg. reward: -9.57696405479378
# Avg poles: [0.3        0.30361626 0.33695512 0.50986992 0.52016762 0.55703273
#  0.57874125 0.93976708 0.98821891]
# Exploration noise: 0.02016411823698576
# Sub_Episode: 181 | avg. reward: -39.37112553388066
# Avg poles: [0.3        0.30247165 0.34309976 0.50555183 0.51178179 0.5540315
#  0.58678923 0.94181583 0.96958033]
# Exploration noise: 0.020157682911179968
# Sub_Episode: 182 | avg. reward: -5.625330087998525
# Avg poles: [0.3        0.3018278  0.34655611 0.5031229  0.53436739 0.57370522
#  0.59256894 0.94322582 0.97851393]
# Exploration noise: 0.02015149992429146
# Sub_Episode: 183 | avg. reward: -23.341766081746318
# Avg poles: [0.3        0.30146564 0.34939929 0.50175663 0.53656568 0.56355294
#  0.59270612 0.94394605 0.98293045]
# Exploration noise: 0.020145559381727303
# Sub_Episode: 184 | avg. reward: -10.887625152304443
# Avg poles: [0.3        0.31365233 0.35321654 0.51295433 0.54222445 0.55784228
#  0.57844842 0.93325767 0.9847718 ]
# Exploration noise: 0.020139851776876626
# Sub_Episode: 185 | avg. reward: -4.028589632894083
# Avg poles: [0.3        0.31949485 0.38240696 0.51626147 0.55858597 0.57584878
#  0.58787724 0.91884983 0.98513363]
# Exploration noise: 0.020134367975897228
# Sub_Episode: 186 | avg. reward: -9.719217361121949
# Avg poles: [0.3        0.31296719 0.35657022 0.50914708 0.55454844 0.56475869
#  0.57198246 0.91067647 0.95608166]
# Exploration noise: 0.02012909920309876
# Sub_Episode: 187 | avg. reward: -5.9148842322193715
# Avg poles: [0.3        0.30773155 0.3328111  0.50514523 0.55190254 0.55852051
#  0.56360928 0.90616849 0.93256859]
# Exploration noise: 0.020124037026899046
# Sub_Episode: 188 | avg. reward: -4.558081769165592
# Avg poles: [0.3        0.30478649 0.31988501 0.50289419 0.55052353 0.55501154
#  0.57953022 0.9038061  0.91941029]
# Exploration noise: 0.02011917334633108
# Sub_Episode: 189 | avg. reward: -5.228541447010151
# Avg poles: [0.3        0.3031299  0.31206032 0.50162798 0.54011898 0.57389592
#  0.58848575 0.90225097 0.93525373]
# Exploration noise: 0.020114500378079093
# Sub_Episode: 190 | avg. reward: -6.414160981459557
# Avg poles: [0.3        0.30219807 0.30765893 0.50091574 0.54832086 0.58487896
#  0.59352323 0.90176934 0.95753619]
# Exploration noise: 0.020110010644022975
# Sub_Episode: 191 | avg. reward: -4.484619565944482
# Avg poles: [0.3        0.32333016 0.347762   0.52155548 0.57005548 0.59105691
#  0.59635682 0.91235214 0.95227036]
# Exploration noise: 0.020105696959271082
# Sub_Episode: 192 | avg. reward: -4.557896761590254
# Avg poles: [0.3        0.33609445 0.36658296 0.53024159 0.58051185 0.59322164
#  0.59795071 0.92641683 0.9495265 ]
# Exploration noise: 0.020101552420662316
# Sub_Episode: 193 | avg. reward: -4.597008103468618
# Avg poles: [0.3        0.34239688 0.37964193 0.53749925 0.58720116 0.59574967
#  0.59884727 0.93691505 0.95035174]
# Exploration noise: 0.02009757039571901
# Sub_Episode: 194 | avg. reward: -4.56937031389056
# Avg poles: [0.32196091 0.36635169 0.38850432 0.54125132 0.59182595 0.59717169
#  0.59935159 0.94014977 0.9673748 ]
# Exploration noise: 0.020093744512033055
# Sub_Episode: 195 | avg. reward: -30.886383010788258
# Avg poles: [0.33469202 0.36240469 0.39916075 0.52320387 0.5824021  0.59797158
#  0.59963527 0.94928583 0.97724099]
# Exploration noise: 0.02009006864706815
# Sub_Episode: 196 | avg. reward: -31.805070788295907
# Avg poles: [0.31951426 0.34796212 0.41202792 0.51317717 0.55937167 0.59842151
#  0.59979484 0.94729188 0.98282306]
# Exploration noise: 0.020086536918361972
# Sub_Episode: 197 | avg. reward: -7.462572340953777
# Avg poles: [0.31097677 0.36151543 0.42867222 0.51945247 0.55413854 0.57745585
#  0.57866585 0.94621161 0.97206748]
# Exploration noise: 0.020083143674112482
# Sub_Episode: 198 | avg. reward: -21.102154005895336
# Avg poles: [0.32804943 0.38785243 0.45530825 0.52013995 0.57309636 0.58682592
#  0.58799954 0.957327   0.97991296]
# Exploration noise: 0.02007988348413341
# Sub_Episode: 199 | avg. reward: -26.162495891086365
# Avg poles: [0.31577781 0.37151074 0.43100465 0.51150723 0.56269599 0.59211046
#  0.59324974 0.95169833 0.98430918]
# Exploration noise: 0.020076751131164344
# Sub_Episode: 200 | avg. reward: -26.91147036773027
# Avg poles: [0.30887502 0.36242625 0.4312133  0.50659781 0.55691545 0.57390589
#  0.59620298 0.94853642 0.96731752]
# Exploration noise: 0.020076751131164344

# %%
from utils.plotting import plot_rl_results_td3_multipliers_dqnstyle, compare_mpc_rl_nominal_from_dirs

# %%
out_td3 = plot_rl_results_td3_multipliers_dqnstyle(
    y_sp=y_sp,
    steady_states=steady_states,
    nFE=nFE,
    delta_t=delta_t,
    time_in_sub_episodes=time_in_sub_episodes,
    y_rl=y_system,
    u_rl=u_rl,
    avg_rewards=avg_rewards,
    data_min=data_min,
    data_max=data_max,
    reward_fn=reward_fn,
    coef_alpha=poles_log,
    coef_delta=None,
    low_coef=LOW_POLES,
    high_coef=HIGH_POLES,
    start_episode=2,
    prefix_name="td3_multipliers_nominal",
    directory=dir_path,
    save_pdf=False
)

# %%
out_dir_cmp = compare_mpc_rl_nominal_from_dirs(
    rl_dir=out_td3,
    mpc_path_or_dir=r"C:\Users\HAMEDI\Desktop\RL_assisted_MPC_polymer\Data\mpc_results_nominal.pickle",
    reward_fn=reward_fn,
    directory=r"Result",
    prefix_name="nominal_compare_td3_multipliers",
    start_episode=2
)
