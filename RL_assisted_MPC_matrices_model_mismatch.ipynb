# %%
from Simulation.mpc import *
from Simulation.system_functions import PolymerCSTR
from utils.helpers import *

# %% [markdown]
# ## Initialize the system

# %%
# First initiate the system
# Parameters
Ad = 2.142e17           # h^-1
Ed = 14897              # K
Ap = 3.816e10           # L/(molh)
Ep = 3557               # K
At = 4.50e12            # L/(molh)
Et = 843                # K
fi = 0.6                # Coefficient
m_delta_H_r = -6.99e4   # j/mol
hA = 1.05e6             # j/(Kh)
rhocp = 1506            # j/(Kh)
rhoccpc = 4043          # j/(Kh)
Mm = 104.14             # g/mol
system_params = np.array([Ad, Ed, Ap, Ep, At, Et, fi, m_delta_H_r, hA, rhocp, rhoccpc, Mm])

# %%
# Design Parameters
CIf = 0.5888    # mol/L
CMf = 8.6981    # mol/L
Qi = 108.       # L/h
Qs = 459.       # L/h
Tf = 330.       # K
Tcf = 295.      # K
V = 3000.       # L
Vc = 3312.4     # L

system_design_params = np.array([CIf, CMf, Qi, Qs, Tf, Tcf, V, Vc])

# %%
# Steady State Inputs
Qm_ss = 378.    # L/h
Qc_ss = 471.6   # L/h

system_steady_state_inputs = np.array([Qc_ss, Qm_ss])

# %%
# Sampling time of the system
delta_t = 0.5 # 30 mins

# %%
# Initiate the CSTR for steady state values
cstr = PolymerCSTR(system_params, system_design_params, system_steady_state_inputs, delta_t)
steady_states={"ss_inputs":cstr.ss_inputs,
               "y_ss":cstr.y_ss}

# %% [markdown]
# ## Loading the system matrices, min max scaling, and min max of the states

# %%
dir_path = os.path.join(os.getcwd(), "Data")

# %%
# Defining the range of setpoints for data generation
setpoint_y = np.array([[3.2, 321],
                       [4.5, 325]])
u_min = np.array([71.6, 78])
u_max = np.array([870, 670])

system_data = load_and_prepare_system_data(steady_states=steady_states, setpoint_y=setpoint_y, u_min=u_min, u_max=u_max)

# %%
A_aug = system_data["A_aug"]
B_aug = system_data["B_aug"]
C_aug = system_data["C_aug"]

# %%
data_min = system_data["data_min"]
data_max = system_data["data_max"]

# %%
min_max_states = {'max_s': np.array([256.79686253, 256.01560603,  48.99447186, 144.79949103,
          2.82199733,   3.14014989,   2.78866348,   3.71691422,
          6.2029936 ]),
                  'min_s': np.array([ -272.28060121, -1112.33972595,   -76.63993491,  -608.60327886,
           -3.94399122,    -3.93115257,    -2.9532091 ,    -4.06547624,
          -28.25906582])}

# %%
y_sp_scaled_deviation = system_data["y_sp_scaled_deviation"]

# %%
b_min = system_data["b_min"]
b_max = system_data["b_max"]

# %%
min_max_dict = system_data["min_max_dict"]
min_max_dict["x_max"] = np.array([256.79686253, 256.01560603,  48.99447186, 144.79949103,
          2.82199733,   3.14014989,   2.78866348,   3.71691422,
          6.2029936 ])
min_max_dict["x_min"] = np.array([ -272.28060121, -1112.33972595,   -76.63993491,  -608.60327886,
           -3.94399122,    -3.93115257,    -2.9532091 ,    -4.06547624,
          -28.25906582])

# %%
# Setpoints in deviation form
inputs_number = int(B_aug.shape[1])
y_sp_scenario = np.array([[4.5, 324],
                          [3.4, 321]])

y_sp_scenario = (apply_min_max(y_sp_scenario, data_min[inputs_number:], data_max[inputs_number:])
                 - apply_min_max(steady_states["y_ss"], data_min[inputs_number:], data_max[inputs_number:]))
n_tests = 200
set_points_len = 400
TEST_CYCLE = [False, False, False, False, False]
warm_start = 5
ACTOR_FREEZE = 0 * set_points_len
warm_start_plot = warm_start * 2 * set_points_len + ACTOR_FREEZE

# %%
# Observer Gain
poles = np.array(np.array([0.44619852, 0.33547649, 0.36380595, 0.70467118, 0.3562966,
                           0.42900673, 0.4228262 , 0.96916776, 0.91230187]))
L = compute_observer_gain(A_aug, C_aug, poles)
# Out:
# The system is observable.
# C:\Users\HAMEDI\Desktop\RL_assisted_MPC_polymer\Simulation\mpc.py:123: UserWarning: Convergence was not reached after maxiter iterations.
# You asked for a tolerance of 0.001, we got 0.9999999422182038.
#   obs_gain_calc = signal.place_poles(A.T, C.T, desired_poles, method='KNV0')

# %% [markdown]
# ## Setting The hyperparameters for the TD3 Agent

# %%
from TD3Agent.agent import TD3Agent
import torch

# %%
set_points_number = int(C_aug.shape[0])
inputs_number = int(B_aug.shape[1])
STATE_DIM = int(A_aug.shape[0]) + 3 * set_points_number + inputs_number
ACTION_DIM = 3 # or Matrix A nad B (Change this to a more general format)
n_outputs = C_aug.shape[0]
a_coef, b_coef, c_coef = 1, 1, 1
ACTOR_LAYER_SIZES = [512, 512, 512]
CRITIC_LAYER_SIZES = [512, 512, 512]
HIGH_COEF = np.array([1.05, 1.2, 1.2])
LOW_COEF = np.array([0.8, 0.8, 0.8])
BUFFER_CAPACITY = 80000
ACTOR_LR = 1e-4
CRITIC_LR = 1e-4
SMOOTHING_STD = 0.1
NOISE_CLIP = 0.2
GAMMA = 0.99
TAU = 0.005
MAX_ACTION = 1.0
POLICY_DELAY = 4
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
BATCH_SIZE = 128
STD_START = 0.2
STD_END = 0.02
STD_DECAY_RATE = 0.99995
STD_DECAY_MODE = "exp"
ACTOR_FREEZE = 0

# %%
td3_agent = TD3Agent(
    state_dim=STATE_DIM,
    action_dim=ACTION_DIM,
    actor_hidden=ACTOR_LAYER_SIZES,
    critic_hidden=CRITIC_LAYER_SIZES,
    gamma=GAMMA,
    actor_lr=ACTOR_LR,
    critic_lr=CRITIC_LR,
    batch_size=BATCH_SIZE,
    policy_delay=POLICY_DELAY,
    target_policy_smoothing_noise_std=SMOOTHING_STD,
    noise_clip=NOISE_CLIP,
    max_action=MAX_ACTION,
    tau=TAU,
    std_start=STD_START,
    std_end=STD_END,
    std_decay_rate=STD_DECAY_RATE,
    std_decay_mode=STD_DECAY_MODE,
    buffer_size=BUFFER_CAPACITY,
    device=DEVICE,
    actor_freeze=ACTOR_FREEZE,
    )

# %% [markdown]
# ## MPC initialization and setpoints

# %%
# MPC parameters
n_inputs = 2
predict_h = 9
cont_h = 3
u_ss = apply_min_max(steady_states['ss_inputs'], data_min[:n_inputs], data_max[:n_inputs])
b_min = apply_min_max(np.array([71.6, 78]), data_min[:n_inputs], data_max[:n_inputs])
b_max= apply_min_max(np.array([870, 670]), data_min[:n_inputs], data_max[:n_inputs])
b1 = (b_min[0]-u_ss[0], b_max[0]-u_ss[0])
b2 = (b_min[1]-u_ss[1], b_max[1]-u_ss[1])
bnds = (b1, b2)*cont_h
cons = []
IC_opt = np.zeros(n_inputs*cont_h)
Q1_penalty = 5.
Q2_penalty = 1.
R1_penalty = 1
R2_penalty = 1

# %%
MPC_obj = MpcSolverGeneral(A_aug, B_aug, C_aug,
    Q_out=np.array([Q1_penalty, Q2_penalty]),
    R_in=np.array([R1_penalty, R2_penalty]),
    NP=predict_h,
    NC=cont_h)

# %%
def make_reward_fn_relative_QR(
    data_min, data_max, n_inputs,
    k_rel, band_floor_phys,
    Q_diag, R_diag,
    tau_frac=0.7,
    gamma_out=0.5, gamma_in=0.5,
    beta=5.0, gate="geom", lam_in=1.0,
    bonus_kind="exp", bonus_k=12.0, bonus_p=0.6, bonus_c=20.0,
):
    """
    Reward with relative tracking bands.

    data_min, data_max : arrays for [u_min..., y_min...], [u_max..., y_max...]
    n_inputs           : number of inputs (so outputs start at index n_inputs)
    k_rel              : per-output relative tolerance factors (same length as outputs)
    band_floor_phys    : per-output minimum band in physical units
    Q_diag, R_diag     : quadratic weights (same as before)
    """

    data_min = np.asarray(data_min, float)
    data_max = np.asarray(data_max, float)
    dy = np.maximum(data_max[n_inputs:] - data_min[n_inputs:], 1e-12)  # phys range for each y

    k_rel = np.asarray(k_rel, float)
    band_floor_phys = np.asarray(band_floor_phys, float)
    Q_diag = np.asarray(Q_diag, float)
    R_diag = np.asarray(R_diag, float)

    # floor in *scaled* coordinates (used if y_sp_phys is not provided)
    band_floor_scaled = band_floor_phys / np.maximum(dy, 1e-12)

    def _sigmoid(x):
        x = np.clip(x, -60.0, 60.0)
        return 1.0 / (1.0 + np.exp(-x))

    def _phi(z, kind=bonus_kind, k=bonus_k, p=bonus_p, c=bonus_c):
        z = np.clip(z, 0.0, 1.0)
        if kind == "linear":
            return 1.0 - z
        if kind == "quadratic":
            return (1.0 - z) ** 2
        if kind == "exp":
            return (np.exp(-k * z) - np.exp(-k)) / (1.0 - np.exp(-k))
        if kind == "power":
            return 1.0 - np.power(z, p)
        if kind == "log":
            return np.log1p(c * (1.0 - z)) / np.log1p(c)
        raise ValueError("unknown bonus kind")

    def reward_fn(e_scaled, du_scaled, y_sp_phys=None):
        """
        e_scaled : output error in scaled deviation space  (same as before)
        du_scaled: input move in scaled deviation space    (same as before)
        y_sp_phys: current setpoint in *physical* units (array len = n_outputs)
        """

        e_scaled = np.asarray(e_scaled, float)
        du_scaled = np.asarray(du_scaled, float)

        # ----- dynamic band based on setpoint -----
        if y_sp_phys is None:
            # fallback: just use the floor
            band_scaled = band_floor_scaled
        else:
            y_sp_phys_arr = np.asarray(y_sp_phys, float)
            # band_phys_i = max(k_rel_i * |y_sp_i|, band_floor_phys_i)
            band_phys = np.maximum(k_rel * np.abs(y_sp_phys_arr), band_floor_phys)
            band_scaled = band_phys / np.maximum(dy, 1e-12)

        tau_scaled = tau_frac * band_scaled

        # ----- inside/outside gate -----
        abs_e = np.abs(e_scaled)
        s_i = _sigmoid((band_scaled - abs_e) / np.maximum(tau_scaled, 1e-12))

        if gate == "prod":
            w_in = float(np.prod(s_i, dtype=np.float64))
        elif gate == "mean":
            w_in = float(np.mean(s_i))
        elif gate == "geom":
            w_in = float(np.prod(s_i, dtype=np.float64) ** (1.0 / len(s_i)))
        else:
            raise ValueError("gate must be 'prod'|'mean'|'geom'")

        # ----- core quadratic costs -----
        err_quad = np.sum(Q_diag * (e_scaled ** 2))
        err_eff = (1.0 - w_in) * err_quad + w_in * (lam_in * err_quad)
        move = np.sum(R_diag * (du_scaled ** 2))

        # ----- linear penalties around band edge -----
        slope_at_edge = 2.0 * Q_diag * band_scaled

        overflow = np.maximum(abs_e - band_scaled, 0.0)
        lin_out = (1.0 - w_in) * np.sum(gamma_out * slope_at_edge * overflow)

        inside_mag = np.minimum(abs_e, band_scaled)
        lin_in = w_in * np.sum(gamma_in * slope_at_edge * inside_mag)

        # ----- bonus near zero error -----
        qb2 = Q_diag * (band_scaled ** 2)
        z = abs_e / np.maximum(band_scaled, 1e-12)
        phi = _phi(z)
        bonus = w_in * beta * np.sum(qb2 * phi)

        # ----- total reward -----
        return (-(err_eff + move + lin_out + lin_in) + bonus) * 0.01

    params = dict(
        k_rel=k_rel,
        band_floor_phys=band_floor_phys,
        band_floor_scaled=band_floor_scaled,
        Q_diag=Q_diag,
        R_diag=R_diag,
        tau_frac=tau_frac,
        gamma_out=gamma_out,
        gamma_in=gamma_in,
        beta=beta,
        gate=gate,
        lam_in=lam_in,
        bonus_kind=bonus_kind,
        bonus_k=bonus_k,
        bonus_p=bonus_p,
        bonus_c=bonus_c,
    )
    return params, reward_fn

# %%
n_inputs = 2

dy = data_max[n_inputs:] - data_min[n_inputs:]
y_sp_nom = 0.5 * (data_min[n_inputs:] + data_max[n_inputs:])

k_rel = np.array([0.003, 0.0003])
band_floor_phys = np.array([0.006, 0.07])

band_phys = np.maximum(k_rel * np.abs(y_sp_nom), band_floor_phys)

scale_factor = 1.0  # use 2.0 for [-1, 1] scaling, 1.0 for [0, 1]
band_scaled = scale_factor * band_phys / dy

q0 = 1.4
Q_diag = q0 / np.maximum(band_scaled ** 2, 1e-12)

print("dy:", dy)
print("y_sp_nom:", y_sp_nom)
print("band_phys:", band_phys)
print("band_scaled:", band_scaled)
print("Q_diag:", Q_diag)
# Out:
# dy: [0.22165278 0.78153727]
# y_sp_nom: [  3.83915067 323.21371982]
# band_phys: [0.01151745 0.09696412]
# band_scaled: [0.05196169 0.12406845]
# Q_diag: [518.51529284  90.95055189]

# %%
Q_diag = np.array([518., 90.])          # rounded from the band-based calculation
R_diag = np.array([90., 90.])          # move cost for du_scaled ~ 0.02

n_inputs = 2

print("Band scaled are:")

params, reward_fn = make_reward_fn_relative_QR(
    data_min, data_max, n_inputs,
    k_rel, band_floor_phys,
    Q_diag, R_diag,
    tau_frac=0.7,
    gamma_out=0.5, gamma_in=0.5,
    beta=7.0, gate="geom", lam_in=1.0,
    bonus_kind="exp", bonus_k=12.0, bonus_p=0.6, bonus_c=20.0,
)
print(params)
# Out:
# Band scaled are:
# {'k_rel': array([0.003 , 0.0003]), 'band_floor_phys': array([0.006, 0.07 ]), 'band_floor_scaled': array([0.02706937, 0.08956707]), 'Q_diag': array([518.,  90.]), 'R_diag': array([90., 90.]), 'tau_frac': 0.7, 'gamma_out': 0.5, 'gamma_in': 0.5, 'beta': 7.0, 'gate': 'geom', 'lam_in': 1.0, 'bonus_kind': 'exp', 'bonus_k': 12.0, 'bonus_p': 0.6, 'bonus_c': 20.0}

# %%
nominal_qs = 459
nominal_qi = 108
nominal_hA = 1.05e6
qi_change = 0.85
qs_change = 1.3
ha_change = 0.85

# %%
import warnings
def compute_observer_gain(A, C, desired_poles):
    """
    Compute an observer gain L for the given MPC system using the desired poles.
    Also performs an observability check.

    Parameters:
    -----------
    A, C : np.ndarray
        System Matrices
    desired_poles : np.ndarray
        A vector of desired observer poles.

    Returns:
    --------
    L : np.ndarray
        The observer gain matrix.
    """
    # Compute the observer gain using pole placement
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", UserWarning)
        obs_gain_calc = signal.place_poles(A.T, C.T, desired_poles, "KNV0")
    L = np.squeeze(obs_gain_calc.gain_matrix).T

    # Check observability
    observability_matrix = control.obsv(A, C)
    rank = np.linalg.matrix_rank(observability_matrix)
    if rank == A.shape[0]:
        # print("The system is observable.")
        pass
    else:
        # print("The system is not observable.")
        pass
    return L

# %%
def generate_disturbances_ramp(
    nFE,
    seg_len=400,
    seed=0,
    qi_nom=108.0,
    qs_nom=459.0,
    cmf_nom=8.6981,
    qi_rel=(0.9, 1.1),
    qs_rel=(0.9, 1.1),
    cmf_rel=(0.90, 1.10),
    step_std=0.03,
    ramp_kind="cosine",
):
    rng = np.random.default_rng(seed)
    nseg = int(np.ceil(nFE / seg_len))

    def ramp(v0, v1, n):
        if n <= 1:
            return np.array([v1], dtype=float)
        t = np.linspace(0.0, 1.0, n, dtype=float)
        if ramp_kind == "linear":
            s = t
        elif ramp_kind == "cosine":
            s = 0.5 * (1.0 - np.cos(np.pi * t))  # smooth start/end slope
        else:
            raise ValueError("ramp_kind must be 'linear' or 'cosine'")
        return v0 + (v1 - v0) * s

    def make_series(nom, rel_lo, rel_hi):
        mult_targets = np.ones(nseg + 1, dtype=float)
        for k in range(1, nseg + 1):
            mult_targets[k] = mult_targets[k - 1] + rng.normal(0.0, step_std)
            mult_targets[k] = np.clip(mult_targets[k], rel_lo, rel_hi)

        out = np.empty(nFE, dtype=float)
        idx = 0
        for k in range(nseg):
            n = min(seg_len, nFE - idx)
            m0 = mult_targets[k]
            m1 = mult_targets[k + 1]
            out[idx:idx + n] = nom * ramp(m0, m1, n)
            idx += n

        return out

    qi = make_series(qi_nom, qi_rel[0], qi_rel[1])
    qs = make_series(qs_nom, qs_rel[0], qs_rel[1])
    cmf = make_series(cmf_nom, cmf_rel[0], cmf_rel[1])

    return qi, qs, cmf

# %%
def generate_setpoints_training_rl_gradually(y_sp_scenario, n_tests, set_points_len, warm_start, test_cycle,
                                             nominal_qi, nominal_qs, nominal_ha,
                                             qi_change, qs_change, ha_change):
    # For each scenario, create a block of size (set_points_len, n_outputs)
    blocks = [np.full((set_points_len, y_sp_scenario.shape[1]), scenario)
              for scenario in y_sp_scenario]

    # Concatenate the blocks to form one cycle
    cycle = np.concatenate(blocks, axis=0)
    # Repeat the cycle 'repetitions' times
    y_sp = np.concatenate([cycle] * n_tests, axis=0)

    # Test train scenario
    test_cycle = test_cycle * int(n_tests / len(test_cycle))
    # Try making everything trainable but te end cycle should be only for testing
    test_cycle[-1] = True

    time_in_sub_episodes = set_points_len * len(y_sp_scenario)

    nFE = int(y_sp.shape[0])
    idxs_setpoints = np.arange(time_in_sub_episodes - 1, nFE, time_in_sub_episodes)
    idxs_tests = np.arange(0, nFE, time_in_sub_episodes)
    sub_episodes_changes = np.arange(1, len(idxs_setpoints) + 1)
    sub_episodes_changes_dict = {}
    test_train_dict = {}
    for i in range(len(idxs_setpoints)):
        sub_episodes_changes_dict[idxs_setpoints[i]] = sub_episodes_changes[i]
    for i in range(len(idxs_tests)):
        test_train_dict[idxs_tests[i]] = test_cycle[i]
    warm_start = list(test_train_dict.keys())[warm_start]

    qi, qs, cmf = generate_disturbances_ramp(nFE, seg_len=set_points_len * 40, qi_nom=nominal_qi, qs_nom=nominal_qs, cmf_rel=(0.90, 1.10))
    ha = np.linspace(nominal_ha, nominal_ha * ha_change, int(nFE / 2))
    ha = np.hstack((ha, np.tile(nominal_ha * ha_change, int(nFE/ 2))))

    done_flags = np.arange(set_points_len - 1, nFE, set_points_len)

    return y_sp, nFE, sub_episodes_changes_dict, time_in_sub_episodes, test_train_dict, warm_start, qi, qs, ha, done_flags, cmf

# %%
def run_rl_train_disturbance_gradually(
        system, y_sp_scenario, n_tests, set_points_len,
        steady_states, min_max_dict, agent, MPC_obj,
        poles,
        data_min, data_max, warm_start,
        test_cycle,
        high_coef, low_coef,
        reward_fn,
        nominal_qi, nominal_qs, nominal_ha,
        qi_change, qs_change, ha_change,
        mode="disturb"
):

    # --- setpoints generation ---
    y_sp, nFE, sub_episodes_changes_dict, time_in_sub_episodes, test_train_dict, WARM_START, qi, qs, ha, done_flags, cmf = \
        generate_setpoints_training_rl_gradually(
            y_sp_scenario, n_tests, set_points_len, warm_start, TEST_CYCLE,
            nominal_qi, nominal_qs, nominal_hA,
            qi_change, qs_change, ha_change
        )

    # inputs and outputs of the system dimensions
    n_inputs = B_aug.shape[1]
    n_outputs = C_aug.shape[0]
    n_states = A_aug.shape[0]

    # Scaled steady states inputs and outputs
    ss_scaled_inputs = apply_min_max(steady_states["ss_inputs"], data_min[:n_inputs], data_max[:n_inputs])
    y_ss_scaled = apply_min_max(steady_states["y_ss"], data_min[n_inputs:], data_max[n_inputs:])

    # Logs
    y_system = np.zeros((nFE + 1, n_outputs))
    y_system[0, :] = system.current_output
    u_mpc = np.zeros((nFE, n_inputs))
    rewards = np.zeros(nFE)
    avg_rewards = []
    yhat = np.zeros((n_outputs, nFE))
    xhatdhat = np.zeros((n_states, nFE + 1))

    # multipliers
    multiplier_coefs_alpha = np.zeros((nFE + 1, 1))
    multiplier_coefs_delta = np.zeros((nFE + 1, n_inputs))

    # Keep immutable baselines for model scaling (avoid cumulative drift)
    A_base = MPC_obj.A.copy()
    B_base = MPC_obj.B.copy()

    # ----- helper ------
    def map_to_bounds(a, low, high):
        return low + ((a + 1.0) / 2.0) * (high - low)

    def map_from_bounds(x, low, high):
        x = np.asarray(x, float)
        return 2.0 * (x - low) / (high - low) - 1.0

    test = False


    # we need to recalculate the observer gain
    # # Observer Gain
    L = compute_observer_gain(MPC_obj.A, MPC_obj.C, poles)

    for i in range(nFE):
        # train/test phase
        if i in test_train_dict:
            test = test_train_dict[i]

        # Current scaled input & deviation
        scaled_current_input = apply_min_max(system.current_input, data_min[:n_inputs], data_max[:n_inputs])
        scaled_current_input_dev = scaled_current_input - ss_scaled_inputs

        # measured output at time i in scaled deviation space
        y_prev_scaled = apply_min_max(y_system[i, :], data_min[n_inputs:], data_max[n_inputs:]) - y_ss_scaled

        # predicted output at time i from current observer state
        yhat_pred = np.dot(MPC_obj.C, xhatdhat[:, i])
        # innovation (prediction mismatch) and tracking error
        innov = y_prev_scaled - yhat_pred
        innov = np.clip(innov, -2.0, 2.0).astype(np.float32)
        e_track = y_prev_scaled - y_sp[i, :]
        e_track = np.clip(e_track, -2.0, 2.0).astype(np.float32)

        # ---- RL state (scaled) ----
        current_rl_state = apply_rl_scaled(min_max_dict, xhatdhat[:, i], y_sp[i, :], scaled_current_input_dev).astype(np.float32)
        current_rl_state = np.concatenate([current_rl_state, innov, e_track], axis=0)

        # ---- TD3 action ----
        if i > WARM_START:
            if not test:
                action = agent.take_action(current_rl_state, explore=(not test))
            else:
                action = agent.act_eval(current_rl_state)
        else:
            action = map_from_bounds(np.array([1., 1., 1.]), low_coef, high_coef)
        # Map to bounds
        action_mapped = map_to_bounds(action, low_coef, high_coef)
        alpha, delta = action_mapped[:-n_inputs], action_mapped[-n_inputs:]

        multiplier_coefs_alpha[i] = alpha
        multiplier_coefs_delta[i] = delta

        # ---- apply model scaling (from baselines each step) ----
        A_change = A_base.copy()
        B_change = B_base.copy()
        n_phys = n_states - n_outputs
        A_change[:n_phys, :n_phys] *= alpha
        B_change[:n_phys, :] *= delta.reshape(1, -1)

        MPC_obj.A = A_change
        MPC_obj.B = B_change

        # Solve MPC for current y_sp and model state x0_model
        sol = spo.minimize(
            lambda x: MPC_obj.mpc_opt_fun(x, y_sp[i, :], scaled_current_input_dev, xhatdhat[:, i]),
            IC_opt, bounds=bnds, constraints=cons
        )

        # Take first move (scaled deviation) and map to plant input
        u_mpc[i, :] = sol.x[:n_inputs] + ss_scaled_inputs
        u_plant = reverse_min_max(u_mpc[i, :], data_min[:n_inputs], data_max[:n_inputs])

        # delta u cost variables
        delta_u = u_mpc[i, :] - scaled_current_input

        # Apply to plant and step
        system.current_input = u_plant
        system.step()
        if mode == "disturb":
            # disturbances
            system.hA = ha[i]
            system.Qs = qs[i]
            system.Qi = qi[i]
            system.CMf = cmf[i]

        # Record output
        y_system[i+1, :] = system.current_output

        # ----- Observer & model roll -----
        y_current_scaled = apply_min_max(y_system[i+1, :], data_min[n_inputs:], data_max[n_inputs:]) - y_ss_scaled

        # Calculate Delta y in deviation form
        delta_y = y_current_scaled - y_sp[i, :]

        # Calculate the next state in deviation form
        yhat[:, i] = yhat_pred
        xhatdhat[:, i+1] = np.dot(MPC_obj.A, xhatdhat[:, i]) + np.dot(MPC_obj.B, (u_mpc[i, :] - ss_scaled_inputs)) + np.dot(L, (y_prev_scaled - yhat[:, i])).T

        # Next state calculation
        yhat_next_pred = MPC_obj.C @ xhatdhat[:, i + 1]
        innov_next = y_current_scaled - yhat_next_pred
        innov_next = np.clip(innov_next, -2.0, 2.0).astype(np.float32)
        e_track_next = y_current_scaled - y_sp[i, :]
        e_track_next = np.clip(e_track_next, -2.0, 2.0).astype(np.float32)

        # y_sp in physical band
        y_sp_phys = reverse_min_max(y_sp[i, :] + y_ss_scaled, data_min[n_inputs:], data_max[n_inputs:])

        # Reward Calculation
        reward = reward_fn(delta_y, delta_u, y_sp_phys)

        # Record rewards
        rewards[i] = reward

        # ----- Next state for TD3 -----
        next_u_dev = u_mpc[i, :] - ss_scaled_inputs
        next_rl_state = apply_rl_scaled(min_max_dict, xhatdhat[:, i + 1], y_sp[i, :], next_u_dev).astype(np.float32)
        next_rl_state = np.concatenate([next_rl_state, innov_next, e_track_next], axis=0)

        # Episode boundary (treat each setpoint block as an episode end)
        if i in done_flags:
            done = 1.0
        else:
            done = 0.0

        # Buffer + train (skip if in test phase)
        if not test:
            agent.push(current_rl_state,
                       action.astype(np.float32),
                       float(reward),
                       next_rl_state,
                       float(done))
            if i >= warm_start:
                _ = agent.train_step()  # returns loss or None

        # diagnostics at sub-episode boundary
        if i in sub_episodes_changes_dict:
            avg_rewards.append(np.mean(rewards[max(0, i - time_in_sub_episodes + 1): i + 1]))
            print('Sub_Episode:', sub_episodes_changes_dict[i], '| avg. reward:', avg_rewards[-1])
            print('Avg scalers -> A:', np.mean(multiplier_coefs_alpha[max(0, i - time_in_sub_episodes + 1): i+1, 0]),
                  ' B:', np.mean(multiplier_coefs_delta[max(0, i - time_in_sub_episodes + 1): i+1, :], axis=0))
            if hasattr(agent, "_expl_sigma"):
                print('Exploration noise:', agent._expl_sigma)

    # Reverse scaling for RL inputs
    u_rl = reverse_min_max(u_mpc, data_min[:n_inputs], data_max[:n_inputs])

    return (y_system, u_rl, avg_rewards, rewards, xhatdhat, nFE, time_in_sub_episodes,
            y_sp, yhat, multiplier_coefs_alpha, multiplier_coefs_delta)

# %%
cstr = PolymerCSTR(system_params, system_design_params, system_steady_state_inputs, delta_t)
(y_system, u_rl, avg_rewards, rewards, xhatdhat, nFE, time_in_sub_episodes,
            y_sp, yhat, multiplier_coefs_alpha, multiplier_coefs_delta) = run_rl_train_disturbance_gradually(
        cstr, y_sp_scenario, n_tests, set_points_len,
        steady_states, min_max_dict, td3_agent, MPC_obj,
        poles,
        data_min, data_max, warm_start,
        TEST_CYCLE,
        HIGH_COEF, LOW_COEF,
        reward_fn,
        nominal_qi, nominal_qs, nominal_hA,
        qi_change, qs_change, ha_change,
        mode="disturb"
)
# Out:
# Sub_Episode: 1 | avg. reward: -3.371345753552239
# Avg scalers -> A: 1.0  B: [1. 1.]
# Sub_Episode: 2 | avg. reward: -4.429850192525055
# Avg scalers -> A: 1.0  B: [1. 1.]
# Sub_Episode: 3 | avg. reward: -4.434092245619343
# Avg scalers -> A: 1.0  B: [1. 1.]
# Sub_Episode: 4 | avg. reward: -4.440875862294172
# Avg scalers -> A: 1.0  B: [1. 1.]
# Sub_Episode: 5 | avg. reward: -4.448471498584553
# Avg scalers -> A: 1.0  B: [1. 1.]
# Sub_Episode: 6 | avg. reward: -5.2734734946375985
# Avg scalers -> A: 0.9934971962254322  B: [0.96921151 0.96201821]
# Exploration noise: 0.19295057362832285
# Sub_Episode: 7 | avg. reward: -4.4492196931036165
# Avg scalers -> A: 0.974935297004933  B: [0.97734846 0.96257257]
# Exploration noise: 0.18616891846288888
# Sub_Episode: 8 | avg. reward: -5.062467190585822
# Avg scalers -> A: 0.9635582784318174  B: [0.98375416 0.9899539 ]
# Exploration noise: 0.17965318231592373
# Sub_Episode: 9 | avg. reward: -4.559984055577582
# Avg scalers -> A: 0.9658227527424514  B: [0.98641088 0.99329435]
# Exploration noise: 0.17339293809807255
# Sub_Episode: 10 | avg. reward: -4.946461736247929
# Avg scalers -> A: 0.9787239790635056  B: [0.97679436 1.01200353]
# Exploration noise: 0.16737816758202073
# Sub_Episode: 11 | avg. reward: -4.853978659692139
# Avg scalers -> A: 0.9787320524398104  B: [0.97416103 1.02558801]
# Exploration noise: 0.1615992453703911
# Sub_Episode: 12 | avg. reward: -4.724491107353541
# Avg scalers -> A: 0.9775951244153964  B: [0.96818962 1.02150705]
# Exploration noise: 0.1560469234922843
# Sub_Episode: 13 | avg. reward: -4.662145945804313
# Avg scalers -> A: 0.9695897746705213  B: [0.98944739 1.00940536]
# Exploration noise: 0.1507123166038122
# Sub_Episode: 14 | avg. reward: -4.174384221971689
# Avg scalers -> A: 0.9717102875210076  B: [1.00282142 0.99242067]
# Exploration noise: 0.14558688776894124
# Sub_Episode: 15 | avg. reward: -4.139465475084486
# Avg scalers -> A: 0.9667826419114395  B: [1.01607462 0.99182057]
# Exploration noise: 0.14066243479788998
# Sub_Episode: 16 | avg. reward: -4.139244486000855
# Avg scalers -> A: 0.9682811163348337  B: [1.02106465 0.99579916]
# Exploration noise: 0.1359310771212194
# Sub_Episode: 17 | avg. reward: -4.155103900641003
# Avg scalers -> A: 0.9687522239287236  B: [1.01931312 0.99763248]
# Exploration noise: 0.13138524317860975
# Sub_Episode: 18 | avg. reward: -4.187578714937467
# Avg scalers -> A: 0.9689527430432159  B: [1.01471481 0.99564475]
# Exploration noise: 0.12701765830214287
# Sub_Episode: 19 | avg. reward: -4.206476622820947
# Avg scalers -> A: 0.9800597576410078  B: [1.00800672 0.98042014]
# Exploration noise: 0.12282133307469925
# Sub_Episode: 20 | avg. reward: -4.165799061526876
# Avg scalers -> A: 0.9831671816631444  B: [1.01649661 0.96770156]
# Exploration noise: 0.11878955214484031
# Sub_Episode: 21 | avg. reward: -4.211401661515941
# Avg scalers -> A: 0.9848824274270018  B: [1.00599124 0.95462856]
# Exploration noise: 0.1149158634802758
# Sub_Episode: 22 | avg. reward: -4.228096165656833
# Avg scalers -> A: 0.9844212814941062  B: [1.00038629 0.95521094]
# Exploration noise: 0.1111940680427195
# Sub_Episode: 23 | avg. reward: -4.174640427894235
# Avg scalers -> A: 0.9843653088274283  B: [1.00256746 0.95824201]
# Exploration noise: 0.10761820986760927
# Sub_Episode: 24 | avg. reward: -4.2083705789467984
# Avg scalers -> A: 0.9850072344526772  B: [1.00039523 0.96282463]
# Exploration noise: 0.10418256653281642
# Sub_Episode: 25 | avg. reward: -4.198633581133658
# Avg scalers -> A: 0.9850294397906151  B: [0.9997092  0.96385026]
# Exploration noise: 0.10088164000109158
# Sub_Episode: 26 | avg. reward: -4.206068900735934
# Avg scalers -> A: 0.9859972120312028  B: [0.99928797 0.96132933]
# Exploration noise: 0.09771014782159211
# Sub_Episode: 27 | avg. reward: -4.195635541751864
# Avg scalers -> A: 0.9868480916161937  B: [1.00068429 0.96049915]
# Exploration noise: 0.09466301467641107
# Sub_Episode: 28 | avg. reward: -4.203491375826431
# Avg scalers -> A: 0.9837082793570022  B: [1.00164455 0.94892089]
# Exploration noise: 0.09173536425857959
# Sub_Episode: 29 | avg. reward: -4.270418581010149
# Avg scalers -> A: 0.9755965990439117  B: [0.983714   0.93554557]
# Exploration noise: 0.08892251146854516
# Sub_Episode: 30 | avg. reward: -4.216821819111212
# Avg scalers -> A: 0.9800691829221109  B: [0.97446457 0.9249737 ]
# Exploration noise: 0.08621995491663792
# Sub_Episode: 31 | avg. reward: -4.2143955971234695
# Avg scalers -> A: 0.9818090775379724  B: [0.9746631  0.92369972]
# Exploration noise: 0.08362336971952657
# Sub_Episode: 32 | avg. reward: -4.201918027905806
# Avg scalers -> A: 0.9829724239270398  B: [0.97506255 0.92183619]
# Exploration noise: 0.08112860057913625
# Sub_Episode: 33 | avg. reward: -4.1901671046660445
# Avg scalers -> A: 0.9819105823822687  B: [0.97698797 0.92421584]
# Exploration noise: 0.07873165513295267
# Sub_Episode: 34 | avg. reward: -4.178339670207582
# Avg scalers -> A: 0.9792010575909498  B: [0.97058456 0.9229932 ]
# Exploration noise: 0.0764286975650707
# Sub_Episode: 35 | avg. reward: -4.230337015841957
# Avg scalers -> A: 0.9777423912554295  B: [0.97003832 0.92262593]
# Exploration noise: 0.07421604246776374
# Sub_Episode: 36 | avg. reward: -4.286591372230276
# Avg scalers -> A: 0.978315983954668  B: [0.97115247 0.92427434]
# Exploration noise: 0.0720901489437501
# Sub_Episode: 37 | avg. reward: -4.290506592632167
# Avg scalers -> A: 0.9768187114821649  B: [0.97829429 0.92154143]
# Exploration noise: 0.07004761493971857
# Sub_Episode: 38 | avg. reward: -4.297817283625086
# Avg scalers -> A: 0.9812568278527164  B: [0.97896619 0.92234917]
# Exploration noise: 0.0680851718020451
# Sub_Episode: 39 | avg. reward: -4.319259270908529
# Avg scalers -> A: 0.9801894214706244  B: [0.97531768 0.92213493]
# Exploration noise: 0.06619967904598803
# Sub_Episode: 40 | avg. reward: -4.282983491376368
# Avg scalers -> A: 0.980310284612494  B: [0.97742319 0.92090047]
# Exploration noise: 0.0643881193299912
# Sub_Episode: 41 | avg. reward: -4.2771013550275345
# Avg scalers -> A: 0.9791438692883103  B: [0.98322255 0.92154775]
# Exploration noise: 0.06264759362705223
# Sub_Episode: 42 | avg. reward: -4.334490447435295
# Avg scalers -> A: 0.9770496536868224  B: [0.98459814 0.92154512]
# Exploration noise: 0.060975316585428915
# Sub_Episode: 43 | avg. reward: -4.380378649391118
# Avg scalers -> A: 0.9813580619178436  B: [0.98142251 0.92805035]
# Exploration noise: 0.05936861207125922
# Sub_Episode: 44 | avg. reward: -4.453798119360703
# Avg scalers -> A: 0.9817632207534425  B: [0.97178958 0.92680832]
# Exploration noise: 0.057824908885962006
# Sub_Episode: 45 | avg. reward: -4.504739353547775
# Avg scalers -> A: 0.9794874419506588  B: [0.97175686 0.93101085]
# Exploration noise: 0.05634173665156507
# Sub_Episode: 46 | avg. reward: -4.501909920696001
# Avg scalers -> A: 0.9776419918949375  B: [0.97768295 0.92684985]
# Exploration noise: 0.05491672185737553
# Sub_Episode: 47 | avg. reward: -4.474059242329043
# Avg scalers -> A: 0.9830546571244153  B: [0.98352713 0.92365782]
# Exploration noise: 0.053547584061666514
# Sub_Episode: 48 | avg. reward: -4.528290619823248
# Avg scalers -> A: 0.9815139559720243  B: [1.00161711 0.91013549]
# Exploration noise: 0.05223213224230133
# Sub_Episode: 49 | avg. reward: -4.634030978838447
# Avg scalers -> A: 0.9793926035589325  B: [1.01440939 0.90220828]
# Exploration noise: 0.05096826129045526
# Sub_Episode: 50 | avg. reward: -4.6772055765899685
# Avg scalers -> A: 0.9782327349430348  B: [1.01477447 0.90946286]
# Exploration noise: 0.04975394864182388
# Sub_Episode: 51 | avg. reward: -4.744171903639163
# Avg scalers -> A: 0.9721023492997231  B: [1.00618323 0.93358497]
# Exploration noise: 0.048587251039926845
# Sub_Episode: 52 | avg. reward: -4.851882252945337
# Avg scalers -> A: 0.974101153693984  B: [0.98646298 0.94316679]
# Exploration noise: 0.047466301426327365
# Sub_Episode: 53 | avg. reward: -4.937599041684374
# Avg scalers -> A: 0.9716584083391138  B: [0.99214999 0.93691586]
# Exploration noise: 0.04638930595279102
# Sub_Episode: 54 | avg. reward: -4.87414024286057
# Avg scalers -> A: 0.9705319131082629  B: [0.99301458 0.93496297]
# Exploration noise: 0.04535454111060228
# Sub_Episode: 55 | avg. reward: -5.031674589707316
# Avg scalers -> A: 0.9716715911125671  B: [0.98441436 0.94165212]
# Exploration noise: 0.044360350972445
# Sub_Episode: 56 | avg. reward: -4.9998002346300146
# Avg scalers -> A: 0.9751652802192369  B: [0.98400421 0.93901852]
# Exploration noise: 0.04340514454243284
# Sub_Episode: 57 | avg. reward: -5.058818714608472
# Avg scalers -> A: 0.9741590634363523  B: [0.98501408 0.94069841]
# Exploration noise: 0.04248739321004914
# Sub_Episode: 58 | avg. reward: -5.103674292094389
# Avg scalers -> A: 0.9752454876175696  B: [0.98222375 0.94052007]
# Exploration noise: 0.04160562830392165
# Sub_Episode: 59 | avg. reward: -5.135988888579634
# Avg scalers -> A: 0.9735447211356467  B: [0.98978715 0.93936372]
# Exploration noise: 0.04075843874151744
# Sub_Episode: 60 | avg. reward: -5.110606161205594
# Avg scalers -> A: 0.9758475337959767  B: [0.98550802 0.94310078]
# Exploration noise: 0.0399444687709969
# Sub_Episode: 61 | avg. reward: -5.1156839568415124
# Avg scalers -> A: 0.9737187780379603  B: [0.98731177 0.94346654]
# Exploration noise: 0.03916241580161307
# Sub_Episode: 62 | avg. reward: -5.070384972773666
# Avg scalers -> A: 0.975232823307612  B: [0.9868522  0.94638686]
# Exploration noise: 0.03841102831918426
# Sub_Episode: 63 | avg. reward: -5.0937631528585605
# Avg scalers -> A: 0.9693589954882791  B: [0.98985737 0.94691565]
# Exploration noise: 0.03768910388330428
# Sub_Episode: 64 | avg. reward: -5.104283897807625
# Avg scalers -> A: 0.9656427214293001  B: [0.99582709 0.94681931]
# Exploration noise: 0.03699548720308494
# Sub_Episode: 65 | avg. reward: -4.922929987829921
# Avg scalers -> A: 0.9732837973961869  B: [0.99251561 0.94807899]
# Exploration noise: 0.036329068288351765
# Sub_Episode: 66 | avg. reward: -4.978308406310471
# Avg scalers -> A: 0.9738708948776691  B: [0.99338425 0.94841769]
# Exploration noise: 0.035688780673334045
# Sub_Episode: 67 | avg. reward: -4.962627697611439
# Avg scalers -> A: 0.9739007463059361  B: [0.99824241 0.94827356]
# Exploration noise: 0.03507359971000677
# Sub_Episode: 68 | avg. reward: -5.038457958627819
# Avg scalers -> A: 0.9695228872865213  B: [0.9981572  0.94792969]
# Exploration noise: 0.03448254092835316
# Sub_Episode: 69 | avg. reward: -5.14011086251861
# Avg scalers -> A: 0.9672292925309484  B: [0.9900415  0.94568339]
# Exploration noise: 0.0339146584609238
# Sub_Episode: 70 | avg. reward: -5.054534067709712
# Avg scalers -> A: 0.9720939590569705  B: [0.98630373 0.94959027]
# Exploration noise: 0.0333690435291713
# Sub_Episode: 71 | avg. reward: -5.108203572620396
# Avg scalers -> A: 0.9696494755533643  B: [0.98851335 0.95476333]
# Exploration noise: 0.032844822989137955
# Sub_Episode: 72 | avg. reward: -5.057019310992271
# Avg scalers -> A: 0.9691842102893264  B: [1.00143275 0.95400941]
# Exploration noise: 0.032341157934169286
# Sub_Episode: 73 | avg. reward: -5.071141111141536
# Avg scalers -> A: 0.9688951760152286  B: [1.00432296 0.95423899]
# Exploration noise: 0.03185724235241726
# Sub_Episode: 74 | avg. reward: -5.2678593907166364
# Avg scalers -> A: 0.9647421714659268  B: [1.00813201 0.96970513]
# Exploration noise: 0.031392301836984916
# Sub_Episode: 75 | avg. reward: -5.265006758780101
# Avg scalers -> A: 0.9597112975317981  B: [1.01485365 0.96476084]
# Exploration noise: 0.03094559234664808
# Sub_Episode: 76 | avg. reward: -5.264589699000169
# Avg scalers -> A: 0.9597698588965864  B: [1.02447384 0.97010036]
# Exploration noise: 0.030516399015171183
# Sub_Episode: 77 | avg. reward: -5.266080275456071
# Avg scalers -> A: 0.9572131839941497  B: [1.02409701 0.97155696]
# Exploration noise: 0.030104035007311538
# Sub_Episode: 78 | avg. reward: -5.272486450280573
# Avg scalers -> A: 0.9588660829413649  B: [1.01884536 0.97228922]
# Exploration noise: 0.029707840419681456
# Sub_Episode: 79 | avg. reward: -5.392879817964776
# Avg scalers -> A: 0.955527228091319  B: [1.0205709  0.97388145]
# Exploration noise: 0.02932718122470923
# Sub_Episode: 80 | avg. reward: -5.380307837390306
# Avg scalers -> A: 0.9420083916342216  B: [1.0448374  0.96084188]
# Exploration noise: 0.02896144825600904
# Sub_Episode: 81 | avg. reward: -5.424487817069248
# Avg scalers -> A: 0.9432777876599502  B: [1.04210951 0.95319469]
# Exploration noise: 0.028610056233535977
# Sub_Episode: 82 | avg. reward: -5.420863509491064
# Avg scalers -> A: 0.9393887337183127  B: [1.04582385 0.95410571]
# Exploration noise: 0.02827244282696631
# Sub_Episode: 83 | avg. reward: -5.593358083382832
# Avg scalers -> A: 0.936737186877026  B: [1.04583826 0.9613665 ]
# Exploration noise: 0.027948067755803982
# Sub_Episode: 84 | avg. reward: -5.601619758244876
# Avg scalers -> A: 0.9344708488617129  B: [1.04126808 0.9685502 ]
# Exploration noise: 0.027636411924773303
# Sub_Episode: 85 | avg. reward: -5.709307015833629
# Avg scalers -> A: 0.9348722975094422  B: [1.04440668 0.97156562]
# Exploration noise: 0.02733697659311425
# Sub_Episode: 86 | avg. reward: -5.80646193850341
# Avg scalers -> A: 0.9340838603449528  B: [1.04126871 0.97035364]
# Exploration noise: 0.02704928257645091
# Sub_Episode: 87 | avg. reward: -5.823808333770906
# Avg scalers -> A: 0.9361022326370244  B: [1.04643939 0.97495136]
# Exploration noise: 0.026772869479955906
# Sub_Episode: 88 | avg. reward: -5.940834511518701
# Avg scalers -> A: 0.9423272883092751  B: [1.04159453 0.99566438]
# Exploration noise: 0.026507294961583616
# Sub_Episode: 89 | avg. reward: -5.9674800239380765
# Avg scalers -> A: 0.925658253781694  B: [1.05483112 0.9600263 ]
# Exploration noise: 0.026252134024193127
# Sub_Episode: 90 | avg. reward: -6.042685995830998
# Avg scalers -> A: 0.927839101410645  B: [1.03771535 0.96502744]
# Exploration noise: 0.026006978335428116
# Sub_Episode: 91 | avg. reward: -6.178629672782211
# Avg scalers -> A: 0.9461825343611516  B: [1.01397093 0.97178235]
# Exploration noise: 0.025771435574265315
# Sub_Episode: 92 | avg. reward: -6.328084302637453
# Avg scalers -> A: 0.926272830416676  B: [1.03873184 0.95863297]
# Exploration noise: 0.02554512880318574
# Sub_Episode: 93 | avg. reward: -6.374328814933268
# Avg scalers -> A: 0.9308704109565761  B: [1.04072506 0.95846254]
# Exploration noise: 0.02532769586496412
# Sub_Episode: 94 | avg. reward: -6.45754604231746
# Avg scalers -> A: 0.93750455349947  B: [1.0546912  0.94583625]
# Exploration noise: 0.025118788803111056
# Sub_Episode: 95 | avg. reward: -6.622538388189139
# Avg scalers -> A: 0.9368913072048763  B: [1.05581705 0.94779728]
# Exploration noise: 0.02491807330504058
# Sub_Episode: 96 | avg. reward: -6.7376057121671025
# Avg scalers -> A: 0.9351148062536013  B: [1.05924097 0.94414411]
# Exploration noise: 0.024725228167071928
# Sub_Episode: 97 | avg. reward: -6.7877500711485865
# Avg scalers -> A: 0.9462936348608036  B: [1.06416244 0.94754637]
# Exploration noise: 0.02453994478040943
# Sub_Episode: 98 | avg. reward: -6.998607550039739
# Avg scalers -> A: 0.935584704153557  B: [1.07258534 0.93523091]
# Exploration noise: 0.02436192663727789
# Sub_Episode: 99 | avg. reward: -7.0288658876236045
# Avg scalers -> A: 0.9491363830273246  B: [1.07214092 0.94846807]
# Exploration noise: 0.02419088885642317
# Sub_Episode: 100 | avg. reward: -7.157907862013213
# Avg scalers -> A: 0.9419510403290724  B: [1.07728089 0.93224104]
# Exploration noise: 0.02402655772721859
# Sub_Episode: 101 | avg. reward: -7.227841956481518
# Avg scalers -> A: 0.9476144049226523  B: [1.07058821 0.93329984]
# Exploration noise: 0.023868670271647654
# Sub_Episode: 102 | avg. reward: -7.259738787448118
# Avg scalers -> A: 0.9485106227591755  B: [1.07165607 0.94011967]
# Exploration noise: 0.023716973823462044
# Sub_Episode: 103 | avg. reward: -7.274969606586767
# Avg scalers -> A: 0.9445253218549433  B: [1.07357367 0.94548798]
# Exploration noise: 0.023571225623841528
# Sub_Episode: 104 | avg. reward: -7.279485908915198
# Avg scalers -> A: 0.9486100392124598  B: [1.0588759  0.93497253]
# Exploration noise: 0.023431192432908594
# Sub_Episode: 105 | avg. reward: -7.357895391342907
# Avg scalers -> A: 0.9680003166343308  B: [1.07880427 0.98503962]
# Exploration noise: 0.02329665015647626
# Sub_Episode: 106 | avg. reward: -7.480519826358073
# Avg scalers -> A: 0.9722183137288192  B: [1.07149003 0.98770108]
# Exploration noise: 0.023167383487431605
# Sub_Episode: 107 | avg. reward: -7.3598083826694145
# Avg scalers -> A: 0.9606666888620691  B: [1.07801953 0.96106012]
# Exploration noise: 0.023043185561181227
# Sub_Episode: 108 | avg. reward: -7.511081655596861
# Avg scalers -> A: 0.9643263948225622  B: [1.07782832 0.97313819]
# Exploration noise: 0.022923857624607222
# Sub_Episode: 109 | avg. reward: -7.4679809002850925
# Avg scalers -> A: 0.9749785576437123  B: [1.07539317 0.97819598]
# Exploration noise: 0.022809208718003862
# Sub_Episode: 110 | avg. reward: -7.487261108710607
# Avg scalers -> A: 0.977739990623989  B: [1.07840814 0.98401658]
# Exploration noise: 0.02269905536948607
# Sub_Episode: 111 | avg. reward: -7.545070302326854
# Avg scalers -> A: 0.9765307357810349  B: [1.0877485 0.9869483]
# Exploration noise: 0.022593221301380556
# Sub_Episode: 112 | avg. reward: -7.545615371546348
# Avg scalers -> A: 0.9662129721813721  B: [1.09762949 0.98277509]
# Exploration noise: 0.022491537148129844
# Sub_Episode: 113 | avg. reward: -7.58701285556191
# Avg scalers -> A: 0.971594116183119  B: [1.09173497 0.97662598]
# Exploration noise: 0.022393840185257682
# Sub_Episode: 114 | avg. reward: -7.649449556356421
# Avg scalers -> A: 0.9687311202628993  B: [1.09358812 0.96247242]
# Exploration noise: 0.022299974068962145
# Sub_Episode: 115 | avg. reward: -7.757436139339379
# Avg scalers -> A: 0.9695666642382065  B: [1.09313687 0.97222041]
# Exploration noise: 0.022209788585919682
# Sub_Episode: 116 | avg. reward: -7.759748017962576
# Avg scalers -> A: 0.9610230522496295  B: [1.08904437 0.97053387]
# Exploration noise: 0.02212313941289974
# Sub_Episode: 117 | avg. reward: -7.836983042583657
# Avg scalers -> A: 0.958550103461466  B: [1.08275112 0.96845218]
# Exploration noise: 0.022039887885805236
# Sub_Episode: 118 | avg. reward: -7.825517715685291
# Avg scalers -> A: 0.9723142624273635  B: [1.07966554 0.98530061]
# Exploration noise: 0.02195990077776935
# Sub_Episode: 119 | avg. reward: -7.887676448053495
# Avg scalers -> A: 0.9761204266931458  B: [1.08830613 0.99062336]
# Exploration noise: 0.021883050085953426
# Sub_Episode: 120 | avg. reward: -7.90670398782986
# Avg scalers -> A: 0.9655571468933871  B: [1.07534449 0.97143793]
# Exploration noise: 0.021809212826704893
# Sub_Episode: 121 | avg. reward: -7.903399003365149
# Avg scalers -> A: 0.9733386475947561  B: [1.07689167 0.98624688]
# Exploration noise: 0.02173827083874734
# Sub_Episode: 122 | avg. reward: -8.077455991477114
# Avg scalers -> A: 0.964133494884545  B: [1.08390283 0.96282901]
# Exploration noise: 0.0216701105940878
# Sub_Episode: 123 | avg. reward: -8.120716270483348
# Avg scalers -> A: 0.9667307163068211  B: [1.0940576  0.97889742]
# Exploration noise: 0.02160462301633867
# Sub_Episode: 124 | avg. reward: -8.438673761987703
# Avg scalers -> A: 0.9455718475313938  B: [1.10713303 0.97975507]
# Exploration noise: 0.021541703306163475
# Sub_Episode: 125 | avg. reward: -8.456418466848469
# Avg scalers -> A: 0.9628949365933639  B: [1.07293654 0.96647402]
# Exploration noise: 0.021481250773567204
# Sub_Episode: 126 | avg. reward: -8.289426725949285
# Avg scalers -> A: 0.9563230602937333  B: [1.08304782 0.95104457]
# Exploration noise: 0.021423168676762756
# Sub_Episode: 127 | avg. reward: -8.256810344788835
# Avg scalers -> A: 0.969661035281282  B: [1.09318199 0.95898305]
# Exploration noise: 0.021367364067355718
# Sub_Episode: 128 | avg. reward: -12.362310838852482
# Avg scalers -> A: 0.9249294664562272  B: [1.15198051 0.98497889]
# Exploration noise: 0.021313747641599653
# Sub_Episode: 129 | avg. reward: -9.456812099184448
# Avg scalers -> A: 0.9804937163739335  B: [1.11030461 0.97428136]
# Exploration noise: 0.02126223359748392
# Sub_Episode: 130 | avg. reward: -8.713597981539685
# Avg scalers -> A: 0.9777791418631341  B: [1.11018188 0.97956885]
# Exploration noise: 0.02121273949742527
# Sub_Episode: 131 | avg. reward: -8.795241795512966
# Avg scalers -> A: 0.9699732464513511  B: [1.10937492 0.9675998 ]
# Exploration noise: 0.02116518613634354
# Sub_Episode: 132 | avg. reward: -8.935918316672224
# Avg scalers -> A: 0.978229836921859  B: [1.10764003 0.97571621]
# Exploration noise: 0.021119497414910284
# Sub_Episode: 133 | avg. reward: -9.202355329268483
# Avg scalers -> A: 0.9807750839833563  B: [1.11581753 0.9916621 ]
# Exploration noise: 0.021075600217767523
# Sub_Episode: 134 | avg. reward: -9.602480531949528
# Avg scalers -> A: 0.9571712821527452  B: [1.12126619 0.98493945]
# Exploration noise: 0.02103342429652172
# Sub_Episode: 135 | avg. reward: -9.386752475826727
# Avg scalers -> A: 0.9943526663297524  B: [1.12175184 1.01357922]
# Exploration noise: 0.020992902157325737
# Sub_Episode: 136 | avg. reward: -9.70103402510681
# Avg scalers -> A: 0.9959385884958732  B: [1.1275368 1.0143431]
# Exploration noise: 0.020953968952868902
# Sub_Episode: 137 | avg. reward: -9.517141758472684
# Avg scalers -> A: 1.0140848600358519  B: [1.13699698 1.04738795]
# Exploration noise: 0.020916562378602253
# Sub_Episode: 138 | avg. reward: -9.660997210972004
# Avg scalers -> A: 1.015839418494668  B: [1.13549163 1.05091923]
# Exploration noise: 0.020880622573033015
# Sub_Episode: 139 | avg. reward: -9.7152903371286
# Avg scalers -> A: 1.0159539776264375  B: [1.13864489 1.04909668]
# Exploration noise: 0.020846092021928622
# Sub_Episode: 140 | avg. reward: -9.751520841184867
# Avg scalers -> A: 1.0154755033092928  B: [1.13913589 1.04851183]
# Exploration noise: 0.020812915466277088
# Sub_Episode: 141 | avg. reward: -9.8008655780011
# Avg scalers -> A: 1.015059688297732  B: [1.13736798 1.04303616]
# Exploration noise: 0.020781039813856376
# Sub_Episode: 142 | avg. reward: -9.804651377986296
# Avg scalers -> A: 1.0122110906572803  B: [1.13672064 1.05469733]
# Exploration noise: 0.02075041405427126
# Sub_Episode: 143 | avg. reward: -9.869815985971297
# Avg scalers -> A: 1.014892159478274  B: [1.1435458 1.0517668]
# Exploration noise: 0.020720989177321736
# Sub_Episode: 144 | avg. reward: -9.797474467578775
# Avg scalers -> A: 1.0214399727780188  B: [1.14131217 1.05862275]
# Exploration noise: 0.020692718094572318
# Sub_Episode: 145 | avg. reward: -9.886452138635892
# Avg scalers -> A: 1.0185628531641544  B: [1.14349811 1.05046579]
# Exploration noise: 0.020665555563996723
# Sub_Episode: 146 | avg. reward: -9.951376631648865
# Avg scalers -> A: 1.0138084714074838  B: [1.1449528  1.04098315]
# Exploration noise: 0.02063945811757737
# Sub_Episode: 147 | avg. reward: -10.186653547832202
# Avg scalers -> A: 1.011854940504261  B: [1.1455437  1.03829672]
# Exploration noise: 0.020614383991743784
# Sub_Episode: 148 | avg. reward: -10.12888268838621
# Avg scalers -> A: 1.0147189609535012  B: [1.14424056 1.04877221]
# Exploration noise: 0.020590293060538646
# Sub_Episode: 149 | avg. reward: -10.169384196727497
# Avg scalers -> A: 1.0124408961415312  B: [1.13838301 1.04949328]
# Exploration noise: 0.020567146771404476
# Sub_Episode: 150 | avg. reward: -10.32336757783694
# Avg scalers -> A: 1.00651168687183  B: [1.14071088 1.04042278]
# Exploration noise: 0.020544908083488238
# Sub_Episode: 151 | avg. reward: -10.353168211752678
# Avg scalers -> A: 1.008986185572886  B: [1.13974505 1.03912769]
# Exploration noise: 0.020523541408365112
# Sub_Episode: 152 | avg. reward: -10.431287838360968
# Avg scalers -> A: 1.0191162085876135  B: [1.13573288 1.03739844]
# Exploration noise: 0.020503012553086564
# Sub_Episode: 153 | avg. reward: -10.584156615406554
# Avg scalers -> A: 1.0105104048821587  B: [1.14068437 1.03734411]
# Exploration noise: 0.020483288665461605
# Sub_Episode: 154 | avg. reward: -10.61838052711533
# Avg scalers -> A: 1.0188616258906737  B: [1.13865421 1.04903837]
# Exploration noise: 0.02046433818148364
# Sub_Episode: 155 | avg. reward: -10.690965201856297
# Avg scalers -> A: 1.013101550758661  B: [1.13469945 1.0443513 ]
# Exploration noise: 0.020446130774818806
# Sub_Episode: 156 | avg. reward: -10.74528717500391
# Avg scalers -> A: 1.0034745864025043  B: [1.13341181 1.02867856]
# Exploration noise: 0.020428637308274943
# Sub_Episode: 157 | avg. reward: -10.825912601374323
# Avg scalers -> A: 1.0126051439149313  B: [1.13029154 1.04709177]
# Exploration noise: 0.020411829787173524
# Sub_Episode: 158 | avg. reward: -10.82383416505501
# Avg scalers -> A: 1.001358219964832  B: [1.13100032 1.03615233]
# Exploration noise: 0.02039568131454997
# Sub_Episode: 159 | avg. reward: -10.87157231299598
# Avg scalers -> A: 1.004072789717268  B: [1.13521453 1.03822383]
# Exploration noise: 0.02038016604811061
# Sub_Episode: 160 | avg. reward: -10.910440189453352
# Avg scalers -> A: 1.0206236712877563  B: [1.1358505  1.05387277]
# Exploration noise: 0.020365259158877436
# Sub_Episode: 161 | avg. reward: -10.946209853548886
# Avg scalers -> A: 1.014592928366537  B: [1.1336456  1.04822956]
# Exploration noise: 0.020350936791454437
# Sub_Episode: 162 | avg. reward: -10.842940474453735
# Avg scalers -> A: 1.0171606437456553  B: [1.13348253 1.04638221]
# Exploration noise: 0.02033717602585199
# Sub_Episode: 163 | avg. reward: -10.829309366095002
# Avg scalers -> A: 1.0238761213055858  B: [1.13509362 1.04214438]
# Exploration noise: 0.020323954840808144
# Sub_Episode: 164 | avg. reward: -10.767537340991675
# Avg scalers -> A: 1.0225462218657495  B: [1.13622755 1.05171214]
# Exploration noise: 0.020311252078548128
# Sub_Episode: 165 | avg. reward: -10.685036430592076
# Avg scalers -> A: 1.0249797796713995  B: [1.13909774 1.05678861]
# Exploration noise: 0.02029904741092572
# Sub_Episode: 166 | avg. reward: -10.493847509556135
# Avg scalers -> A: 1.0252960724184144  B: [1.13904689 1.06267246]
# Exploration noise: 0.02028732130689225
# Sub_Episode: 167 | avg. reward: -10.369648913116166
# Avg scalers -> A: 1.0265359635052906  B: [1.14208096 1.06753773]
# Exploration noise: 0.02027605500124118
# Sub_Episode: 168 | avg. reward: -10.203429742973045
# Avg scalers -> A: 1.0268590322409537  B: [1.13891304 1.07073248]
# Exploration noise: 0.02026523046457827
# Sub_Episode: 169 | avg. reward: -10.022237468649656
# Avg scalers -> A: 1.0263599043145553  B: [1.14086511 1.07177187]
# Exploration noise: 0.02025483037446927
# Sub_Episode: 170 | avg. reward: -9.775599842189973
# Avg scalers -> A: 1.0251962628980147  B: [1.13801137 1.06726167]
# Exploration noise: 0.020244838087718937
# Sub_Episode: 171 | avg. reward: -9.559497455325335
# Avg scalers -> A: 1.0227585662846899  B: [1.14112082 1.0674904 ]
# Exploration noise: 0.020235237613737033
# Sub_Episode: 172 | avg. reward: -9.367958850307957
# Avg scalers -> A: 1.022717861620016  B: [1.13847517 1.07201193]
# Exploration noise: 0.0202260135889487
# Sub_Episode: 173 | avg. reward: -9.226175091216845
# Avg scalers -> A: 1.0189075060628685  B: [1.13913674 1.07468751]
# Exploration noise: 0.020217151252208226
# Sub_Episode: 174 | avg. reward: -9.056349064460795
# Avg scalers -> A: 1.0204051567547452  B: [1.13971486 1.07362377]
# Exploration noise: 0.020208636421176887
# Sub_Episode: 175 | avg. reward: -8.909931595982346
# Avg scalers -> A: 1.0150632958525962  B: [1.13843486 1.06506032]
# Exploration noise: 0.020200455469627038
# Sub_Episode: 176 | avg. reward: -8.759519649438628
# Avg scalers -> A: 1.0128549688989912  B: [1.13623056 1.06133566]
# Exploration noise: 0.020192595305636156
# Sub_Episode: 177 | avg. reward: -8.663347527370851
# Avg scalers -> A: 1.0154171130366216  B: [1.1368091  1.04856556]
# Exploration noise: 0.020185043350635923
# Sub_Episode: 178 | avg. reward: -8.587487205858322
# Avg scalers -> A: 1.012891667764209  B: [1.13981387 1.04960138]
# Exploration noise: 0.02017778751928282
# Sub_Episode: 179 | avg. reward: -8.57407752191305
# Avg scalers -> A: 1.007727426364802  B: [1.13827693 1.04515519]
# Exploration noise: 0.020170816200118045
# Sub_Episode: 180 | avg. reward: -8.486368436700552
# Avg scalers -> A: 1.0084621235762001  B: [1.13160248 1.02580542]
# Exploration noise: 0.02016411823698576
# Sub_Episode: 181 | avg. reward: -8.498623758894254
# Avg scalers -> A: 1.0080184079562071  B: [1.13237718 1.04341497]
# Exploration noise: 0.020157682911179968
# Sub_Episode: 182 | avg. reward: -8.429777629035772
# Avg scalers -> A: 1.0072790685928164  B: [1.13097975 1.03651556]
# Exploration noise: 0.02015149992429146
# Sub_Episode: 183 | avg. reward: -8.374499463603723
# Avg scalers -> A: 1.0071101572214993  B: [1.13191869 1.03200171]
# Exploration noise: 0.020145559381727303
# Sub_Episode: 184 | avg. reward: -8.275790137315182
# Avg scalers -> A: 1.0077148316603854  B: [1.12837842 1.02299071]
# Exploration noise: 0.020139851776876626
# Sub_Episode: 185 | avg. reward: -8.164780467950852
# Avg scalers -> A: 1.0071974887448645  B: [1.132072   1.02999459]
# Exploration noise: 0.020134367975897228
# Sub_Episode: 186 | avg. reward: -8.010497049403254
# Avg scalers -> A: 1.0067578191722846  B: [1.13394693 1.02856871]
# Exploration noise: 0.02012909920309876
# Sub_Episode: 187 | avg. reward: -7.816102396043745
# Avg scalers -> A: 1.0063044296890782  B: [1.13355921 1.01952606]
# Exploration noise: 0.020124037026899046
# Sub_Episode: 188 | avg. reward: -7.636542470581092
# Avg scalers -> A: 1.0056726493729482  B: [1.12751019 1.02116385]
# Exploration noise: 0.02011917334633108
# Sub_Episode: 189 | avg. reward: -7.410269360080813
# Avg scalers -> A: 1.0060969858927362  B: [1.12415159 1.01695896]
# Exploration noise: 0.020114500378079093
# Sub_Episode: 190 | avg. reward: -7.21123170493546
# Avg scalers -> A: 1.0044703861685589  B: [1.12649987 1.01117538]
# Exploration noise: 0.020110010644022975
# Sub_Episode: 191 | avg. reward: -7.04432856703069
# Avg scalers -> A: 0.9939001184576136  B: [1.12516762 0.99505906]
# Exploration noise: 0.020105696959271082
# Sub_Episode: 192 | avg. reward: -6.901253533022823
# Avg scalers -> A: 0.9932706584996589  B: [1.13000984 0.99400733]
# Exploration noise: 0.020101552420662316
# Sub_Episode: 193 | avg. reward: -6.70154956876757
# Avg scalers -> A: 0.9888147123299891  B: [1.11916493 0.98665646]
# Exploration noise: 0.02009757039571901
# Sub_Episode: 194 | avg. reward: -6.535396033215031
# Avg scalers -> A: 0.9844307165380849  B: [1.12432513 0.9901146 ]
# Exploration noise: 0.020093744512033055
# Sub_Episode: 195 | avg. reward: -6.418483320689902
# Avg scalers -> A: 0.985651570750917  B: [1.12302691 0.98536234]
# Exploration noise: 0.02009006864706815
# Sub_Episode: 196 | avg. reward: -6.307344126026854
# Avg scalers -> A: 0.9818819905690402  B: [1.12358568 0.97756731]
# Exploration noise: 0.020086536918361972
# Sub_Episode: 197 | avg. reward: -6.233220339378128
# Avg scalers -> A: 1.0067887006666454  B: [1.11618739 1.01973672]
# Exploration noise: 0.020083143674112482
# Sub_Episode: 198 | avg. reward: -6.153732133206861
# Avg scalers -> A: 1.0079781664181222  B: [1.10379388 1.00837346]
# Exploration noise: 0.02007988348413341
# Sub_Episode: 199 | avg. reward: -6.137709944298928
# Avg scalers -> A: 1.0051016404036777  B: [1.10789011 1.01023464]
# Exploration noise: 0.020076751131164344
# Sub_Episode: 200 | avg. reward: -6.094618556520325
# Avg scalers -> A: 1.0065160245448355  B: [1.10819424 1.00749434]
# Exploration noise: 0.020076751131164344

# %%
from utils.plotting import plot_rl_results_td3_multipliers_dqnstyle, compare_mpc_rl_nominal_from_dirs, \
    compare_mpc_rl_disturb_from_dirs

# %%
out_td3 = plot_rl_results_td3_multipliers_dqnstyle(
    y_sp=y_sp,
    steady_states=steady_states,
    nFE=nFE,
    delta_t=delta_t,
    time_in_sub_episodes=time_in_sub_episodes,
    y_rl=y_system,
    u_rl=u_rl,
    avg_rewards=avg_rewards,
    data_min=data_min,
    data_max=data_max,
    reward_fn=reward_fn,
    coef_alpha=multiplier_coefs_alpha,
    coef_delta=multiplier_coefs_delta,
    low_coef=LOW_COEF,
    high_coef=HIGH_COEF,
    start_episode=2,
    prefix_name="td3_multipliers_disturb",
    directory=dir_path,
    save_pdf=False
)

# %%
out_dir_cmp = compare_mpc_rl_disturb_from_dirs(
    rl_dir=out_td3,
    mpc_path_or_dir=r"C:\Users\HAMEDI\Desktop\RL_assisted_MPC_polymer\Data\mpc_results_dist_1.pickle",
    reward_fn=reward_fn,
    directory=r"Result",
    prefix_name="disturb_compare_td3_multipliers",
    start_episode=2
)
