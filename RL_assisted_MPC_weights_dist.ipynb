# %%
from Simulation.mpc import *
from Simulation.system_functions import PolymerCSTR
from utils.helpers import *

# %% [markdown]
# ## Initialize the system

# %%
# First initiate the system
# Parameters
Ad = 2.142e17           # h^-1
Ed = 14897              # K
Ap = 3.816e10           # L/(molh)
Ep = 3557               # K
At = 4.50e12            # L/(molh)
Et = 843                # K
fi = 0.6                # Coefficient
m_delta_H_r = -6.99e4   # j/mol
hA = 1.05e6             # j/(Kh)
rhocp = 1506            # j/(Kh)
rhoccpc = 4043          # j/(Kh)
Mm = 104.14             # g/mol
system_params = np.array([Ad, Ed, Ap, Ep, At, Et, fi, m_delta_H_r, hA, rhocp, rhoccpc, Mm])

# %%
# Design Parameters
CIf = 0.5888    # mol/L
CMf = 8.6981    # mol/L
Qi = 108.       # L/h
Qs = 459.       # L/h
Tf = 330.       # K
Tcf = 295.      # K
V = 3000.       # L
Vc = 3312.4     # L

system_design_params = np.array([CIf, CMf, Qi, Qs, Tf, Tcf, V, Vc])

# %%
# Steady State Inputs
Qm_ss = 378.    # L/h
Qc_ss = 471.6   # L/h

system_steady_state_inputs = np.array([Qc_ss, Qm_ss])

# %%
# Sampling time of the system
delta_t = 0.5 # 30 mins

# %%
# Initiate the CSTR for steady state values
cstr = PolymerCSTR(system_params, system_design_params, system_steady_state_inputs, delta_t)
steady_states={"ss_inputs":cstr.ss_inputs,
               "y_ss":cstr.y_ss}

# %% [markdown]
# ## Loading the system matrices, min max scaling, and min max of the states

# %%
dir_path = os.path.join(os.getcwd(), "Data")

# %%
# Defining the range of setpoints for data generation
setpoint_y = np.array([[3.2, 321],
                       [4.5, 325]])
u_min = np.array([71.6, 78])
u_max = np.array([870, 670])

system_data = load_and_prepare_system_data(steady_states=steady_states, setpoint_y=setpoint_y, u_min=u_min, u_max=u_max)

# %%
A_aug = system_data["A_aug"]
B_aug = system_data["B_aug"]
C_aug = system_data["C_aug"]

# %%
data_min = system_data["data_min"]
data_max = system_data["data_max"]

# %%
min_max_states = {'max_s': np.array([256.79686253, 256.01560603,  48.99447186, 144.79949103,
          2.82199733,   3.14014989,   2.78866348,   3.71691422,
          6.2029936 ]),
                  'min_s': np.array([ -272.28060121, -1112.33972595,   -76.63993491,  -608.60327886,
           -3.94399122,    -3.93115257,    -2.9532091 ,    -4.06547624,
          -28.25906582])}

# %%
y_sp_scaled_deviation = system_data["y_sp_scaled_deviation"]

# %%
b_min = system_data["b_min"]
b_max = system_data["b_max"]

# %%
min_max_dict = system_data["min_max_dict"]
min_max_dict["x_max"] = np.array([256.79686253, 256.01560603,  48.99447186, 144.79949103,
          2.82199733,   3.14014989,   2.78866348,   3.71691422,
          6.2029936 ])
min_max_dict["x_min"] = np.array([ -272.28060121, -1112.33972595,   -76.63993491,  -608.60327886,
           -3.94399122,    -3.93115257,    -2.9532091 ,    -4.06547624,
          -28.25906582])

# %%
# Setpoints in deviation form
inputs_number = int(B_aug.shape[1])
y_sp_scenario = np.array([[4.5, 324],
                          [3.4, 321]])

y_sp_scenario = (apply_min_max(y_sp_scenario, data_min[inputs_number:], data_max[inputs_number:])
                 - apply_min_max(steady_states["y_ss"], data_min[inputs_number:], data_max[inputs_number:]))
n_tests = 200
set_points_len = 400
TEST_CYCLE = [False, False, False, False, False]
warm_start = 5
ACTOR_FREEZE = 0 * set_points_len
warm_start_plot = warm_start * 2 * set_points_len + ACTOR_FREEZE

# %%
# Observer Gain
poles = np.array(np.array([0.44619852, 0.33547649, 0.36380595, 0.70467118, 0.3562966,
                           0.42900673, 0.4228262 , 0.96916776, 0.91230187]))
L = compute_observer_gain(A_aug, C_aug, poles)
# Out:
# The system is observable.
# C:\Users\HAMEDI\Desktop\RL_assisted_MPC_polymer\Simulation\mpc.py:123: UserWarning: Convergence was not reached after maxiter iterations.
# You asked for a tolerance of 0.001, we got 0.9999999422182038.
#   obs_gain_calc = signal.place_poles(A.T, C.T, desired_poles, method='KNV0')

# %% [markdown]
# ## Setting The hyperparameters for the TD3 Agent

# %%
from TD3Agent.agent import TD3Agent
import torch

# %%
set_points_number = int(C_aug.shape[0])
inputs_number = int(B_aug.shape[1])
STATE_DIM = int(A_aug.shape[0]) + set_points_number + inputs_number
ACTION_DIM=4
HIGH_COEF=np.array([3.0,3.0,3.0,3.0])
LOW_COEF=np.array([0.5,0.5,0.5,0.5])
n_outputs = C_aug.shape[0]
ACTOR_LAYER_SIZES = [512, 512, 512, 512, 512]
CRITIC_LAYER_SIZES = [512, 512, 512, 512, 512]
BUFFER_CAPACITY = 50000
ACTOR_LR = 1e-4
CRITIC_LR = 1e-4
SMOOTHING_STD = 0.1
NOISE_CLIP = 0.2
GAMMA = 0.995
TAU = 0.005
MAX_ACTION = 1.0
POLICY_DELAY = 2
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
BATCH_SIZE = 128
STD_START = 0.2
STD_END = 0.02
STD_DECAY_RATE = 0.9999
STD_DECAY_MODE = "exp"
ACTOR_FREEZE = 0

# %%
td3_agent = TD3Agent(
    state_dim=STATE_DIM,
    action_dim=ACTION_DIM,
    actor_hidden=ACTOR_LAYER_SIZES,
    critic_hidden=CRITIC_LAYER_SIZES,
    gamma=GAMMA,
    actor_lr=ACTOR_LR,
    critic_lr=CRITIC_LR,
    batch_size=BATCH_SIZE,
    policy_delay=POLICY_DELAY,
    target_policy_smoothing_noise_std=SMOOTHING_STD,
    noise_clip=NOISE_CLIP,
    max_action=MAX_ACTION,
    tau=TAU,
    std_start=STD_START,
    std_end=STD_END,
    std_decay_rate=STD_DECAY_RATE,
    std_decay_mode=STD_DECAY_MODE,
    buffer_size=BUFFER_CAPACITY,
    device=DEVICE,
    actor_freeze=ACTOR_FREEZE,
    )

# %% [markdown]
# ## MPC initialization and setpoints

# %%
# MPC parameters
n_inputs = 2
predict_h = 9
cont_h = 3
u_ss = apply_min_max(steady_states['ss_inputs'], data_min[:n_inputs], data_max[:n_inputs])
b_min = apply_min_max(np.array([71.6, 78]), data_min[:n_inputs], data_max[:n_inputs])
b_max= apply_min_max(np.array([870, 670]), data_min[:n_inputs], data_max[:n_inputs])
b1 = (b_min[0]-u_ss[0], b_max[0]-u_ss[0])
b2 = (b_min[1]-u_ss[1], b_max[1]-u_ss[1])
bnds = (b1, b2)*cont_h
cons = []
IC_opt = np.zeros(n_inputs*cont_h)
Q1_penalty = 5.
Q2_penalty = 1.
R1_penalty = 1
R2_penalty = 1

# %%
MPC_obj = MpcSolverGeneral(A_aug, B_aug, C_aug,
    Q_out=np.array([Q1_penalty, Q2_penalty]),
    R_in=np.array([R1_penalty, R2_penalty]),
    NP=predict_h,
    NC=cont_h)

# %%
def make_reward_fn_relative_QR(
    data_min, data_max, n_inputs,
    k_rel, band_floor_phys,
    Q_diag, R_diag,
    tau_frac=0.7,
    gamma_out=0.5, gamma_in=0.5,
    beta=5.0, gate="geom", lam_in=1.0,
    bonus_kind="exp", bonus_k=12.0, bonus_p=0.6, bonus_c=20.0,
):
    """
    Reward with relative tracking bands.

    data_min, data_max : arrays for [u_min..., y_min...], [u_max..., y_max...]
    n_inputs           : number of inputs (so outputs start at index n_inputs)
    k_rel              : per-output relative tolerance factors (same length as outputs)
    band_floor_phys    : per-output minimum band in physical units
    Q_diag, R_diag     : quadratic weights (same as before)
    """

    data_min = np.asarray(data_min, float)
    data_max = np.asarray(data_max, float)
    dy = np.maximum(data_max[n_inputs:] - data_min[n_inputs:], 1e-12)  # phys range for each y

    k_rel = np.asarray(k_rel, float)
    band_floor_phys = np.asarray(band_floor_phys, float)
    Q_diag = np.asarray(Q_diag, float)
    R_diag = np.asarray(R_diag, float)

    # floor in *scaled* coordinates (used if y_sp_phys is not provided)
    band_floor_scaled = band_floor_phys / np.maximum(dy, 1e-12)

    def _sigmoid(x):
        x = np.clip(x, -60.0, 60.0)
        return 1.0 / (1.0 + np.exp(-x))

    def _phi(z, kind=bonus_kind, k=bonus_k, p=bonus_p, c=bonus_c):
        z = np.clip(z, 0.0, 1.0)
        if kind == "linear":
            return 1.0 - z
        if kind == "quadratic":
            return (1.0 - z) ** 2
        if kind == "exp":
            return (np.exp(-k * z) - np.exp(-k)) / (1.0 - np.exp(-k))
        if kind == "power":
            return 1.0 - np.power(z, p)
        if kind == "log":
            return np.log1p(c * (1.0 - z)) / np.log1p(c)
        raise ValueError("unknown bonus kind")

    def reward_fn(e_scaled, du_scaled, y_sp_phys=None):
        """
        e_scaled : output error in scaled deviation space  (same as before)
        du_scaled: input move in scaled deviation space    (same as before)
        y_sp_phys: current setpoint in *physical* units (array len = n_outputs)
        """

        e_scaled = np.asarray(e_scaled, float)
        du_scaled = np.asarray(du_scaled, float)

        # ----- dynamic band based on setpoint -----
        if y_sp_phys is None:
            # fallback: just use the floor
            band_scaled = band_floor_scaled
        else:
            y_sp_phys_arr = np.asarray(y_sp_phys, float)
            # band_phys_i = max(k_rel_i * |y_sp_i|, band_floor_phys_i)
            band_phys = np.maximum(k_rel * np.abs(y_sp_phys_arr), band_floor_phys)
            band_scaled = band_phys / np.maximum(dy, 1e-12)

        tau_scaled = tau_frac * band_scaled

        # ----- inside/outside gate -----
        abs_e = np.abs(e_scaled)
        s_i = _sigmoid((band_scaled - abs_e) / np.maximum(tau_scaled, 1e-12))

        if gate == "prod":
            w_in = float(np.prod(s_i, dtype=np.float64))
        elif gate == "mean":
            w_in = float(np.mean(s_i))
        elif gate == "geom":
            w_in = float(np.prod(s_i, dtype=np.float64) ** (1.0 / len(s_i)))
        else:
            raise ValueError("gate must be 'prod'|'mean'|'geom'")

        # ----- core quadratic costs -----
        err_quad = np.sum(Q_diag * (e_scaled ** 2))
        err_eff = (1.0 - w_in) * err_quad + w_in * (lam_in * err_quad)
        move = np.sum(R_diag * (du_scaled ** 2))

        # ----- linear penalties around band edge -----
        slope_at_edge = 2.0 * Q_diag * band_scaled

        overflow = np.maximum(abs_e - band_scaled, 0.0)
        lin_out = (1.0 - w_in) * np.sum(gamma_out * slope_at_edge * overflow)

        inside_mag = np.minimum(abs_e, band_scaled)
        lin_in = w_in * np.sum(gamma_in * slope_at_edge * inside_mag)

        # ----- bonus near zero error -----
        qb2 = Q_diag * (band_scaled ** 2)
        z = abs_e / np.maximum(band_scaled, 1e-12)
        phi = _phi(z)
        bonus = w_in * beta * np.sum(qb2 * phi)

        # ----- total reward -----
        return (-(err_eff + move + lin_out + lin_in) + bonus) * 0.01

    params = dict(
        k_rel=k_rel,
        band_floor_phys=band_floor_phys,
        band_floor_scaled=band_floor_scaled,
        Q_diag=Q_diag,
        R_diag=R_diag,
        tau_frac=tau_frac,
        gamma_out=gamma_out,
        gamma_in=gamma_in,
        beta=beta,
        gate=gate,
        lam_in=lam_in,
        bonus_kind=bonus_kind,
        bonus_k=bonus_k,
        bonus_p=bonus_p,
        bonus_c=bonus_c,
    )
    return params, reward_fn

# %%
n_inputs = 2

dy = data_max[n_inputs:] - data_min[n_inputs:]
y_sp_nom = 0.5 * (data_min[n_inputs:] + data_max[n_inputs:])

k_rel = np.array([0.003, 0.0003])
band_floor_phys = np.array([0.006, 0.07])

band_phys = np.maximum(k_rel * np.abs(y_sp_nom), band_floor_phys)

scale_factor = 1.0  # use 2.0 for [-1, 1] scaling, 1.0 for [0, 1]
band_scaled = scale_factor * band_phys / dy

q0 = 1.4
Q_diag = q0 / np.maximum(band_scaled ** 2, 1e-12)

print("dy:", dy)
print("y_sp_nom:", y_sp_nom)
print("band_phys:", band_phys)
print("band_scaled:", band_scaled)
print("Q_diag:", Q_diag)
# Out:
# dy: [0.22165278 0.78153727]
# y_sp_nom: [  3.83915067 323.21371982]
# band_phys: [0.01151745 0.09696412]
# band_scaled: [0.05196169 0.12406845]
# Q_diag: [518.51529284  90.95055189]

# %%
Q_diag = np.array([518., 90.])          # rounded from the band-based calculation
R_diag = np.array([90., 90.])          # move cost for du_scaled ~ 0.02

n_inputs = 2

print("Band scaled are:")

params, reward_fn = make_reward_fn_relative_QR(
    data_min, data_max, n_inputs,
    k_rel, band_floor_phys,
    Q_diag, R_diag,
    tau_frac=0.7,
    gamma_out=0.5, gamma_in=0.5,
    beta=7.0, gate="geom", lam_in=1.0,
    bonus_kind="exp", bonus_k=12.0, bonus_p=0.6, bonus_c=20.0,
)
print(params)
# Out:
# Band scaled are:
# {'k_rel': array([0.003 , 0.0003]), 'band_floor_phys': array([0.006, 0.07 ]), 'band_floor_scaled': array([0.02706937, 0.08956707]), 'Q_diag': array([518.,  90.]), 'R_diag': array([90., 90.]), 'tau_frac': 0.7, 'gamma_out': 0.5, 'gamma_in': 0.5, 'beta': 7.0, 'gate': 'geom', 'lam_in': 1.0, 'bonus_kind': 'exp', 'bonus_k': 12.0, 'bonus_p': 0.6, 'bonus_c': 20.0}

# %%
nominal_qs = 459
nominal_qi = 108
nominal_hA = 1.05e6
qi_change = 0.85
qs_change = 1.3
ha_change = 0.85

# %%
import warnings
def compute_observer_gain(A, C, desired_poles):
    """
    Compute an observer gain L for the given MPC system using the desired poles.
    Also performs an observability check.

    Parameters:
    -----------
    A, C : np.ndarray
        System Matrices
    desired_poles : np.ndarray
        A vector of desired observer poles.

    Returns:
    --------
    L : np.ndarray
        The observer gain matrix.
    """
    # Compute the observer gain using pole placement
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", UserWarning)
        obs_gain_calc = signal.place_poles(A.T, C.T, desired_poles, "KNV0")
    L = np.squeeze(obs_gain_calc.gain_matrix).T

    # Check observability
    observability_matrix = control.obsv(A, C)
    rank = np.linalg.matrix_rank(observability_matrix)
    if rank == A.shape[0]:
        # print("The system is observable.")
        pass
    else:
        # print("The system is not observable.")
        pass
    return L

# %%
def run_rl_train_disturbance_gradually(
        system, y_sp_scenario, n_tests, set_points_len,
        steady_states, min_max_dict, agent, MPC_obj,
        Q1_penalty, Q2_penalty, R1_penalty, R2_penalty, poles,
        data_min, data_max, warm_start,
        test_cycle,
        high_coef, low_coef,
        reward_fn,
        nominal_qi, nominal_qs, nominal_ha,
        qi_change, qs_change, ha_change,
        mode="disturb"
):

    # --- setpoints generation ---
    y_sp, nFE, sub_episodes_changes_dict, time_in_sub_episodes, test_train_dict, WARM_START, qi, qs, ha = \
        generate_setpoints_training_rl_gradually(
            y_sp_scenario, n_tests, set_points_len, warm_start, test_cycle,
            nominal_qi, nominal_qs, nominal_ha,
            qi_change, qs_change, ha_change
        )

    # inputs and outputs of the system dimensions
    n_inputs = B_aug.shape[1]
    n_outputs = C_aug.shape[0]
    n_states = A_aug.shape[0]

    # Scaled steady states inputs and outputs
    ss_scaled_inputs = apply_min_max(steady_states["ss_inputs"], data_min[:n_inputs], data_max[:n_inputs])
    y_ss_scaled = apply_min_max(steady_states["y_ss"], data_min[n_inputs:], data_max[n_inputs:])

    # Logs
    y_system = np.zeros((nFE + 1, n_outputs))
    y_system[0, :] = system.current_output
    u_mpc = np.zeros((nFE, n_inputs))
    rewards = np.zeros(nFE)
    avg_rewards = []
    yhat = np.zeros((n_outputs, nFE))
    xhatdhat = np.zeros((n_states, nFE + 1))


    # we need to recalculate the observer gain
    # # Observer Gain
    L = compute_observer_gain(MPC_obj.A, MPC_obj.C, poles)

    Q_base=np.array([Q1_penalty,Q2_penalty],dtype=float)
    R_base=np.array([R1_penalty,R2_penalty],dtype=float)

    # ----- helper ------
    def map_to_bounds(a, low, high):
        return low + ((a + 1.0) / 2.0) * (high - low)

    def map_from_bounds(x, low, high):
        return 2.0 * (x - low) / (high - low) - 1.0

    def set_penalties(MPC_obj, Q_base, R_base, m):
        Q1_new=float(Q_base[0]*m[0])
        Q2_new=float(Q_base[1]*m[1])
        R1_new=float(R_base[0]*m[2])
        R2_new=float(R_base[1]*m[3])

        MPC_obj.Q_out = np.array([Q1_new, Q2_new])
        MPC_obj.R_in = np.array([R1_new, R2_new])




    m_prev=np.ones(4,dtype=float)
    mult_log=np.zeros((nFE,4))

    test = False

    for i in range(nFE):
        # train/test phase
        if i in test_train_dict:
            test = test_train_dict[i]

        # Current scaled input & deviation
        scaled_current_input = apply_min_max(system.current_input, data_min[:n_inputs], data_max[:n_inputs])
        scaled_current_input_dev = scaled_current_input - ss_scaled_inputs

        # ---- RL state (scaled) ----
        current_rl_state = apply_rl_scaled(min_max_dict, xhatdhat[:, i], y_sp[i, :], scaled_current_input_dev).astype(np.float32)

        # ---- TD3 action ----
        if i > WARM_START:
            if not test:
                action = agent.take_action(current_rl_state, explore=(not test))
            else:
                action = agent.act_eval(current_rl_state)
        else:
            action_ = np.array([1., 1., 1., 1.])
            action = map_from_bounds(action_, low_coef, high_coef)



        m=map_to_bounds(action,low_coef,high_coef)
        m=np.asarray(m,dtype=float).reshape(-1)
        if m.size!=4:
            raise ValueError("ACTION_DIM must be 4 for [Q1,Q2,R1,R2] tuning")

        mult_log[i,:] = m

        set_penalties(MPC_obj, Q_base, R_base, m)

        # Solve MPC for current y_sp and model state x0_model
        sol = spo.minimize(
            lambda x: MPC_obj.mpc_opt_fun(x, y_sp[i, :], scaled_current_input_dev, xhatdhat[:, i]),
            IC_opt, bounds=bnds, constraints=cons
        )

        # Take first move (scaled deviation) and map to plant input
        u_mpc[i, :] = sol.x[:n_inputs] + ss_scaled_inputs
        u_plant = reverse_min_max(u_mpc[i, :], data_min[:n_inputs], data_max[:n_inputs])

        # delta u cost variables
        delta_u = u_mpc[i, :] - scaled_current_input

        # Apply to plant and step
        system.current_input = u_plant
        system.step()
        if mode == "disturb":
            # disturbances
            system.hA = ha[i]
            system.Qs = qs[i]
            system.Qi = qi[i]

        # Record output
        y_system[i+1, :] = system.current_output

        # ----- Observer & model roll -----
        y_current_scaled = apply_min_max(y_system[i+1, :], data_min[n_inputs:], data_max[n_inputs:]) - y_ss_scaled
        y_prev_scaled = apply_min_max(y_system[i, :], data_min[n_inputs:], data_max[n_inputs:]) - y_ss_scaled

        # Calculate Delta y in deviation form
        delta_y = y_current_scaled - y_sp[i, :]

        # Calculate the next state in deviation form
        yhat[:, i] = np.dot(MPC_obj.C, xhatdhat[:, i])
        xhatdhat[:, i+1] = np.dot(MPC_obj.A, xhatdhat[:, i]) + np.dot(MPC_obj.B, (u_mpc[i, :] - ss_scaled_inputs)) + np.dot(L, (y_prev_scaled - yhat[:, i])).T

        # y_sp in physical band
        y_sp_phys = reverse_min_max(y_sp[i, :] + y_ss_scaled, data_min[n_inputs:], data_max[n_inputs:])

        # Reward Calculation
        reward = reward_fn(delta_y, delta_u, y_sp_phys) * 0.01

        # Record rewards
        rewards[i] = reward

        # ----- Next state for TD3 -----
        next_u_dev = u_mpc[i, :] - ss_scaled_inputs
        next_rl_state = apply_rl_scaled(min_max_dict, xhatdhat[:, i+1], y_sp[i, :], next_u_dev)

        # Episode boundary (treat each setpoint block as an episode end)
        # done = ((i + 1) % time_in_sub_episodes == 0) or (i == nFE - 1)
        done = 0.0

        # Buffer + train (skip if in test phase)
        if not test:
            agent.push(current_rl_state,
                       action.astype(np.float32),
                       float(reward),
                       next_rl_state,
                       float(done))
            if i >= warm_start:
                _ = agent.train_step()  # returns loss or None

        # diagnostics at sub-episode boundary
        if i in sub_episodes_changes_dict:
            avg_rewards.append(np.mean(rewards[max(0, i - time_in_sub_episodes + 1): i + 1]))
            print('Sub_Episode:', sub_episodes_changes_dict[i], '| avg. reward:', avg_rewards[-1])
            m_avg = np.mean(mult_log[max(0, i - time_in_sub_episodes + 1): i + 1, :], axis=0)
            print("Avg Weights Multipliers [Q1, Q2 ,R1, R2]:",m_avg)

            if hasattr(agent, "_expl_sigma"):
                print('Exploration noise:', agent._expl_sigma)

    # Reverse scaling for RL inputs
    u_rl = reverse_min_max(u_mpc, data_min[:n_inputs], data_max[:n_inputs])

    return (y_system, u_rl, avg_rewards, rewards, xhatdhat, nFE, time_in_sub_episodes,
            y_sp, yhat, mult_log)

# %%
cstr = PolymerCSTR(system_params, system_design_params, system_steady_state_inputs, delta_t)
(y_system, u_rl, avg_rewards, rewards, xhatdhat, nFE, time_in_sub_episodes,
            y_sp, yhat, mult_log) = run_rl_train_disturbance_gradually(
        cstr, y_sp_scenario, n_tests, set_points_len,
        steady_states, min_max_dict, td3_agent, MPC_obj,
        Q1_penalty, Q2_penalty, R1_penalty, R2_penalty, poles,
        data_min, data_max, warm_start,
        TEST_CYCLE,
        HIGH_COEF, LOW_COEF,
        reward_fn,
        nominal_qi, nominal_qs, nominal_hA,
        qi_change, qs_change, ha_change,
        mode="disturb"
)
# Out:
# Sub_Episode: 1 | avg. reward: -3.3675827713234594
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1. 1. 1. 1.]
# Sub_Episode: 2 | avg. reward: -4.4172201390272985
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1. 1. 1. 1.]
# Sub_Episode: 3 | avg. reward: -4.412489336020124
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1. 1. 1. 1.]
# Sub_Episode: 4 | avg. reward: -4.40907056807221
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1. 1. 1. 1.]
# Sub_Episode: 5 | avg. reward: -4.405474399625482
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1. 1. 1. 1.]
# Sub_Episode: 6 | avg. reward: -5.620645118435351
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.27157523 1.14495238 1.16473319 1.08754425]
# Exploration noise: 0.1861768953523783
# Sub_Episode: 7 | avg. reward: -4.314794429790493
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.5516858  1.23838877 1.01366925 0.90752118]
# Exploration noise: 0.17339999484944665
# Sub_Episode: 8 | avg. reward: -4.541460046807481
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.81945389 1.32651602 1.16212773 0.86873465]
# Exploration noise: 0.1616054763203486
# Sub_Episode: 9 | avg. reward: -3.1904334767473213
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.90026255 1.44384887 1.22407247 0.83494222]
# Exploration noise: 0.15071780702204596
# Sub_Episode: 10 | avg. reward: -2.9175790713149814
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.98847543 1.41146039 1.25162978 0.87017168]
# Exploration noise: 0.14066726172367272
# Sub_Episode: 11 | avg. reward: -2.8828606899176896
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.7422757  1.62460536 1.11948588 1.07181973]
# Exploration noise: 0.13138947618233565
# Sub_Episode: 12 | avg. reward: -2.7027947706147586
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.61659276 1.59265486 0.88618581 1.20167384]
# Exploration noise: 0.1228250349509752
# Sub_Episode: 13 | avg. reward: -2.572752128373539
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.54849238 1.62716977 0.87950375 1.390635  ]
# Exploration noise: 0.11491909087858657
# Sub_Episode: 14 | avg. reward: -2.423181775457384
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.53963211 1.61731065 0.92030066 1.42915149]
# Exploration noise: 0.10762101386605877
# Sub_Episode: 15 | avg. reward: -2.4890026873417077
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.59367587 1.40023099 0.79443381 1.24983984]
# Exploration noise: 0.10088406662824527
# Sub_Episode: 16 | avg. reward: -2.7544218399810165
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.51744904 1.4871372  0.82918399 1.22549523]
# Exploration noise: 0.09466510538582851
# Sub_Episode: 17 | avg. reward: -2.373337983548222
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.41571952 1.65308767 0.78230685 1.07739274]
# Exploration noise: 0.0889243035701928
# Sub_Episode: 18 | avg. reward: -2.4084364114433345
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.44168689 1.50712842 0.88854428 0.99679268]
# Exploration noise: 0.08362489677189623
# Sub_Episode: 19 | avg. reward: -2.3061058215675065
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.89920888 1.71045942 0.92283335 1.09093448]
# Exploration noise: 0.0787329472993778
# Sub_Episode: 20 | avg. reward: -2.301367703636883
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.90329196 1.7664483  0.98701957 1.34219904]
# Exploration noise: 0.0742171268401208
# Sub_Episode: 21 | avg. reward: -2.2824623701816296
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.74442193 1.71884735 0.79124261 1.53139248]
# Exploration noise: 0.07004851583242251
# Sub_Episode: 22 | avg. reward: -2.2240747683896656
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.83886374 1.70721687 0.79075882 1.58261366]
# Exploration noise: 0.06620041826293623
# Sub_Episode: 23 | avg. reward: -2.1986075045852576
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.76778068 1.87847826 0.65872661 1.48059259]
# Exploration noise: 0.06264819070393872
# Sub_Episode: 24 | avg. reward: -2.167252007079542
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.81027856 2.09936372 0.72571859 1.45572798]
# Exploration noise: 0.05936908449546856
# Sub_Episode: 25 | avg. reward: -2.170115396294289
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.78308732 2.15121513 0.77313332 1.50471556]
# Exploration noise: 0.05634210006166103
# Sub_Episode: 26 | avg. reward: -2.1304511627547122
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.84369087 2.17461123 0.74035292 1.50013559]
# Exploration noise: 0.05354785242831346
# Sub_Episode: 27 | avg. reward: -2.121489928581545
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.91862785 2.06839682 0.76041737 1.55331866]
# Exploration noise: 0.05096844708044805
# Sub_Episode: 28 | avg. reward: -2.1375240360258094
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.7862558  2.12245123 0.76783498 1.55403487]
# Exploration noise: 0.04858736536485728
# Sub_Episode: 29 | avg. reward: -2.117064351725075
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.03932052 2.1126179  0.73815568 1.5637619 ]
# Exploration noise: 0.046389358703743486
# Sub_Episode: 30 | avg. reward: -2.0918679222568075
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.00086625 2.03920795 0.81709138 1.68428423]
# Exploration noise: 0.044360350941991006
# Sub_Episode: 31 | avg. reward: -2.137776143042262
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.0346673  2.01413669 0.75131428 1.5781611 ]
# Exploration noise: 0.04248734820269737
# Sub_Episode: 32 | avg. reward: -2.0856801868179695
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.14488331 1.95514836 0.77420463 1.56901431]
# Exploration noise: 0.0407583556736735
# Sub_Episode: 33 | avg. reward: -2.10681101117305
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.16563026 1.95087698 0.7620272  1.52838893]
# Exploration noise: 0.03916230079200912
# Sub_Episode: 34 | avg. reward: -2.1078490128198664
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.13244469 1.85291142 0.7856607  1.48183441]
# Exploration noise: 0.03768896233477308
# Sub_Episode: 35 | avg. reward: -2.0984829954566866
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.09202513 1.93574467 0.74351512 1.48987812]
# Exploration noise: 0.03632890496174149
# Sub_Episode: 36 | avg. reward: -2.0651930162692675
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.09407364 1.90249323 0.78584195 1.51337759]
# Exploration noise: 0.03507341879096189
# Sub_Episode: 37 | avg. reward: -2.0871401304870663
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.06825551 1.84182012 0.79968589 1.51254821]
# Exploration noise: 0.03391446362019191
# Sub_Episode: 38 | avg. reward: -2.0719390459577616
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.15766238 1.96872262 0.8056596  1.56412923]
# Exploration noise: 0.032844617437003426
# Sub_Episode: 39 | avg. reward: -2.074071407481489
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.14485848 1.97794248 0.72855916 1.53195234]
# Exploration noise: 0.031857028887808246
# Sub_Episode: 40 | avg. reward: -2.050841575106269
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.11635999 1.88821753 0.8887617  1.48580736]
# Exploration noise: 0.030945373401414275
# Sub_Episode: 41 | avg. reward: -2.0388466411667308
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.01727225 1.81531263 0.76446579 1.45179644]
# Exploration noise: 0.030103812686124963
# Sub_Episode: 42 | avg. reward: -2.037940032268105
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.09290284 1.84395493 0.73678037 1.42759715]
# Exploration noise: 0.029326957340999334
# Sub_Episode: 43 | avg. reward: -2.0368432443844866
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.09234068 1.87727911 0.75175345 1.41632405]
# Exploration noise: 0.028609832341833008
# Sub_Episode: 44 | avg. reward: -2.0435427671928057
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.07201285 2.1033777  0.62343762 1.56284472]
# Exploration noise: 0.02794784518083055
# Sub_Episode: 45 | avg. reward: -2.0465329460381843
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.03975834 2.12853074 0.64047124 1.58280852]
# Exploration noise: 0.02733675645593385
# Sub_Episode: 46 | avg. reward: -2.035493434850827
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.76308767 1.80618458 0.72632539 1.54279216]
# Exploration noise: 0.02677265272145903
# Sub_Episode: 47 | avg. reward: -2.081748284495737
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.63411591 1.72570272 0.83711965 1.52657487]
# Exploration noise: 0.026251921426175787
# Sub_Episode: 48 | avg. reward: -2.0292776178546315
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.99019686 2.10234905 0.66127341 1.57569664]
# Exploration noise: 0.025771227778331372
# Sub_Episode: 49 | avg. reward: -2.0318493270939197
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.12472396 2.1166429  0.66601065 1.63564654]
# Exploration noise: 0.025327493389461407
# Sub_Episode: 50 | avg. reward: -2.0285186006587153
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.02718279 2.13738363 0.68028953 1.61107217]
# Exploration noise: 0.024917876560221493
# Sub_Episode: 51 | avg. reward: -2.017576082743229
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.10581201 2.1701044  0.70759888 1.63835615]
# Exploration noise: 0.024539754081988836
# Sub_Episode: 52 | avg. reward: -2.0250626717273574
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.03394159 2.13106042 0.6261981  1.57122769]
# Exploration noise: 0.024190704437690502
# Sub_Episode: 53 | avg. reward: -2.0181785059033177
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.06972981 2.20961609 0.76037641 1.72285755]
# Exploration noise: 0.023868492294275345
# Sub_Episode: 54 | avg. reward: -2.01044091622766
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.98165606 2.18822235 1.00648002 1.6318588 ]
# Exploration noise: 0.02357105418751867
# Sub_Episode: 55 | avg. reward: -2.0495742547138764
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.08265979 2.04847373 1.13850617 1.57720915]
# Exploration noise: 0.023296485307484224
# Sub_Episode: 56 | avg. reward: -2.0656215626810397
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.24157362 1.81643132 0.87513457 1.56344192]
# Exploration noise: 0.02304302730001701
# Sub_Episode: 57 | avg. reward: -2.0161521494503645
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.06714182 2.0144277  0.61578354 1.6037885 ]
# Exploration noise: 0.022809057006146875
# Sub_Episode: 58 | avg. reward: -1.9991270381777622
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.03027654 2.05303938 0.65601439 1.61560791]
# Exploration noise: 0.022593076067289553
# Sub_Episode: 59 | avg. reward: -1.9967363179726565
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.8435677  1.82958879 0.70773669 1.55799306]
# Exploration noise: 0.02239370132967614
# Sub_Episode: 60 | avg. reward: -2.032905423367713
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.91591931 1.96779607 0.71810276 1.47928516]
# Exploration noise: 0.022209655986560578
# Sub_Episode: 61 | avg. reward: -2.000790167247288
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.83422488 1.91358468 0.70669917 1.57834927]
# Exploration noise: 0.02203976140147927
# Sub_Episode: 62 | avg. reward: -1.9903456167652334
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.85980965 1.9071291  0.70229196 1.56386864]
# Exploration noise: 0.021882929560198588
# Sub_Episode: 63 | avg. reward: -2.0040669153418564
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.877689   1.92081428 0.71852752 1.57587559]
# Exploration noise: 0.02173815610301207
# Sub_Episode: 64 | avg. reward: -2.0086165693092277
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.93257471 1.97498025 0.72432182 1.56013293]
# Exploration noise: 0.021604513892765836
# Sub_Episode: 65 | avg. reward: -1.9978077465861463
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.98048035 2.03036216 0.70508787 1.50236338]
# Exploration noise: 0.021481147077421447
# Sub_Episode: 66 | avg. reward: -2.017504084502268
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.91809745 2.0142929  0.73880363 1.52124519]
# Exploration noise: 0.021367265609132536
# Sub_Episode: 67 | avg. reward: -2.0319214382268633
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.67186952 2.15744059 0.83568148 1.61776409]
# Exploration noise: 0.0212621401847351
# Sub_Episode: 68 | avg. reward: -2.0015048300540967
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.73862323 2.16051093 0.76621745 1.70881681]
# Exploration noise: 0.02116509757525009
# Sub_Episode: 69 | avg. reward: -2.0160848300658163
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.68869035 2.1499013  0.78334879 1.7132598 ]
# Exploration noise: 0.021075516314488115
# Sub_Episode: 70 | avg. reward: -2.0223761623811796
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.70741192 2.14039405 0.76571343 1.64511992]
# Exploration noise: 0.020992822719145904
# Sub_Episode: 71 | avg. reward: -2.0289717773611047
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.78158722 2.20167603 0.75117281 1.6461798 ]
# Exploration noise: 0.020916487214907013
# Sub_Episode: 72 | avg. reward: -2.0047559018584993
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.80006455 2.1940341  0.92190052 1.68730801]
# Exploration noise: 0.02084602094501886
# Sub_Episode: 73 | avg. reward: -2.0249498427187467
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.98625888 2.2426076  1.17066049 1.69868641]
# Exploration noise: 0.020780972639627304
# Sub_Episode: 74 | avg. reward: -2.0269020830108535
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.96132172 2.35186683 1.04919213 1.70278774]
# Exploration noise: 0.020720925725819756
# Sub_Episode: 75 | avg. reward: -1.9859434870836885
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.02052911 2.28406839 0.79674341 1.69966444]
# Exploration noise: 0.020665495659869432
# Sub_Episode: 76 | avg. reward: -1.97137522707772
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.06676865 2.23362758 0.61850297 1.62018443]
# Exploration noise: 0.02061432746459623
# Sub_Episode: 77 | avg. reward: -1.9721619324533348
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.08580443 2.27199005 0.64900662 1.58170493]
# Exploration noise: 0.020567093456073444
# Sub_Episode: 78 | avg. reward: -2.0026965656157136
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.10100175 2.25268095 0.67933556 1.58065291]
# Exploration noise: 0.020523491145121916
# Sub_Episode: 79 | avg. reward: -1.9668939278444946
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.12213725 2.29888436 0.78396106 1.53086369]
# Exploration noise: 0.020483241300152763
# Sub_Episode: 80 | avg. reward: -1.9769097881761173
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.20350184 2.23542981 0.83677053 1.47775706]
# Exploration noise: 0.02044608615895298
# Sub_Episode: 81 | avg. reward: -1.9667798261826857
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.13321413 2.33588508 0.76741198 1.46530829]
# Exploration noise: 0.0204117877779621
# Sub_Episode: 82 | avg. reward: -1.9558373303199341
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.08773114 2.34379864 0.75481906 1.53707646]
# Exploration noise: 0.0203801265084686
# Sub_Episode: 83 | avg. reward: -1.9806794589422287
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.13556694 2.41104225 0.76049342 1.5840002 ]
# Exploration noise: 0.020350899589967497
# Sub_Episode: 84 | avg. reward: -1.9627125881587202
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.08009565 2.39424786 0.74596156 1.53281854]
# Exploration noise: 0.020323919851670983
# Sub_Episode: 85 | avg. reward: -2.027058935134403
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.0229181  2.42439982 1.1180142  1.66216373]
# Exploration noise: 0.02029901451385643
# Sub_Episode: 86 | avg. reward: -1.9991550525210433
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.90056899 2.28211838 1.34816408 1.78534723]
# Exploration noise: 0.020276024081375583
# Sub_Episode: 87 | avg. reward: -1.999477191789776
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.09711024 2.16679135 1.01340001 1.74513307]
# Exploration noise: 0.020254801322238877
# Sub_Episode: 88 | avg. reward: -1.9776246964235797
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.07779119 2.04813307 0.87779088 1.93457796]
# Exploration noise: 0.02023521032473373
# Sub_Episode: 89 | avg. reward: -1.9316407541201546
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.92437433 2.32028025 0.78552399 1.76902531]
# Exploration noise: 0.02021712562703847
# Sub_Episode: 90 | avg. reward: -1.942184182541974
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.93062562 2.31607433 0.7620323  1.76706111]
# Exploration noise: 0.02020043141375795
# Sub_Episode: 91 | avg. reward: -1.9073948785739916
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.83367545 2.23272241 0.68974218 1.73537477]
# Exploration noise: 0.020185020774235427
# Sub_Episode: 92 | avg. reward: -1.9232299163483093
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.82246693 2.18024248 0.68243106 1.74725842]
# Exploration noise: 0.020170795017890847
# Sub_Episode: 93 | avg. reward: -1.9267682728524442
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.80649525 2.20422323 0.67974808 1.73020192]
# Exploration noise: 0.020157663042200964
# Sub_Episode: 94 | avg. reward: -1.9334842931787148
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.82266956 2.24103678 0.67333682 1.67650689]
# Exploration noise: 0.020145540749273782
# Sub_Episode: 95 | avg. reward: -1.917519594108702
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.79219335 2.21693851 0.65827427 1.69435517]
# Exploration noise: 0.020134350507281056
# Sub_Episode: 96 | avg. reward: -1.9197065605283792
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.84514176 2.24407474 0.65464532 1.75655113]
# Exploration noise: 0.0201240206532998
# Sub_Episode: 97 | avg. reward: -1.919956275546366
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.81080993 2.2601237  0.67235613 1.81327773]
# Exploration noise: 0.02011448503437901
# Sub_Episode: 98 | avg. reward: -1.9146225817825673
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.90654377 2.22563904 0.66251512 1.77799518]
# Exploration noise: 0.020105682583892535
# Sub_Episode: 99 | avg. reward: -1.9223858111564822
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.86308505 2.22316593 0.65398111 1.75177449]
# Exploration noise: 0.020097556930465058
# Sub_Episode: 100 | avg. reward: -1.9180872306264405
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.89017381 2.21055995 0.6594707  1.74212198]
# Exploration noise: 0.020090056036966716
# Sub_Episode: 101 | avg. reward: -1.9102872223679213
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.89303448 2.22085729 0.63577069 1.7466191 ]
# Exploration noise: 0.02008313186726447
# Sub_Episode: 102 | avg. reward: -1.9149679897279832
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.91450815 2.25004492 0.6229463  1.78398983]
# Exploration noise: 0.020076740078596084
# Sub_Episode: 103 | avg. reward: -1.9104409442998826
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.89800179 2.2402529  0.62623256 1.7499061 ]
# Exploration noise: 0.020070839737596633
# Sub_Episode: 104 | avg. reward: -1.9032821487164058
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.95486639 2.04602144 0.61173928 1.57071202]
# Exploration noise: 0.020065393058158996
# Sub_Episode: 105 | avg. reward: -1.9241916114304423
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.98000385 1.96776342 0.64948395 1.53781734]
# Exploration noise: 0.02006036515944956
# Sub_Episode: 106 | avg. reward: -1.9191158415233043
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.94146494 2.00537199 0.65837601 1.53453555]
# Exploration noise: 0.02005572384252945
# Sub_Episode: 107 | avg. reward: -1.9221406205814089
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.89521143 2.01547991 0.66862682 1.54857274]
# Exploration noise: 0.020051439384150743
# Sub_Episode: 108 | avg. reward: -1.897899497694224
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.88650477 2.04212896 0.65328234 1.53955626]
# Exploration noise: 0.020047484346407185
# Sub_Episode: 109 | avg. reward: -1.963927862294081
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.92630902 2.01823775 0.68064516 1.53392335]
# Exploration noise: 0.020043833401020315
# Sub_Episode: 110 | avg. reward: -1.8824756735869885
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.9788403  1.99777102 0.68752886 1.52757955]
# Exploration noise: 0.02004046316713579
# Sub_Episode: 111 | avg. reward: -1.8974054455643716
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.97513431 1.99466857 0.67430258 1.51073871]
# Exploration noise: 0.020037352061591115
# Sub_Episode: 112 | avg. reward: -1.8963152636389902
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.96521352 2.07808737 0.64945805 1.50177759]
# Exploration noise: 0.020034480160695884
# Sub_Episode: 113 | avg. reward: -1.8895528467034768
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.8921865  2.13209159 0.65832102 1.48186138]
# Exploration noise: 0.020031829072639378
# Sub_Episode: 114 | avg. reward: -1.888306741217655
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.87793184 2.05666676 0.6680288  1.49084947]
# Exploration noise: 0.020029381819708387
# Sub_Episode: 115 | avg. reward: -1.890264748712136
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.95502676 2.05363709 0.68722007 1.46284634]
# Exploration noise: 0.020027122729561028
# Sub_Episode: 116 | avg. reward: -1.9353432390737795
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.89219722 2.08091277 0.6760949  1.51662619]
# Exploration noise: 0.020025037334860194
# Sub_Episode: 117 | avg. reward: -1.8832852298992435
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.02535979 2.24497061 0.70143984 1.57473354]
# Exploration noise: 0.02002311228062393
# Sub_Episode: 118 | avg. reward: -1.8967253373735085
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.95404111 2.31642381 0.78532093 1.5273671 ]
# Exploration noise: 0.02002133523869941
# Sub_Episode: 119 | avg. reward: -1.8817690284083608
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.10780046 2.35360811 0.684593   1.44701867]
# Exploration noise: 0.02001969482881276
# Sub_Episode: 120 | avg. reward: -1.8852218276782862
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.2247026  2.33863786 0.72240283 1.45009549]
# Exploration noise: 0.020018180545689167
# Sub_Episode: 121 | avg. reward: -1.8735212188892367
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.28114205 2.30387564 0.67209344 1.42531538]
# Exploration noise: 0.020016782691776525
# Sub_Episode: 122 | avg. reward: -1.8731984845583725
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.29103592 2.26075366 0.67645105 1.43091232]
# Exploration noise: 0.020015492315141763
# Sub_Episode: 123 | avg. reward: -1.8766866847921506
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.01861564 2.26049942 0.7550584  1.46922219]
# Exploration noise: 0.020014301152142196
# Sub_Episode: 124 | avg. reward: -1.874601194264026
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.00130257 2.29638658 0.6873074  1.53749345]
# Exploration noise: 0.0200132015745047
# Sub_Episode: 125 | avg. reward: -1.8785390358382517
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.98616423 2.28968621 0.68020991 1.53418377]
# Exploration noise: 0.02001218654047382
# Sub_Episode: 126 | avg. reward: -1.89243219353259
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.96849537 2.28776749 0.66611329 1.52433835]
# Exploration noise: 0.020011249549715997
# Sub_Episode: 127 | avg. reward: -1.8673494351598412
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.98441036 2.2928411  0.68527215 1.53916074]
# Exploration noise: 0.020010384601691068
# Sub_Episode: 128 | avg. reward: -1.864006799603313
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.88709812 2.19682961 0.62004509 1.50958928]
# Exploration noise: 0.020009586157224476
# Sub_Episode: 129 | avg. reward: -1.8781077493460527
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.87775547 2.23126948 0.6354434  1.54878914]
# Exploration noise: 0.020008849103034104
# Sub_Episode: 130 | avg. reward: -1.8748812753960373
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.91978746 2.19490766 0.63128515 1.52750412]
# Exploration noise: 0.02000816871898452
# Sub_Episode: 131 | avg. reward: -1.8676682214651021
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.8869462  2.22858426 0.6322886  1.54260127]
# Exploration noise: 0.020007540647858986
# Sub_Episode: 132 | avg. reward: -1.844466300689811
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.93507959 2.20531939 0.62920769 1.53139721]
# Exploration noise: 0.020006960867455594
# Sub_Episode: 133 | avg. reward: -1.859349275729336
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.96207782 2.19712341 0.64608521 1.5498542 ]
# Exploration noise: 0.020006425664828867
# Sub_Episode: 134 | avg. reward: -1.8389990802577427
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.96044551 2.18376042 0.63717769 1.55548052]
# Exploration noise: 0.020005931612511848
# Sub_Episode: 135 | avg. reward: -1.8480303141778611
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.10497439 2.02601281 0.58205931 1.57703965]
# Exploration noise: 0.02000547554656643
# Sub_Episode: 136 | avg. reward: -1.8401462660079995
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.07290569 2.02725874 0.60685983 1.62623494]
# Exploration noise: 0.0200050545463213
# Sub_Episode: 137 | avg. reward: -1.8355161451503068
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.08654215 2.06763777 0.58330893 1.5754662 ]
# Exploration noise: 0.020004665915667814
# Sub_Episode: 138 | avg. reward: -1.8274551869452642
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.0506592  2.1199831  0.60156955 1.59721266]
# Exploration noise: 0.020004307165793975
# Sub_Episode: 139 | avg. reward: -1.8429649405276405
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.34901623 2.27173918 0.65776295 1.50470308]
# Exploration noise: 0.020003975999245926
# Sub_Episode: 140 | avg. reward: -1.8258930281857284
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.33875509 2.30105526 0.67036583 1.48648953]
# Exploration noise: 0.020003670295214947
# Sub_Episode: 141 | avg. reward: -1.8322765391661415
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.34164043 2.30026181 0.65675147 1.51741098]
# Exploration noise: 0.020003388095955667
# Sub_Episode: 142 | avg. reward: -1.8196293136575603
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.25393743 2.30905145 0.62467811 1.51144181]
# Exploration noise: 0.020003127594248566
# Sub_Episode: 143 | avg. reward: -1.823058821550792
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.14690237 2.35029863 0.64900573 1.57229772]
# Exploration noise: 0.02000288712182644
# Sub_Episode: 144 | avg. reward: -1.8496687734015689
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.1862598  2.35863061 0.6356711  1.58123179]
# Exploration noise: 0.020002665138690708
# Sub_Episode: 145 | avg. reward: -1.8176949505678976
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [2.18059073 2.33701968 0.66028922 1.59418802]
# Exploration noise: 0.02000246022324921
# Sub_Episode: 146 | avg. reward: -1.8187006725126387
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.9976752  2.24542557 0.59205345 1.65870367]
# Exploration noise: 0.02000227106321223
# Sub_Episode: 147 | avg. reward: -1.8236175806958699
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.91454667 2.18324987 0.58720902 1.70013287]
# Exploration noise: 0.020002096447188523
# Sub_Episode: 148 | avg. reward: -1.814530789006476
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.93002697 2.15232363 0.58178825 1.66824372]
# Exploration noise: 0.020001935256927502
# Sub_Episode: 149 | avg. reward: -1.824228500837952
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.91024506 2.18243288 0.58448187 1.66131233]
# Exploration noise: 0.020001786460157902
# Sub_Episode: 150 | avg. reward: -1.8268373534028415
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.90113004 2.18836487 0.58686627 1.645879  ]
# Exploration noise: 0.02000164910397706
# Sub_Episode: 151 | avg. reward: -1.813613319849451
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.94549904 2.20090341 0.58395401 1.63133093]
# Exploration noise: 0.02000152230874846
# Sub_Episode: 152 | avg. reward: -1.824620934723165
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.93013216 2.21934152 0.58692158 1.67744442]
# Exploration noise: 0.020001405262468516
# Sub_Episode: 153 | avg. reward: -1.8158513108294607
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.9156893  2.20735758 0.58913399 1.65688462]
# Exploration noise: 0.020001297215566434
# Sub_Episode: 154 | avg. reward: -1.8073581203318207
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.90935181 2.22988257 0.59124238 1.6617613 ]
# Exploration noise: 0.02000119747610393
# Sub_Episode: 155 | avg. reward: -1.8173146898740429
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.92902126 2.20213998 0.59386855 1.6652689 ]
# Exploration noise: 0.02000110540534402
# Sub_Episode: 156 | avg. reward: -1.8289380139681555
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.93393899 2.14125721 0.58755185 1.66674868]
# Exploration noise: 0.020001020413660513
# Sub_Episode: 157 | avg. reward: -1.8191752418513571
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.97242837 2.12118757 0.63461453 1.60929372]
# Exploration noise: 0.020000941956762008
# Sub_Episode: 158 | avg. reward: -1.821208308727277
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.98784868 2.14582008 0.58689034 1.53197965]
# Exploration noise: 0.02000086953220623
# Sub_Episode: 159 | avg. reward: -1.8183079048537008
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.94846616 2.17700364 0.63737786 1.6583068 ]
# Exploration noise: 0.020000802676182358
# Sub_Episode: 160 | avg. reward: -1.8126122692771311
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.98133555 2.1934948  0.58746842 1.63685369]
# Exploration noise: 0.020000740960540744
# Sub_Episode: 161 | avg. reward: -1.8058957723345888
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.94204132 2.20446148 0.58812703 1.6437624 ]
# Exploration noise: 0.02000068399005104
# Sub_Episode: 162 | avg. reward: -1.808847045539877
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.92026112 2.22490394 0.58132725 1.66453104]
# Exploration noise: 0.020000631399871106
# Sub_Episode: 163 | avg. reward: -1.8113156914167985
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.95327159 2.20892994 0.59640533 1.63999503]
# Exploration noise: 0.020000582853210554
# Sub_Episode: 164 | avg. reward: -1.817122703040478
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.93471137 2.222622   0.60413508 1.65842573]
# Exploration noise: 0.020000538039173902
# Sub_Episode: 165 | avg. reward: -1.80647222004494
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.94576903 2.18988754 0.60312941 1.67890438]
# Exploration noise: 0.020000496670769606
# Sub_Episode: 166 | avg. reward: -1.800974067227977
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.89762861 2.16770965 0.59421719 1.66106409]
# Exploration noise: 0.020000458483072137
# Sub_Episode: 167 | avg. reward: -1.8047895573253891
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.88836819 2.20210023 0.59923828 1.65089971]
# Exploration noise: 0.02000042323152539
# Sub_Episode: 168 | avg. reward: -1.8165166574652896
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.85501853 2.23422722 0.58904558 1.68463653]
# Exploration noise: 0.020000390690376523
# Sub_Episode: 169 | avg. reward: -1.7963196811825584
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.91712331 2.20247957 0.6069954  1.69142474]
# Exploration noise: 0.02000036065123024
# Sub_Episode: 170 | avg. reward: -1.7982533927391011
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.95949122 2.14175104 0.61921511 1.66958564]
# Exploration noise: 0.0200003329217142
# Sub_Episode: 171 | avg. reward: -1.7944167855601514
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.916416   2.19253492 0.59613064 1.660373  ]
# Exploration noise: 0.020000307324247065
# Sub_Episode: 172 | avg. reward: -1.806658794748676
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.91084477 2.22067205 0.61660993 1.67349865]
# Exploration noise: 0.02000028369490125
# Sub_Episode: 173 | avg. reward: -1.8106612651159788
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.90461241 2.22850193 0.60795273 1.6790093 ]
# Exploration noise: 0.02000026188235313
# Sub_Episode: 174 | avg. reward: -1.8071370228070212
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.86742929 2.23371989 0.57815279 1.68006426]
# Exploration noise: 0.02000024174691395
# Sub_Episode: 175 | avg. reward: -1.8099358405177997
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.93386737 2.19018644 0.60532453 1.67535772]
# Exploration noise: 0.020000223159635254
# Sub_Episode: 176 | avg. reward: -1.798433856270289
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.87411371 2.20136956 0.57926024 1.70547708]
# Exploration noise: 0.020000206001483094
# Sub_Episode: 177 | avg. reward: -1.812386425730416
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.87628675 2.18719338 0.59758714 1.69125177]
# Exploration noise: 0.02000019016257572
# Sub_Episode: 178 | avg. reward: -1.7898993216008607
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.89664002 2.19148665 0.58409398 1.63024251]
# Exploration noise: 0.020000175541479908
# Sub_Episode: 179 | avg. reward: -1.7852709073022297
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.90904656 2.18979409 0.60027957 1.70698008]
# Exploration noise: 0.020000162044561346
# Sub_Episode: 180 | avg. reward: -1.7977372656254533
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.89502744 2.17732923 0.58803276 1.6561754 ]
# Exploration noise: 0.02000014958538504
# Sub_Episode: 181 | avg. reward: -1.7912759281569648
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.88790406 2.16621804 0.56285652 1.64277407]
# Exploration noise: 0.020000138084161737
# Sub_Episode: 182 | avg. reward: -1.7919134522218951
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.90744086 2.17205959 0.56942576 1.61720891]
# Exploration noise: 0.02000012746723697
# Sub_Episode: 183 | avg. reward: -1.787375810452685
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.86569332 2.25170608 0.57723859 1.62117971]
# Exploration noise: 0.02000011766661938
# Sub_Episode: 184 | avg. reward: -1.7852175497171978
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.88585455 2.19418037 0.56958827 1.62778229]
# Exploration noise: 0.020000108619545265
# Sub_Episode: 185 | avg. reward: -1.789828956888573
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.86365645 2.20539294 0.56384759 1.64277612]
# Exploration noise: 0.020000100268076672
# Sub_Episode: 186 | avg. reward: -1.7933055794595345
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.89478264 2.20734891 0.56891888 1.62297291]
# Exploration noise: 0.020000092558730337
# Sub_Episode: 187 | avg. reward: -1.793920226628366
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.89840814 2.19965242 0.56813617 1.63321885]
# Exploration noise: 0.020000085442135183
# Sub_Episode: 188 | avg. reward: -1.7965240000104745
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.95370029 2.18980687 0.57064894 1.6567564 ]
# Exploration noise: 0.020000078872716143
# Sub_Episode: 189 | avg. reward: -1.7819555241227045
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.9564842  2.17661666 0.57495646 1.69150392]
# Exploration noise: 0.020000072808402304
# Sub_Episode: 190 | avg. reward: -1.7883410999553582
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.89830509 2.15218935 0.59962757 1.69648302]
# Exploration noise: 0.02000006721035746
# Sub_Episode: 191 | avg. reward: -1.7885135132032355
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.88563601 2.18212154 0.59724747 1.62731719]
# Exploration noise: 0.02000006204273143
# Sub_Episode: 192 | avg. reward: -1.780488853873347
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.90042253 2.19905374 0.58675927 1.62794753]
# Exploration noise: 0.02000005727243045
# Sub_Episode: 193 | avg. reward: -1.7894265959254876
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.87630737 2.17395226 0.59111011 1.64753601]
# Exploration noise: 0.020000052868905258
# Sub_Episode: 194 | avg. reward: -1.7805689396844933
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.8446938  2.19547309 0.58829487 1.68030497]
# Exploration noise: 0.02000004880395543
# Sub_Episode: 195 | avg. reward: -1.8047796217968781
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.85741875 2.20260221 0.59262771 1.65516867]
# Exploration noise: 0.020000045051548808
# Sub_Episode: 196 | avg. reward: -1.7913571352972348
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.84758774 2.18184771 0.59300063 1.64553044]
# Exploration noise: 0.02000004158765477
# Sub_Episode: 197 | avg. reward: -1.794193796430597
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.86781435 2.15105913 0.57627789 1.55709646]
# Exploration noise: 0.020000038390090357
# Sub_Episode: 198 | avg. reward: -1.7882913738455277
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.92719056 2.17010424 0.61024344 1.65693027]
# Exploration noise: 0.020000035438378184
# Sub_Episode: 199 | avg. reward: -1.8072816944576784
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.97661668 2.16698113 0.66329612 1.55097554]
# Exploration noise: 0.020000032713615327
# Sub_Episode: 200 | avg. reward: -1.7819026181397624
# Avg Weights Multipliers [Q1, Q2 ,R1, R2]: [1.97192551 2.19182862 0.62609759 1.58530675]
# Exploration noise: 0.020000032713615327

# %%
from utils.plotting import plot_rl_results_td3_weights_dqnstyle, compare_mpc_rl_nominal_from_dirs

# %%
out_td3 = plot_rl_results_td3_weights_dqnstyle(
    y_sp=y_sp,
    steady_states=steady_states,
    nFE=nFE,
    delta_t=delta_t,
    time_in_sub_episodes=time_in_sub_episodes,
    y_rl=y_system,
    u_rl=u_rl,
    avg_rewards=avg_rewards,
    data_min=data_min,
    data_max=data_max,
    mult_log=mult_log,
    low_coef=LOW_COEF,
    high_coef=HIGH_COEF,
    reward_fn=reward_fn,
    start_episode=2,
    prefix_name="td3_weights_disturb",
    directory=dir_path,
    save_pdf=False
)

# %%
out_dir_cmp = compare_mpc_rl_nominal_from_dirs(
    rl_dir=out_td3,
    mpc_path_or_dir=r"C:\Users\HAMEDI\Desktop\RL_assisted_MPC_polymer\Data\mpc_results_dist.pickle",
    reward_fn=reward_fn,
    directory=r"Result",
    prefix_name="disturb_compare_td3_weights",
    start_episode=2
)
